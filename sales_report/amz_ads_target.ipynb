# %% [markdown]
# Doc title: **Amazon Advertising Targeting Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Targeting Report' @Amazon Seller Central.
#
# 文章备注：亚马逊后台广告目标投放报告分析
#
# Last modified date: 2019-07-22 21:47:01

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，2019年6月份数据
workdf = pd.read_excel('amz_ads_target_us_201906.xlsx', usecols=['广告活动名称', '广告组名称', '匹配类型', '投放', '展现量', '点击量', '花费', '7天总销售额(￥)', '7天总销售量(#)'])

# %% [markdown]
# # 广告组数据排序（以销量为取值标准）

# %%
# Manipulating data and column names.
impr_df = workdf.groupby(['广告活动名称', '广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False).head(20)
impr_df['总销售额'] = impr_df['7天总销售额(￥)']
impr_df['总销售量'] = impr_df['7天总销售量(#)']
impr_df = impr_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
impr_df['点击率'] = round((impr_df['点击量'] / impr_df['展现量'] * 100), 2)
impr_df['卖出1件商品的平均花费'] = round(impr_df['花费'] / impr_df['总销售量'], 2)

impr_df.sort_values(by=['卖出1件商品的平均花费'])
# Out:
#                                                               展现量   点击量  \
# 广告活动名称                                       广告组名称
# Advertise Long Term Storage Items - Hotmarzz 0701-粉        101748   296
#                                              0706           40670   112
# Advertise Catalog38.24 - Hotmarzz            Others        360583   849
# Stranded Product Ad Promotion                FBA Instock   153500   510
# 手投                                           纯色系列            3063    50
# Advertise 0722、0742Low Traffic - Hotmarzz    Others        466526  1502
# 手投                                           女款平底纯色        204499   631
# Advertise Top 0731、0701 Items - Hotmarzz     Others        627295  1513
# 厚底人字拖                                        厚底人字拖全部        45522   422
# Advertise Long Term Storage Items - Hotmarzz Others        250281   869
# 童鞋自动                                         童鞋             39393    88
# Advertise New0739 Products - Hotmarzz        Others        699883   796
# havaianas测试                                  斑点狗           377810  1522
# 自投                                           自投           3446588  7225
# 男款鞋                                          全部男款           85430   227
# 广泛                                           测试广泛           16633    76
# 0701测试                                       0701          136424   362
# 黑色纯色女款                                       全部黑色款式女款       41949    87
# 0701测试                                       0731          641346  1336
# 男款手投                                         全部款           190522   315
#
#                                                                花费     总销售额  \
# 广告活动名称                                       广告组名称
# Advertise Long Term Storage Items - Hotmarzz 0701-粉        111.20   781.46
#                                              0706           44.49   322.80
# Advertise Catalog38.24 - Hotmarzz            Others        280.98  1770.85
# Stranded Product Ad Promotion                FBA Instock   150.15   746.70
# 手投                                           纯色系列           15.10    79.95
# Advertise 0722、0742Low Traffic - Hotmarzz    Others        436.73  2185.63
# 手投                                           女款平底纯色        181.23   754.51
# Advertise Top 0731、0701 Items - Hotmarzz     Others        442.08  1880.82
# 厚底人字拖                                        厚底人字拖全部       142.66   548.66
# Advertise Long Term Storage Items - Hotmarzz Others        241.18   912.43
# 童鞋自动                                         童鞋             35.78   111.92
# Advertise New0739 Products - Hotmarzz        Others        291.08   990.35
# havaianas测试                                  斑点狗           478.06  1645.94
# 自投                                           自投           2234.81  7681.14
# 男款鞋                                          全部男款           67.34   159.89
# 广泛                                           测试广泛           43.89   111.93
# 0701测试                                       0701          260.23   517.65
# 黑色纯色女款                                       全部黑色款式女款       46.43    93.94
# 0701测试                                       0731          706.85  1286.19
# 男款手投                                         全部款           144.44   190.07
#
#                                                           总销售量   点击率  \
# 广告活动名称                                       广告组名称
# Advertise Long Term Storage Items - Hotmarzz 0701-粉         54  0.29
#                                              0706           20  0.28
# Advertise Catalog38.24 - Hotmarzz            Others        115  0.24
# Stranded Product Ad Promotion                FBA Instock    50  0.33
# 手投                                           纯色系列            5  1.63
# Advertise 0722、0742Low Traffic - Hotmarzz    Others        137  0.32
# 手投                                           女款平底纯色         49  0.31
# Advertise Top 0731、0701 Items - Hotmarzz     Others        118  0.24
# 厚底人字拖                                        厚底人字拖全部        34  0.93
# Advertise Long Term Storage Items - Hotmarzz Others         57  0.35
# 童鞋自动                                         童鞋              8  0.22
# Advertise New0739 Products - Hotmarzz        Others         65  0.11
# havaianas测试                                  斑点狗           106  0.40
# 自投                                           自投            486  0.21
# 男款鞋                                          全部男款           11  0.27
# 广泛                                           测试广泛            7  0.46
# 0701测试                                       0701           35  0.27
# 黑色纯色女款                                       全部黑色款式女款        6  0.21
# 0701测试                                       0731           81  0.21
# 男款手投                                         全部款            13  0.17
#
#                                                           卖出1件商品的平均花费
# 广告活动名称                                       广告组名称
# Advertise Long Term Storage Items - Hotmarzz 0701-粉              2.06
#                                              0706                2.22
# Advertise Catalog38.24 - Hotmarzz            Others              2.44
# Stranded Product Ad Promotion                FBA Instock         3.00
# 手投                                           纯色系列                3.02
# Advertise 0722、0742Low Traffic - Hotmarzz    Others              3.19
# 手投                                           女款平底纯色              3.70
# Advertise Top 0731、0701 Items - Hotmarzz     Others              3.75
# 厚底人字拖                                        厚底人字拖全部             4.20
# Advertise Long Term Storage Items - Hotmarzz Others              4.23
# 童鞋自动                                         童鞋                  4.47
# Advertise New0739 Products - Hotmarzz        Others              4.48
# havaianas测试                                  斑点狗                 4.51
# 自投                                           自投                  4.60
# 男款鞋                                          全部男款                6.12
# 广泛                                           测试广泛                6.27
# 0701测试                                       0701                7.44
# 黑色纯色女款                                       全部黑色款式女款            7.74
# 0701测试                                       0731                8.73
# 男款手投                                         全部款                11.11

# %% [markdown]
# 此表解决的问题为：
#
# - 找出展现量最高的广告组。
#
# - 找出最具性价比的广告组。（卖出1件商品花费越小，则性价比越高）

# %% [markdown]
# # 投放数据排序（以展现量为取值标准）

# %%
# Manipulating data and column names.
target_df = workdf.groupby(['广告组名称', '匹配类型', '投放']).sum().sort_values(by=['展现量'], ascending=False).head(20)
target_df['总销售额'] = target_df['7天总销售额(￥)']
target_df['总销售量'] = target_df['7天总销售量(#)']
target_df = target_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
target_df['性价比(总销售额/花费)'] = round(target_df['总销售额'] / target_df['花费'], 2)

target_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                                                        展现量   点击量       花费  \
# 广告组名称       匹配类型   投放
# FBA Instock -      substitutes                       39123    51    13.51
# 0701-粉      -      substitutes                       56065    71    23.68
# Others      BROAD  *                               2404568  5529  1692.05
# 女款平底纯色      BROAD  womens flip flops                177753   537   157.66
# FBA Instock -      loose-match                       91757   355   106.29
# 0701-粉      -      loose-match                       40924   192    73.91
# 自投          BROAD  *                               3446588  7225  2234.81
# 斑点狗         BROAD  havaianas women                   42971    79    31.95
#             EXACT  havaianas flip flops for women    27798   284    86.47
#             BROAD  havaianas flip flops for women    47644   157    75.00
# 全部款         PHRASE men's flip flops                  30357   137    48.70
# 斑点狗         BROAD  havaianas                        215653   569   158.82
# 全部男款        BROAD  *                                 85430   227    67.34
# 0701        EXACT  flip flop for women              105708   275   198.40
# 全部黑色款式女款    EXACT  black flip flops for women        41216    84    45.23
# 0701        EXACT  women's flip flops                28688    76    55.65
# 0731        EXACT  flip flops for women             564532   877   505.84
#                    women's flip flops                32045    57    26.91
# 全部款         EXACT  flip flops for men                40520    74    42.55
#             BROAD  mens' sandals                    111678    73    38.61
#
#                                                       总销售额  总销售量  性价比(总销售额/花费)
# 广告组名称       匹配类型   投放
# FBA Instock -      substitutes                      208.86    14         15.46
# 0701-粉      -      substitutes                      223.84    16          9.45
# Others      BROAD  *                               7740.08   492          4.57
# 女款平底纯色      BROAD  womens flip flops                644.58    42          4.09
# FBA Instock -      loose-match                      429.91    29          4.04
# 0701-粉      -      loose-match                      282.81    19          3.83
# 自投          BROAD  *                               7681.14   486          3.44
# 斑点狗         BROAD  havaianas women                  105.93     7          3.32
#             EXACT  havaianas flip flops for women   282.82    18          3.27
#             BROAD  havaianas flip flops for women   236.85    15          3.16
# 全部款         PHRASE men's flip flops                 145.10    10          2.98
# 斑点狗         BROAD  havaianas                        465.70    30          2.93
# 全部男款        BROAD  *                                159.89    11          2.37
# 0701        EXACT  flip flop for women              414.72    28          2.09
# 全部黑色款式女款    EXACT  black flip flops for women        93.94     6          2.08
# 0701        EXACT  women's flip flops               102.93     7          1.85
# 0731        EXACT  flip flops for women             784.49    51          1.55
#                    women's flip flops                13.99     1          0.52
# 全部款         EXACT  flip flops for men                13.99     1          0.33
#             BROAD  mens' sandals                      0.00     0          0.00

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的投放项目。

# %% [markdown]
# # 性价比最高的Top 10广告组与全部广告组数据对比

# %% [markdown]
# *注：在某一项目组每投入1美元带来的销售额回报越高，则其性价比越高。*

# %% [markdown]
# ## Top 10广告组

# %%
# Top 10 Ads.
top10_df = workdf.groupby(['广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False)
top10_df['总销售额'] = top10_df['7天总销售额(￥)']
top10_df['性价比'] = round(top10_df['总销售额'] / top10_df['花费'], 2)
top10_df = top10_df[['展现量', '点击量', '花费', '总销售额', '性价比']].sort_values(by=['性价比'], ascending=False).head(10)

top10_df
# Out:
#                  展现量   点击量       花费     总销售额   性价比
# 广告组名称
# 0706           40670   112    44.49   322.80  7.26
# 0701-粉        101748   296   111.20   781.46  7.03
# 纯色系列            3063    50    15.10    79.95  5.29
# FBA Instock   153500   510   150.15   746.70  4.97
# Others       2404568  5529  1692.05  7740.08  4.57
# 女款平底纯色        204499   631   181.23   754.51  4.16
# 厚底人字拖全部        45522   422   142.66   548.66  3.85
# 黑色厚底            2840    47    18.47    63.96  3.46
# 斑点狗           377810  1522   478.06  1645.94  3.44
# 自投           3446588  7225  2234.81  7681.14  3.44

# %% [markdown]
# ## 数据对比

# %%
total_ds = workdf.sum()
top10_ds = top10_df.sum()

print('结论：')
print('\nTop 10广告组花费为：{0:.2f}美元； 全部广告组花费为：{1:.2f}美元； Top 10广告组占比：{2:.2f}%'.format(top10_ds['花费'], total_ds['花费'], top10_ds['花费'] / total_ds['花费'] * 100))
print('\nTop 10广告组共销售：{0:.2f}美元； 全部广告组共销售：{1:.2f}美元； Top 10广告组占比：{2:.2f}%'.format(top10_ds['总销售额'], total_ds['7天总销售额(￥)'], top10_ds['总销售额'] / total_ds['7天总销售额(￥)'] * 100))
# Out:
# 结论：
#
# Top 10广告组花费为：5068.22美元； 全部广告组花费为：6396.33美元； Top 10广告组占比：79.24%
#
# Top 10广告组共销售：20365.20美元； 全部广告组共销售：22852.78美元； Top 10广告组占比：89.11%

# %% [markdown]
# **[返回目录](amz_ads_links.ipynb)**
