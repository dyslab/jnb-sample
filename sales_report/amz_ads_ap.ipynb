# %% [markdown]
# Doc title: **Amazon Advertising Advertised Product Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Advertised Product Report' @Amazon Seller Central. Certain columns which contained the product ASIN has been removed from the file.
#
# 文章备注：亚马逊后台广告产品报告分析。其中包含ASIN数据的列已从文件中删除。
#
# Last modified date: 2019-07-23 19:39:10

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，2019年6月份数据
workdf = pd.read_excel('amz_ads_ap_us_201906.xlsx', usecols=['广告活动名称', '广告组名称', '广告SKU', '展现量', '点击量', '花费', '7天总销售额(￥)', '7天总销售量(#)', '7天内其他SKU销售量(#)', '7天内其他SKU销售额(￥)'])

# %% [markdown]
# # 广告组数据排序（以销量为取值标准）

# %% [markdown]
# *注：此部分结果请查看 [amz_ads_target.ipynb](amz_ads_target.ipynb) 中相关内容。*

# %% [raw]
# # Manipulating data and column names.
# impr_df = workdf.groupby(['广告活动名称', '广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False).head(20)
# impr_df['总销售额'] = impr_df['7天总销售额(￥)']
# impr_df['总销售量'] = impr_df['7天总销售量(#)']
# impr_df = impr_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
# impr_df['点击率'] = round((impr_df['点击量'] / impr_df['展现量'] * 100), 2)
# impr_df['卖出1件商品的平均花费'] = round(impr_df['花费'] / impr_df['总销售量'], 2)
#
# impr_df.sort_values(by=['卖出1件商品的平均花费'])
#
# # Note: Regarding the result is as same as the analyzation in 'amz_ads_target.ipynb', check it out there as well as this section was annotated as a raw data cell.

# %% [markdown]
# 此表解决的问题为：
#
# - 找出展现量最高的广告组。
#
# - 找出最具性价比的广告组。（卖出1件商品花费越小，则性价比越高）

# %% [markdown]
# # 广告产品数据排序（以展现量为取值标准）

# %% [markdown]
# ## 最具性价比的广告产品以及其所在的广告组

# %%
# Manipulating data and column names.
ap_df = workdf.groupby(['广告活动名称', '广告组名称', '广告SKU']).sum().sort_values(by=['展现量'], ascending=False).head(20)
ap_df['总销售额'] = ap_df['7天总销售额(￥)']
ap_df['总销售量'] = ap_df['7天总销售量(#)']
ap_df = ap_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
ap_df['性价比(总销售额/花费)'] = round(ap_df['总销售额'] / ap_df['花费'], 2)

ap_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                                                                     展现量  点击量  \
# 广告活动名称                                       广告组名称  广告SKU
# Advertise Long Term Storage Items - Hotmarzz 0701-粉 HM0701-F-37  101699  296
# Advertise New0739 Products - Hotmarzz        Others HM0729-L-41  128496  166
# Advertise Catalog38.24 - Hotmarzz            Others HM0724-F-37   89045  207
# Advertise Top 0731、0701 Items - Hotmarzz     Others HM0701-F-37  115933  307
# 自投                                           自投     HM0731-Z-35   88224  610
#                                                     HM0740-3241  236912  594
#                                                     HM0744-240    74065   51
#                                                     HM0724-F-37   68115  138
# Advertise New0739 Products - Hotmarzz        Others HM0739-237   145450  133
# 自投                                           自投     HM0722-M-39  212074  393
#                                                     HM0706-L-39   93981  129
# 0701测试                                       0731   HM0731-Z-36   77983   96
# Advertise Top 0731、0701 Items - Hotmarzz     Others HM0731-Z-36   58763   96
# Advertise New0739 Products - Hotmarzz        Others HM0903-1633  113292  129
# 0701测试                                       0731   HM0701-X-40   90129   59
#                                                     HM0737-Z-40   68120  119
# 自投                                           自投     HM0725-2740  102628   70
#                                                     HM0701-B-36   74793   46
#                                                     HM0731-Y-41   57334   15
#                                                     HM0709-1239   57285   16
#
#                                                                      花费  \
# 广告活动名称                                       广告组名称  广告SKU
# Advertise Long Term Storage Items - Hotmarzz 0701-粉 HM0701-F-37  111.20
# Advertise New0739 Products - Hotmarzz        Others HM0729-L-41   63.19
# Advertise Catalog38.24 - Hotmarzz            Others HM0724-F-37   77.50
# Advertise Top 0731、0701 Items - Hotmarzz     Others HM0701-F-37   92.85
# 自投                                           自投     HM0731-Z-35  176.76
#                                                     HM0740-3241  191.78
#                                                     HM0744-240    17.23
#                                                     HM0724-F-37   42.52
# Advertise New0739 Products - Hotmarzz        Others HM0739-237    52.89
# 自投                                           自投     HM0722-M-39  129.65
#                                                     HM0706-L-39   42.36
# 0701测试                                       0731   HM0731-Z-36   51.35
# Advertise Top 0731、0701 Items - Hotmarzz     Others HM0731-Z-36   28.75
# Advertise New0739 Products - Hotmarzz        Others HM0903-1633   47.10
# 0701测试                                       0731   HM0701-X-40   33.06
#                                                     HM0737-Z-40   67.41
# 自投                                           自投     HM0725-2740   22.60
#                                                     HM0701-B-36   15.42
#                                                     HM0731-Y-41    5.07
#                                                     HM0709-1239    5.44
#
#                                                                    总销售额  总销售量  \
# 广告活动名称                                       广告组名称  广告SKU
# Advertise Long Term Storage Items - Hotmarzz 0701-粉 HM0701-F-37  781.46    54
# Advertise New0739 Products - Hotmarzz        Others HM0729-L-41  339.78    22
# Advertise Catalog38.24 - Hotmarzz            Others HM0724-F-37  349.77    23
# Advertise Top 0731、0701 Items - Hotmarzz     Others HM0701-F-37  394.73    27
# 自投                                           自投     HM0731-Z-35  738.58    42
#                                                     HM0740-3241  766.51    49
#                                                     HM0744-240    64.96     4
#                                                     HM0724-F-37  137.91     9
# Advertise New0739 Products - Hotmarzz        Others HM0739-237   169.89    11
# 自投                                           自投     HM0722-M-39  406.74    26
#                                                     HM0706-L-39  106.93     7
# 0701测试                                       0731   HM0731-Z-36   97.94     6
# Advertise Top 0731、0701 Items - Hotmarzz     Others HM0731-Z-36   51.97     3
# Advertise New0739 Products - Hotmarzz        Others HM0903-1633   83.94     6
# 0701测试                                       0731   HM0701-X-40   58.96     4
#                                                     HM0737-Z-40  110.93     7
# 自投                                           自投     HM0725-2740   32.98     2
#                                                     HM0701-B-36   13.99     1
#                                                     HM0731-Y-41    0.00     0
#                                                     HM0709-1239    0.00     0
#
#                                                                  性价比(总销售额/花费)
# 广告活动名称                                       广告组名称  广告SKU
# Advertise Long Term Storage Items - Hotmarzz 0701-粉 HM0701-F-37          7.03
# Advertise New0739 Products - Hotmarzz        Others HM0729-L-41          5.38
# Advertise Catalog38.24 - Hotmarzz            Others HM0724-F-37          4.51
# Advertise Top 0731、0701 Items - Hotmarzz     Others HM0701-F-37          4.25
# 自投                                           自投     HM0731-Z-35          4.18
#                                                     HM0740-3241          4.00
#                                                     HM0744-240           3.77
#                                                     HM0724-F-37          3.24
# Advertise New0739 Products - Hotmarzz        Others HM0739-237           3.21
# 自投                                           自投     HM0722-M-39          3.14
#                                                     HM0706-L-39          2.52
# 0701测试                                       0731   HM0731-Z-36          1.91
# Advertise Top 0731、0701 Items - Hotmarzz     Others HM0731-Z-36          1.81
# Advertise New0739 Products - Hotmarzz        Others HM0903-1633          1.78
# 0701测试                                       0731   HM0701-X-40          1.78
#                                                     HM0737-Z-40          1.65
# 自投                                           自投     HM0725-2740          1.46
#                                                     HM0701-B-36          0.91
#                                                     HM0731-Y-41          0.00
#                                                     HM0709-1239          0.00

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的广告产品以及其所在的广告组。

# %% [markdown]
# ## 最具性价比的广告产品（不考虑其所在的广告组）

# %%
# Manipulating data and column names.
ap_df = workdf.groupby(['广告SKU']).sum().sort_values(by=['展现量'], ascending=False).head(20)
ap_df['总销售额'] = ap_df['7天总销售额(￥)']
ap_df['总销售量'] = ap_df['7天总销售量(#)']
ap_df = ap_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
ap_df['性价比(总销售额/花费)'] = round(ap_df['总销售额'] / ap_df['花费'], 2)

ap_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                 展现量  点击量      花费     总销售额  总销售量  性价比(总销售额/花费)
# 广告SKU
# HM0724-F-36   83327  258   86.04   612.60    40          7.12
# HM0729-L-41  134558  173   65.36   435.72    28          6.67
# HM0701-F-37  255278  698  253.64  1338.08    92          5.28
# HM0722-L-37  110065  496  150.06   661.59    41          4.41
# HM0731-Z-39   79198  872  297.13  1270.27    73          4.28
# HM0731-Z-35   88262  611  176.96   738.58    42          4.17
# HM0740-3241  236912  594  191.78   766.51    49          4.00
# HM0724-F-37  209813  495  165.56   623.59    41          3.77
# HM0731-H-39  105974  405  133.45   485.71    29          3.64
# HM0722-H-40  111586  163   59.93   191.88    12          3.20
# HM0739-237   149418  138   54.53   169.89    11          3.12
# HM0722-M-39  212771  396  130.53   406.74    26          3.12
# HM0706-L-39  123609  220   70.69   201.87    13          2.86
# HM0722-C-36   76143  289   81.14   223.86    14          2.76
# HM0731-Z-38   86393  103   34.75    88.95     5          2.56
# HM0903-1633  117231  145   55.41   139.90    10          2.52
# HM0701-B-36   85638   82   35.95    56.96     4          1.58
# HM0701-X-40  153087  143   57.93    87.94     6          1.52
# HM0725-2740  102628   70   22.60    32.98     2          1.46
# HM0731-Z-36  189785  305  114.73   167.90    10          1.46

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的广告产品（不考虑其所在的广告组）。

# %% [markdown]
# **[返回目录](amz_ads_links.ipynb)**
