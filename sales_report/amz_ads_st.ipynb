# %% [markdown]
# Doc title: **Amazon Advertising Search Term Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Search Term Report' @Amazon Seller Central.
#
# 文章备注：亚马逊后台广告搜索词报告分析
#
# Last modified date: 2019-07-22 04:07:48

# %%
# 引入pandas数据分析模块
import pandas as pd

workdf = pd.read_excel('amz_ads_st_201906.xlsx', usecols=['广告活动名称', '广告组名称', '客户搜索词', '展现量', '点击量', '花费', '7天总销售额(￥)', '7天总销售量(#)', '7天内广告SKU销售量(#)'])
workdf.groupby(['广告活动名称', '广告组名称']).sum()
# Out:
#                                                               展现量   点击量  \
# 广告活动名称                                       广告组名称
# 0701测试                                       0701          125557   362
#                                              0731          617043  1336
#                                              07311             30     2
# 0701测试2                                      0701测试          7518    19
# Advertise 0722、0742Low Traffic - Hotmarzz    Others         87551  1502
# Advertise Catalog38.24 - Hotmarzz            Others         72402   848
# Advertise Long Term Storage Items - Hotmarzz 0701-粉          9719   295
#                                              0706            3674   112
#                                              Others         45036   869
# Advertise New0739 Products - Hotmarzz        Others         98852   796
# Advertise Top 0731、0701 Items - Hotmarzz     Others        105696  1513
# ...
