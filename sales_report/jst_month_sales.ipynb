# %%
import pandas as pd
from pyecharts import options as opts
from pyecharts.globals import ThemeType
from pyecharts.charts import Bar, Pie, Line, Map, Grid

# %%
workdf = pd.read_excel('jst_month_sales.xlsx', sheet_name='Sheet1')
workdf
# Out:
#      区域   销售单数    销售数量    实发数量    退货单数    退货数量    实退数量
# 0    广东  21806   27738   27090   814.0   981.0   882.0
# 1    未知    106   15693   15693     NaN     NaN     NaN
# 2    江苏   5566    6538    6385   212.0   256.0   220.0
# 3    浙江   5390    6465    6379   179.0   228.0   194.0
# 4    北京   5051    6173    6037   192.0   227.0   190.0
# 5    上海   4883    6000    5901   176.0   232.0   199.0
# 6    福建   3798    4512    4400   121.0   152.0   135.0
# 7    四川   3375    4088    3952   111.0   139.0   128.0
# 8    山东   3183    3631    3566   121.0   161.0   138.0
# 9    河南   2783    3107    3055   113.0   131.0   116.0
# 10   湖北   2698    3086    3035    93.0   108.0   100.0
# 11   云南   2120    3049    2915    56.0   115.0   108.0
# 12   广西   2450    2880    2846    89.0   101.0    93.0
# 13   湖南   2125    2400    2368    75.0    82.0    73.0
# 14   安徽   2034    2321    2277    81.0    93.0    83.0
# 15   河北   1802    2088    2016    80.0    99.0    92.0
# 16   陕西   1668    2027    1942    73.0    93.0    85.0
# 17   重庆   1422    1693    1661    57.0    66.0    55.0
# 18   天津   1416    1636    1616    54.0    63.0    53.0
# 19   江西   1233    1389    1374    55.0    66.0    53.0
# 20   辽宁   1163    1336    1324    61.0    74.0    67.0
# 21   海南    718    1321    1272    21.0    49.0    17.0
# 22   山西    541     634     621    24.0    38.0    26.0
# 23   贵州    528     614     587    12.0    13.0    12.0
# 24   吉林    440     492     489    23.0    31.0    23.0
# 25  黑龙江    424     488     485    30.0    32.0    32.0
# 26   甘肃    241     281     275    12.0    14.0    14.0
# 27   内蒙    219     264     249     7.0     8.0     8.0
# 28   新疆    107     135     133     2.0     3.0     2.0
# 29   宁夏     79      90      85     1.0     1.0     0.0
# 30   青海     38      41      40     NaN     NaN     NaN
# 31   西藏      6       7       7     NaN     NaN     NaN
# 32   香港      2       3       3     2.0     3.0     3.0
# 33   台湾      1       1       1     1.0     1.0     1.0
# 34    #  79416  112221  110079  2948.0  3660.0  3202.0

# %% [markdown]
# # 销售单数/实发数量分析图表

# %%
orders = (workdf.loc[:, ['区域', '销售单数', '实发数量']])[:-1].set_index('销售单数', drop=False).sort_index(0, ascending=False)
orders
# Out:
#         区域   销售单数   实发数量
# 销售单数
# 21806   广东  21806  27090
# 5566    江苏   5566   6385
# 5390    浙江   5390   6379
# 5051    北京   5051   6037
# 4883    上海   4883   5901
# 3798    福建   3798   4400
# 3375    四川   3375   3952
# 3183    山东   3183   3566
# 2783    河南   2783   3055
# 2698    湖北   2698   3035
# 2450    广西   2450   2846
# 2125    湖南   2125   2368
# 2120    云南   2120   2915
# 2034    安徽   2034   2277
# 1802    河北   1802   2016
# 1668    陕西   1668   1942
# 1422    重庆   1422   1661
# 1416    天津   1416   1616
# 1233    江西   1233   1374
# 1163    辽宁   1163   1324
# 718     海南    718   1272
# 541     山西    541    621
# 528     贵州    528    587
# 440     吉林    440    489
# 424    黑龙江    424    485
# 241     甘肃    241    275
# 219     内蒙    219    249
# 107     新疆    107    133
# 106     未知    106  15693
# 79      宁夏     79     85
# 38      青海     38     40
# 6       西藏      6      7
# 2       香港      2      3
# 1       台湾      1      1

# %% [markdown]
# pyecharts **ThemeType**:
#
# 'BUILTIN_THEMES', 'CHALK', 'DARK', 'ESSOS', 'INFOGRAPHIC', 'LIGHT',
#
# 'MACARONS', 'PURPLE_PASSION', 'ROMA', 'ROMANTIC', 'SHINE', 'VINTAGE',
#
# 'WALDEN', 'WESTEROS', 'WHITE', 'WONDERLAND'

# %%
bar1 = (
    Bar(init_opts = opts.InitOpts(theme = ThemeType.INFOGRAPHIC))
    .add_xaxis(orders[:10]['区域'].to_list())
    .add_yaxis("销售单数", orders[:10]['销售单数'].to_list())
    .add_yaxis("实发数量", orders[:10]['实发数量'].to_list())
    .set_global_opts(title_opts = opts.TitleOpts(title="每月销售订单数", subtitle="TOP 10"))
)
bar1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'infographic':'https://assets.pyecharts.org/assets/themes/infographic'
#         }
#     });
# </script>
#
#     <div id="855830c47be44afbb5c65785baefbae6" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'infographic'], function(echarts) {
#         var chart_855830c47be44afbb5c65785baefbae6 = echarts.init(
#             document.getElementById('855830c47be44afbb5c65785baefbae6'), 'infographic', {renderer: 'canvas'});
#         var option_855830c47be44afbb5c65785baefbae6 = {
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9500\u552e\u5355\u6570",
#             "data": [
#                 21806,
#                 5566,
#                 5390,
#                 5051,
#                 4883,
#                 3798,
#                 3375,
#                 3183,
#                 2783,
#                 2698
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5b9e\u53d1\u6570\u91cf",
#             "data": [
#                 27090,
#                 6385,
#                 6379,
#                 6037,
#                 5901,
#                 4400,
#                 3952,
#                 3566,
#                 3055,
#                 3035
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u552e\u5355\u6570",
#                 "\u5b9e\u53d1\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u9500\u552e\u5355\u6570": true,
#                 "\u5b9e\u53d1\u6570\u91cf": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5e7f\u4e1c",
#                 "\u6c5f\u82cf",
#                 "\u6d59\u6c5f",
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77",
#                 "\u798f\u5efa",
#                 "\u56db\u5ddd",
#                 "\u5c71\u4e1c",
#                 "\u6cb3\u5357",
#                 "\u6e56\u5317"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6bcf\u6708\u9500\u552e\u8ba2\u5355\u6570",
#             "subtext": "TOP 10"
#         }
#     ]
# };
#         chart_855830c47be44afbb5c65785baefbae6.setOption(option_855830c47be44afbb5c65785baefbae6);
#     });
# </script>

# %%
# 计算及构建饼图数据。取销售单数前10的省份，其他省份销量数据合并。
orders_piedata = [list(x) for x in zip(orders[0:10]['区域'], orders[0:10]['销售单数'])]
orders_piedata.append(['其它地区', int(orders[10:orders.shape[0]]['销售单数'].sum())])

pie1 = (
    Pie(init_opts = opts.InitOpts(theme = ThemeType.MACARONS))
    .add("销售单数", orders_piedata, radius=['25%', '70%'])
    .set_global_opts(title_opts = opts.TitleOpts(title="每月销售订单数-区域占比", pos_left='center', pos_top="bottom"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}，占比：{d}%"))
)
pie1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'macarons':'https://assets.pyecharts.org/assets/themes/macarons'
#         }
#     });
# </script>
#
#     <div id="6f5343da96864c5783fe4dbe6ac60202" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'macarons'], function(echarts) {
#         var chart_6f5343da96864c5783fe4dbe6ac60202 = echarts.init(
#             document.getElementById('6f5343da96864c5783fe4dbe6ac60202'), 'macarons', {renderer: 'canvas'});
#         var option_6f5343da96864c5783fe4dbe6ac60202 = {
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u9500\u552e\u5355\u6570",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 21806
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 5566
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 5390
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 5051
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 4883
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 3798
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 3375
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 3183
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 2783
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 2698
#                 },
#                 {
#                     "name": "\u5176\u5b83\u5730\u533a",
#                     "value": 20883
#                 }
#             ],
#             "radius": [
#                 "25%",
#                 "70%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}\uff0c\u5360\u6bd4\uff1a{d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e7f\u4e1c",
#                 "\u6c5f\u82cf",
#                 "\u6d59\u6c5f",
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77",
#                 "\u798f\u5efa",
#                 "\u56db\u5ddd",
#                 "\u5c71\u4e1c",
#                 "\u6cb3\u5357",
#                 "\u6e56\u5317",
#                 "\u5176\u5b83\u5730\u533a"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6bcf\u6708\u9500\u552e\u8ba2\u5355\u6570-\u533a\u57df\u5360\u6bd4",
#             "left": "center",
#             "top": "bottom"
#         }
#     ]
# };
#         chart_6f5343da96864c5783fe4dbe6ac60202.setOption(option_6f5343da96864c5783fe4dbe6ac60202);
#     });
# </script>

# %%
provincesdataset = [list(x) for x in zip(orders['区域'], orders['销售单数'])]

# 设置颜色分段属性
scalar_step = 3000
scalar_max = (int((provincesdataset[0][1] - 1) / scalar_step) + 1) * scalar_step
scalar_min = 0
scalar_number = scalar_max / scalar_step

# %%
map1 = (
    Map()
    .add(
        "销售单数", 
        provincesdataset,
        "china",
        is_roam=False
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(
            min_=scalar_min, 
            max_=scalar_max,
            is_piecewise=True,
            split_number=scalar_number,
            range_color=["#FFF0F0", "#FF0000"]
        ),
        title_opts=opts.TitleOpts(title="销售单数-区域对比")
    )
)

map1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="c398fd01ffa54739840696a85dbec193" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_c398fd01ffa54739840696a85dbec193 = echarts.init(
#             document.getElementById('c398fd01ffa54739840696a85dbec193'), 'white', {renderer: 'canvas'});
#         var option_c398fd01ffa54739840696a85dbec193 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u9500\u552e\u5355\u6570",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 21806
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 5566
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 5390
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 5051
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 4883
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 3798
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 3375
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 3183
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 2783
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 2698
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 2450
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 2125
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 2120
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 2034
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 1802
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 1668
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 1422
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 1416
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 1233
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 1163
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 718
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 541
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 528
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 440
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 424
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 241
#                 },
#                 {
#                     "name": "\u5185\u8499",
#                     "value": 219
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 107
#                 },
#                 {
#                     "name": "\u672a\u77e5",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 79
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 1
#                 }
#             ],
#             "roam": false,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u552e\u5355\u6570"
#             ],
#             "selected": {
#                 "\u9500\u552e\u5355\u6570": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u9500\u552e\u5355\u6570-\u533a\u57df\u5bf9\u6bd4"
#         }
#     ],
#     "visualMap": {
#         "type": "piecewise",
#         "min": 0,
#         "max": 24000,
#         "inRange": {
#             "color": [
#                 "#FFF0F0",
#                 "#FF0000"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 8.0,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#         chart_c398fd01ffa54739840696a85dbec193.setOption(option_c398fd01ffa54739840696a85dbec193);
#     });
# </script>

# %% [markdown]
# # 销售单数/退货单数分析图表

# %%
returns = (workdf.loc[:, ['区域', '销售单数', '退货单数']])[:-1].set_index('销售单数', drop=False).sort_index(0, ascending=False)
returns['退货比例']=[round(x*100,2) for x in returns['退货单数']/returns['销售单数']]
# 退货率条件：销量大于1000
valid_returns = returns[returns['销售单数']>1000]
valid_returns
# Out:
#        区域   销售单数   退货单数  退货比例
# 销售单数
# 21806  广东  21806  814.0  3.73
# 5566   江苏   5566  212.0  3.81
# 5390   浙江   5390  179.0  3.32
# 5051   北京   5051  192.0  3.80
# 4883   上海   4883  176.0  3.60
# 3798   福建   3798  121.0  3.19
# 3375   四川   3375  111.0  3.29
# 3183   山东   3183  121.0  3.80
# 2783   河南   2783  113.0  4.06
# 2698   湖北   2698   93.0  3.45
# 2450   广西   2450   89.0  3.63
# 2125   湖南   2125   75.0  3.53
# 2120   云南   2120   56.0  2.64
# 2034   安徽   2034   81.0  3.98
# 1802   河北   1802   80.0  4.44
# 1668   陕西   1668   73.0  4.38
# 1422   重庆   1422   57.0  4.01
# 1416   天津   1416   54.0  3.81
# 1233   江西   1233   55.0  4.46
# 1163   辽宁   1163   61.0  5.25

# %%
bar10 = (
    Bar()
    .add_xaxis(valid_returns['区域'].to_list())
    .add_yaxis("销售单数", valid_returns['销售单数'].to_list())
    .add_yaxis("退货单数", valid_returns['退货单数'].to_list())
    .set_global_opts(title_opts = opts.TitleOpts(title="每月销售/退货订单数"))
)
line10 = (
    Line()
    .add_xaxis(valid_returns['区域'].to_list())
    .add_yaxis("退货比例（%）", valid_returns['退货比例'].to_list())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="每月退货订单数百分比", pos_top="62%"),
        legend_opts=opts.LegendOpts(pos_top="62%")
     )
)
grid10 = (
    Grid(init_opts = opts.InitOpts(height="600px"))
    .add(bar10, grid_opts=opts.GridOpts(pos_bottom="45%"))
    .add(line10, grid_opts=opts.GridOpts(pos_top="70%"))
)
grid10.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="d2149159be4c4138acc7fef9fc3eed3b" style="width:900px; height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_d2149159be4c4138acc7fef9fc3eed3b = echarts.init(
#             document.getElementById('d2149159be4c4138acc7fef9fc3eed3b'), 'white', {renderer: 'canvas'});
#         var option_d2149159be4c4138acc7fef9fc3eed3b = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9500\u552e\u5355\u6570",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 21806,
#                 5566,
#                 5390,
#                 5051,
#                 4883,
#                 3798,
#                 3375,
#                 3183,
#                 2783,
#                 2698,
#                 2450,
#                 2125,
#                 2120,
#                 2034,
#                 1802,
#                 1668,
#                 1422,
#                 1416,
#                 1233,
#                 1163
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u9000\u8d27\u5355\u6570",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 814.0,
#                 212.0,
#                 179.0,
#                 192.0,
#                 176.0,
#                 121.0,
#                 111.0,
#                 121.0,
#                 113.0,
#                 93.0,
#                 89.0,
#                 75.0,
#                 56.0,
#                 81.0,
#                 80.0,
#                 73.0,
#                 57.0,
#                 54.0,
#                 55.0,
#                 61.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u9000\u8d27\u6bd4\u4f8b\uff08%\uff09",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5e7f\u4e1c",
#                     3.73
#                 ],
#                 [
#                     "\u6c5f\u82cf",
#                     3.81
#                 ],
#                 [
#                     "\u6d59\u6c5f",
#                     3.32
#                 ],
#                 [
#                     "\u5317\u4eac",
#                     3.8
#                 ],
#                 [
#                     "\u4e0a\u6d77",
#                     3.6
#                 ],
#                 [
#                     "\u798f\u5efa",
#                     3.19
#                 ],
#                 [
#                     "\u56db\u5ddd",
#                     3.29
#                 ],
#                 [
#                     "\u5c71\u4e1c",
#                     3.8
#                 ],
#                 [
#                     "\u6cb3\u5357",
#                     4.06
#                 ],
#                 [
#                     "\u6e56\u5317",
#                     3.45
#                 ],
#                 [
#                     "\u5e7f\u897f",
#                     3.63
#                 ],
#                 [
#                     "\u6e56\u5357",
#                     3.53
#                 ],
#                 [
#                     "\u4e91\u5357",
#                     2.64
#                 ],
#                 [
#                     "\u5b89\u5fbd",
#                     3.98
#                 ],
#                 [
#                     "\u6cb3\u5317",
#                     4.44
#                 ],
#                 [
#                     "\u9655\u897f",
#                     4.38
#                 ],
#                 [
#                     "\u91cd\u5e86",
#                     4.01
#                 ],
#                 [
#                     "\u5929\u6d25",
#                     3.81
#                 ],
#                 [
#                     "\u6c5f\u897f",
#                     4.46
#                 ],
#                 [
#                     "\u8fbd\u5b81",
#                     5.25
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u552e\u5355\u6570",
#                 "\u9000\u8d27\u5355\u6570"
#             ],
#             "selected": {
#                 "\u9500\u552e\u5355\u6570": true,
#                 "\u9000\u8d27\u5355\u6570": true
#             },
#             "show": true
#         },
#         {
#             "data": [
#                 "\u9000\u8d27\u6bd4\u4f8b\uff08%\uff09"
#             ],
#             "selected": {
#                 "\u9000\u8d27\u6bd4\u4f8b\uff08%\uff09": true
#             },
#             "show": true,
#             "top": "62%"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5e7f\u4e1c",
#                 "\u6c5f\u82cf",
#                 "\u6d59\u6c5f",
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77",
#                 "\u798f\u5efa",
#                 "\u56db\u5ddd",
#                 "\u5c71\u4e1c",
#                 "\u6cb3\u5357",
#                 "\u6e56\u5317",
#                 "\u5e7f\u897f",
#                 "\u6e56\u5357",
#                 "\u4e91\u5357",
#                 "\u5b89\u5fbd",
#                 "\u6cb3\u5317",
#                 "\u9655\u897f",
#                 "\u91cd\u5e86",
#                 "\u5929\u6d25",
#                 "\u6c5f\u897f",
#                 "\u8fbd\u5b81"
#             ]
#         },
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 1,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5e7f\u4e1c",
#                 "\u6c5f
