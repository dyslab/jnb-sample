# %% [markdown]
# Doc title: **Amazon Advertising Placement Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Placement Report' @Amazon Seller Central.
#
# 文章备注：亚马逊后台广告位置报告分析。
#
# Last modified date: 2019-10-05 03:19:53

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_placement_us_201909.xlsx', usecols=['广告活动名称', '竞价策略', '放置', '展现量', '点击量', '花费', '7天总销售额(￥)', '7天总销售量(#)'])

# %% [markdown]
# # 广告位置数据排序（以展现量为取值标准）

# %% [markdown]
# ## 点击率表现最好的广告位置

# %%
# Manipulating data and column names.
placement_df = workdf.groupby(['广告活动名称', '放置']).sum().sort_values(by=['展现量'], ascending=False).head(20)
placement_df['总销售额'] = placement_df['7天总销售额(￥)']
placement_df['总销售量'] = placement_df['7天总销售量(#)']
placement_df = placement_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
placement_df['点击率(点击量/展现量)'] = round(placement_df['点击量'] / placement_df['展现量'] * 100, 2)

placement_df.sort_values(by=['点击率(点击量/展现量)'], ascending=False)
# Out:
#                                                                 展现量   点击量  \
# 广告活动名称                                       放置
# Advertise Top 0731、0701 Items - Hotmarzz     亚马逊上搜索结果的其余位置    25925   278
# 0701测试                                       亚马逊上搜索结果的其余位置    53940   541
# Advertise New0739 Products - Hotmarzz        亚马逊上搜索结果的其余位置    21798   211
# Advertise 0722、0742Low Traffic - Hotmarzz    亚马逊上搜索结果的其余位置    37538   295
# 自投                                           亚马逊上搜索结果的其余位置   106256   736
# 厚底人字拖                                        亚马逊上的商品页面       147433   375
# havaianas测试                                  亚马逊上的商品页面        87958   215
# Advertise Catalog38.24 - Hotmarzz            亚马逊上的商品页面       191880   427
# 男款鞋                                          亚马逊上的商品页面        39159    85
# Advertise 0722、0742Low Traffic - Hotmarzz    亚马逊上的商品页面       196566   348
# Advertise Top 0731、0701 Items - Hotmarzz     亚马逊上的商品页面       104701   173
# Stranded Product Ad Promotion                亚马逊上的商品页面       350890   585
# 0701测试                                       亚马逊上的商品页面       311497   519
# Advertise New0739 Products - Hotmarzz        亚马逊上的商品页面       135602   215
# 手投                                           亚马逊上的商品页面       296515   455
# Advertise Long Term Storage Items - Hotmarzz 亚马逊上的商品页面       158721   196
# 棉拖                                           亚马逊上的商品页面        24471    29
# 男款手投                                         亚马逊上的商品页面        44664    48
# 颜色分类                                         亚马逊上的商品页面        26123    29
# 自投                                           亚马逊上的商品页面      2303842  2584
#
#                                                                  花费     总销售额  \
# 广告活动名称                                       放置
# Advertise Top 0731、0701 Items - Hotmarzz     亚马逊上搜索结果的其余位置    80.36   371.65
# 0701测试                                       亚马逊上搜索结果的其余位置   218.87   882.84
# Advertise New0739 Products - Hotmarzz        亚马逊上搜索结果的其余位置    55.26   353.18
# Advertise 0722、0742Low Traffic - Hotmarzz    亚马逊上搜索结果的其余位置    76.91   333.80
# 自投                                           亚马逊上搜索结果的其余位置   286.77  1315.17
# 厚底人字拖                                        亚马逊上的商品页面       172.64   519.69
# havaianas测试                                  亚马逊上的商品页面        72.49   346.38
# Advertise Catalog38.24 - Hotmarzz            亚马逊上的商品页面       111.63   487.69
# 男款鞋                                          亚马逊上的商品页面        21.64    95.94
# Advertise 0722、0742Low Traffic - Hotmarzz    亚马逊上的商品页面       117.64   541.97
# Advertise Top 0731、0701 Items - Hotmarzz     亚马逊上的商品页面        50.08   185.87
# Stranded Product Ad Promotion                亚马逊上的商品页面       174.27   761.81
# 0701测试                                       亚马逊上的商品页面       271.59   710.94
# Advertise New0739 Products - Hotmarzz        亚马逊上的商品页面        57.11   390.85
# 手投                                           亚马逊上的商品页面       215.70   826.78
# Advertise Long Term Storage Items - Hotmarzz 亚马逊上的商品页面       117.00   301.11
# 棉拖                                           亚马逊上的商品页面        31.97    81.95
# 男款手投                                         亚马逊上的商品页面        27.34    31.98
# 颜色分类                                         亚马逊上的商品页面        12.19    80.95
# 自投                                           亚马逊上的商品页面      1403.81  3421.03
#
#                                                             总销售量  点击率(点击量/展现量)
# 广告活动名称                                       放置
# Advertise Top 0731、0701 Items - Hotmarzz     亚马逊上搜索结果的其余位置    25          1.07
# 0701测试                                       亚马逊上搜索结果的其余位置    56          1.00
# Advertise New0739 Products - Hotmarzz        亚马逊上搜索结果的其余位置    22          0.97
# Advertise 0722、0742Low Traffic - Hotmarzz    亚马逊上搜索结果的其余位置    20          0.79
# 自投                                           亚马逊上搜索结果的其余位置    83          0.69
# 厚底人字拖                                        亚马逊上的商品页面        31          0.25
# havaianas测试                                  亚马逊上的商品页面        22          0.24
# Advertise Catalog38.24 - Hotmarzz            亚马逊上的商品页面        31          0.22
# 男款鞋                                          亚马逊上的商品页面         6          0.22
# Advertise 0722、0742Low Traffic - Hotmarzz    亚马逊上的商品页面        33          0.18
# Advertise Top 0731、0701 Items - Hotmarzz     亚马逊上的商品页面        13          0.17
# Stranded Product Ad Promotion                亚马逊上的商品页面        49          0.17
# 0701测试                                       亚马逊上的商品页面        46          0.17
# Advertise New0739 Products - Hotmarzz        亚马逊上的商品页面        25          0.16
# 手投                                           亚马逊上的商品页面        53          0.15
# Advertise Long Term Storage Items - Hotmarzz 亚马逊上的商品页面        19          0.12
# 棉拖                                           亚马逊上的商品页面         5          0.12
# 男款手投                                         亚马逊上的商品页面         2          0.11
# 颜色分类                                         亚马逊上的商品页面         5          0.11
# 自投                                           亚马逊上的商品页面       217          0.11

# %% [markdown]
# 解决问题：
#
# - 在具备一定展现量基础上，不同位置的点击率哪个表现更好。

# %% [markdown]
# ## 不同位置的性价比（花费、销量、销售额）对比

# %%
# Manipulating data and column names.
placement_df = workdf.groupby(['放置']).sum().sort_values(by=['展现量'], ascending=False).head(20)
placement_df['总销售额'] = placement_df['7天总销售额(￥)']
placement_df['总销售量'] = placement_df['7天总销售量(#)']
placement_df = placement_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
placement_df['性价比(总销售额/花费)'] = round(placement_df['总销售额'] / placement_df['花费'], 2)

placement_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                     展现量   点击量       花费     总销售额  总销售量  性价比(总销售额/花费)
# 放置
# 在非亚马逊平台进行再营销       2528     9     3.12    15.29     1          4.90
# 亚马逊上搜索结果的其余位置    368274  3083  1023.85  5002.54   316          4.89
# 亚马逊上第一个页面的热门搜索    52020  1826   819.51  3349.56   214          4.09
# 亚马逊上的商品页面       4443473  6307  2861.57  8784.94   557          3.07

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的广告位置。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
