# %% [markdown]
# Doc title: **Amazon Advertising Placement Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Placement Report' @Amazon Seller Central.
#
# 文章备注：亚马逊后台广告位置报告分析。
#
# Last modified date: 2019-11-03 20:35:26

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_placement_us_201910.xlsx', usecols=['广告活动名称', '竞价策略', '放置', '展现量', '点击量', '花费', '7天总销售额(￥)', '7天总销售量(#)'])

# %% [markdown]
# # 广告位置数据排序（以展现量为取值标准）

# %% [markdown]
# ## 点击率表现最好的广告位置

# %%
# Manipulating data and column names.
placement_df = workdf.groupby(['广告活动名称', '放置']).sum().sort_values(by=['展现量'], ascending=False).head(20)
placement_df['总销售额'] = placement_df['7天总销售额(￥)']
placement_df['总销售量'] = placement_df['7天总销售量(#)']
placement_df = placement_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
placement_df['点击率(点击量/展现量)'] = round(placement_df['点击量'] / placement_df['展现量'] * 100, 2)

placement_df.sort_values(by=['点击率(点击量/展现量)'], ascending=False)
# Out:
#                                                              展现量   点击量  \
# 广告活动名称                                    放置
# havaianas测试                               亚马逊上搜索结果的其余位置    27937   288
# 自投                                        亚马逊上搜索结果的其余位置    41091   375
# Advertise Top 0731、0701 Items - Hotmarzz  亚马逊上搜索结果的其余位置    24100   220
# Advertise New0739 Products - Hotmarzz     亚马逊上搜索结果的其余位置    11481   100
# Advertise 0722、0742Low Traffic - Hotmarzz 亚马逊上搜索结果的其余位置    23371   204
# 0701测试                                    亚马逊上搜索结果的其余位置    36421   250
# 厚底人字拖                                     亚马逊上的商品页面       146683   341
# 男款鞋                                       亚马逊上的商品页面        25230    49
# Advertise Catalog38.24 - Hotmarzz         亚马逊上的商品页面       180256   341
# 颜色分类                                      亚马逊上的商品页面        66895   118
# Stranded Product Ad Promotion             亚马逊上的商品页面        72612   126
# Advertise New0739 Products - Hotmarzz     亚马逊上的商品页面       178587   268
# 手投                                        亚马逊上的商品页面       137356   192
# 男款手投                                      亚马逊上的商品页面        32094    37
# havaianas测试                               亚马逊上的商品页面       190623   224
# Advertise Top 0731、0701 Items - Hotmarzz  亚马逊上的商品页面       364939   452
# 童鞋自动                                      亚马逊上的商品页面        18085    21
# Advertise 0722、0742Low Traffic - Hotmarzz 亚马逊上的商品页面       250213   264
# 0701测试                                    亚马逊上的商品页面       367102   362
# 自投                                        亚马逊上的商品页面      1239092  1185
#
#                                                              花费     总销售额  \
# 广告活动名称                                    放置
# havaianas测试                               亚马逊上搜索结果的其余位置  102.50   567.66
# 自投                                        亚马逊上搜索结果的其余位置  118.12   810.49
# Advertise Top 0731、0701 Items - Hotmarzz  亚马逊上搜索结果的其余位置   57.22   314.80
# Advertise New0739 Products - Hotmarzz     亚马逊上搜索结果的其余位置   26.52    88.95
# Advertise 0722、0742Low Traffic - Hotmarzz 亚马逊上搜索结果的其余位置   50.80   314.81
# 0701测试                                    亚马逊上搜索结果的其余位置  202.82   570.64
# 厚底人字拖                                     亚马逊上的商品页面      178.71   283.83
# 男款鞋                                       亚马逊上的商品页面       13.82    61.96
# Advertise Catalog38.24 - Hotmarzz         亚马逊上的商品页面      118.16   633.60
# 颜色分类                                      亚马逊上的商品页面       72.37   330.79
# Stranded Product Ad Promotion             亚马逊上的商品页面       40.02   142.91
# Advertise New0739 Products - Hotmarzz     亚马逊上的商品页面       71.60   260.84
# 手投                                        亚马逊上的商品页面       91.12   147.91
# 男款手投                                      亚马逊上的商品页面       24.16    15.99
# havaianas测试                               亚马逊上的商品页面      115.55   435.72
# Advertise Top 0731、0701 Items - Hotmarzz  亚马逊上的商品页面      130.47   817.48
# 童鞋自动                                      亚马逊上的商品页面        3.46    55.96
# Advertise 0722、0742Low Traffic - Hotmarzz 亚马逊上的商品页面       75.31   374.77
# 0701测试                                    亚马逊上的商品页面      307.14   606.61
# 自投                                        亚马逊上的商品页面      512.55  1874.83
#
#                                                          总销售量  点击率(点击量/展现量)
# 广告活动名称                                    放置
# havaianas测试                               亚马逊上搜索结果的其余位置    34          1.03
# 自投                                        亚马逊上搜索结果的其余位置    51          0.91
# Advertise Top 0731、0701 Items - Hotmarzz  亚马逊上搜索结果的其余位置    20          0.91
# Advertise New0739 Products - Hotmarzz     亚马逊上搜索结果的其余位置     5          0.87
# Advertise 0722、0742Low Traffic - Hotmarzz 亚马逊上搜索结果的其余位置    19          0.87
# 0701测试                                    亚马逊上搜索结果的其余位置    36          0.69
# 厚底人字拖                                     亚马逊上的商品页面        17          0.23
# 男款鞋                                       亚马逊上的商品页面         4          0.19
# Advertise Catalog38.24 - Hotmarzz         亚马逊上的商品页面        40          0.19
# 颜色分类                                      亚马逊上的商品页面        21          0.18
# Stranded Product Ad Promotion             亚马逊上的商品页面         9          0.17
# Advertise New0739 Products - Hotmarzz     亚马逊上的商品页面        16          0.15
# 手投                                        亚马逊上的商品页面         9          0.14
# 男款手投                                      亚马逊上的商品页面         1          0.12
# havaianas测试                               亚马逊上的商品页面        28          0.12
# Advertise Top 0731、0701 Items - Hotmarzz  亚马逊上的商品页面        52          0.12
# 童鞋自动                                      亚马逊上的商品页面         4          0.12
# Advertise 0722、0742Low Traffic - Hotmarzz 亚马逊上的商品页面        23          0.11
# 0701测试                                    亚马逊上的商品页面        39          0.10
# 自投                                        亚马逊上的商品页面       117          0.10

# %% [markdown]
# 解决问题：
#
# - 在具备一定展现量基础上，不同位置的点击率哪个表现更好。

# %% [markdown]
# ## 不同位置的性价比（花费、销量、销售额）对比

# %%
# Manipulating data and column names.
placement_df = workdf.groupby(['放置']).sum().sort_values(by=['展现量'], ascending=False).head(20)
placement_df['总销售额'] = placement_df['7天总销售额(￥)']
placement_df['总销售量'] = placement_df['7天总销售量(#)']
placement_df = placement_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
placement_df['性价比(总销售额/花费)'] = round(placement_df['总销售额'] / placement_df['花费'], 2)

placement_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                     展现量   点击量       花费     总销售额  总销售量  性价比(总销售额/花费)
# 放置
# 在非亚马逊平台进行再营销       9302    31    10.15    62.96     4          6.20
# 亚马逊上搜索结果的其余位置    208260  1865   690.34  3397.90   210          4.92
# 亚马逊上第一个页面的热门搜索    34636  1066   545.75  2327.54   146          4.26
# 亚马逊上的商品页面       3276700  3990  1764.83  6043.20   380          3.42

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的广告位置。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
