# %% [markdown]
# Doc title: **Amazon Advertising Placement Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Placement Report' @Amazon Seller Central.
#
# 文章备注：亚马逊后台广告位置报告分析。
#
# Last modified date: 2019-12-05 16:49:37

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_placement_us_201911.xlsx', usecols=['广告活动名称', '竞价策略', '放置', '展现量', '点击量', '花费', '7天总销售额(￥)', '7天总销售量(#)'])

# %% [markdown]
# # 广告位置数据排序（以展现量为取值标准）

# %% [markdown]
# ## 点击率表现最好的广告位置

# %%
# Manipulating data and column names.
placement_df = workdf.groupby(['广告活动名称', '放置']).sum().sort_values(by=['展现量'], ascending=False).head(20)
placement_df['总销售额'] = placement_df['7天总销售额(￥)']
placement_df['总销售量'] = placement_df['7天总销售量(#)']
placement_df = placement_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
placement_df['点击率(点击量/展现量)'] = round(placement_df['点击量'] / placement_df['展现量'] * 100, 2)

placement_df.sort_values(by=['点击率(点击量/展现量)'], ascending=False)
# Out:
#                                                              展现量  点击量      花费  \
# 广告活动名称                                    放置
# 厚底人字拖                                     亚马逊上搜索结果的其余位置     9876  109   33.57
# havaianas测试                               亚马逊上搜索结果的其余位置    31804  336  133.54
# Advertise New0739 Products - Hotmarzz     亚马逊上搜索结果的其余位置     9215   92   27.60
# Advertise 0722、0742Low Traffic - Hotmarzz 亚马逊上搜索结果的其余位置    20680  203   45.36
# 自投                                        亚马逊上搜索结果的其余位置    37610  366  109.69
# Advertise Top 0731、0701 Items - Hotmarzz  亚马逊上搜索结果的其余位置    32783  315   92.51
# 0701测试                                    亚马逊上搜索结果的其余位置    39314  318  252.23
# 厚底人字拖                                     亚马逊上的商品页面       127947  304  146.18
# 手投                                        亚马逊上的商品页面         8798   20   11.11
# Advertise Catalog38.24 - Hotmarzz         亚马逊上的商品页面       213486  322  105.44
# Advertise New0739 Products - Hotmarzz     亚马逊上的商品页面       202766  288   77.41
# 颜色分类                                      亚马逊上的商品页面        57508   73   42.18
# 男款鞋                                       亚马逊上的商品页面        23098   30    6.16
# havaianas测试                               亚马逊上的商品页面       171245  209  124.38
# 男款手投                                      亚马逊上的商品页面        14458   17    5.99
# Advertise Top 0731、0701 Items - Hotmarzz  亚马逊上的商品页面       542200  582  167.07
# 0701测试                                    亚马逊上的商品页面       267910  270  180.19
# Advertise 0722、0742Low Traffic - Hotmarzz 亚马逊上的商品页面       269932  282   62.40
# 童鞋自动                                      亚马逊上的商品页面        44504   40    9.71
# 自投                                        亚马逊上的商品页面      1013229  879  222.62
#
#                                                             总销售额  总销售量  \
# 广告活动名称                                    放置
# 厚底人字拖                                     亚马逊上搜索结果的其余位置   135.92     8
# havaianas测试                               亚马逊上搜索结果的其余位置   394.76    24
# Advertise New0739 Products - Hotmarzz     亚马逊上搜索结果的其余位置   132.92     8
# Advertise 0722、0742Low Traffic - Hotmarzz 亚马逊上搜索结果的其余位置   167.90    10
# 自投                                        亚马逊上搜索结果的其余位置   495.69    31
# Advertise Top 0731、0701 Items - Hotmarzz  亚马逊上搜索结果的其余位置   644.58    42
# 0701测试                                    亚马逊上搜索结果的其余位置   779.50    50
# 厚底人字拖                                     亚马逊上的商品页面       253.85    15
# 手投                                        亚马逊上的商品页面         0.00     0
# Advertise Catalog38.24 - Hotmarzz         亚马逊上的商品页面       423.73    27
# Advertise New0739 Products - Hotmarzz     亚马逊上的商品页面       467.71    29
# 颜色分类                                      亚马逊上的商品页面        80.95     5
# 男款鞋                                       亚马逊上的商品页面        63.96     4
# havaianas测试                               亚马逊上的商品页面       317.80    20
# 男款手投                                      亚马逊上的商品页面         0.00     0
# Advertise Top 0731、0701 Items - Hotmarzz  亚马逊上的商品页面       966.37    63
# 0701测试                                    亚马逊上的商品页面       408.74    26
# Advertise 0722、0742Low Traffic - Hotmarzz 亚马逊上的商品页面       266.83    17
# 童鞋自动                                      亚马逊上的商品页面        14.99     1
# 自投                                        亚马逊上的商品页面      1152.29    71
#
#                                                          点击率(点击量/展现量)
# 广告活动名称                                    放置
# 厚底人字拖                                     亚马逊上搜索结果的其余位置          1.10
# havaianas测试                               亚马逊上搜索结果的其余位置          1.06
# Advertise New0739 Products - Hotmarzz     亚马逊上搜索结果的其余位置          1.00
# Advertise 0722、0742Low Traffic - Hotmarzz 亚马逊上搜索结果的其余位置          0.98
# 自投                                        亚马逊上搜索结果的其余位置          0.97
# Advertise Top 0731、0701 Items - Hotmarzz  亚马逊上搜索结果的其余位置          0.96
# 0701测试                                    亚马逊上搜索结果的其余位置          0.81
# 厚底人字拖                                     亚马逊上的商品页面              0.24
# 手投                                        亚马逊上的商品页面              0.23
# Advertise Catalog38.24 - Hotmarzz         亚马逊上的商品页面              0.15
# Advertise New0739 Products - Hotmarzz     亚马逊上的商品页面              0.14
# 颜色分类                                      亚马逊上的商品页面              0.13
# 男款鞋                                       亚马逊上的商品页面              0.13
# havaianas测试                               亚马逊上的商品页面              0.12
# 男款手投                                      亚马逊上的商品页面              0.12
# Advertise Top 0731、0701 Items - Hotmarzz  亚马逊上的商品页面              0.11
# 0701测试                                    亚马逊上的商品页面              0.10
# Advertise 0722、0742Low Traffic - Hotmarzz 亚马逊上的商品页面              0.10
# 童鞋自动                                      亚马逊上的商品页面              0.09
# 自投                                        亚马逊上的商品页面              0.09

# %% [markdown]
# 解决问题：
#
# - 在具备一定展现量基础上，不同位置的点击率哪个表现更好。

# %% [markdown]
# ## 不同位置的性价比（花费、销量、销售额）对比

# %%
# Manipulating data and column names.
placement_df = workdf.groupby(['放置']).sum().sort_values(by=['展现量'], ascending=False).head(20)
placement_df['总销售额'] = placement_df['7天总销售额(￥)']
placement_df['总销售量'] = placement_df['7天总销售量(#)']
placement_df = placement_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
placement_df['性价比(总销售额/花费)'] = round(placement_df['总销售额'] / placement_df['花费'], 2)

placement_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                     展现量   点击量       花费     总销售额  总销售量  性价比(总销售额/花费)
# 放置
# 亚马逊上第一个页面的热门搜索    16485   541   190.73   815.49    51          4.28
# 亚马逊上搜索结果的其余位置    206473  1961   758.55  3000.11   189          3.96
# 亚马逊上的商品页面       2957081  3316  1160.84  4417.22   278          3.81
# 在非亚马逊平台进行再营销       3883     9     2.32     0.00     0          0.00

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的广告位置。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
