# %% [markdown]
# Doc title: **Amazon Advertising Placement Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Placement Report' @Amazon Seller Central.
#
# 文章备注：亚马逊后台广告位置报告分析。
#
# Last modified date: 2019-09-12 17:26:44

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_placement_us_201908.xlsx', usecols=['广告活动名称', '竞价策略', '放置', '展现量', '点击量', '花费', '7天总销售额(￥)', '7天总销售量(#)'])

# %% [markdown]
# # 广告位置数据排序（以展现量为取值标准）

# %% [markdown]
# ## 点击率表现最好的广告位置

# %%
# Manipulating data and column names.
placement_df = workdf.groupby(['广告活动名称', '放置']).sum().sort_values(by=['展现量'], ascending=False).head(20)
placement_df['总销售额'] = placement_df['7天总销售额(￥)']
placement_df['总销售量'] = placement_df['7天总销售量(#)']
placement_df = placement_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
placement_df['点击率(点击量/展现量)'] = round(placement_df['点击量'] / placement_df['展现量'] * 100, 2)

placement_df.sort_values(by=['点击率(点击量/展现量)'], ascending=False)
# Out:
#                                                                  展现量   点击量  \
# 广告活动名称                                       放置
# 自投                                           亚马逊上第一个页面的热门搜索    53571  1543
# 0701测试                                       亚马逊上搜索结果的其余位置     57936   665
# Advertise Top 0731、0701 Items - Hotmarzz     亚马逊上搜索结果的其余位置     49905   395
# 自投                                           亚马逊上搜索结果的其余位置    284841  2077
# 手投                                           亚马逊上搜索结果的其余位置     36569   220
# Advertise Catalog38.24 - Hotmarzz            亚马逊上搜索结果的其余位置     58965   300
# 厚底人字拖                                        亚马逊上的商品页面        161118   326
# havaianas测试                                  亚马逊上的商品页面        122260   226
# 男款鞋                                          亚马逊上的商品页面         81448   143
# 棉拖                                           亚马逊上的商品页面         59088   103
# 自投                                           亚马逊上的商品页面       1792700  2937
# 0701测试                                       亚马逊上的商品页面        788169  1101
# Advertise Long Term Storage Items - Hotmarzz 亚马逊上的商品页面        337123   480
# Advertise Catalog38.24 - Hotmarzz            亚马逊上的商品页面        654551   864
# Advertise Top 0731、0701 Items - Hotmarzz     亚马逊上的商品页面        308567   371
# Advertise New0739 Products - Hotmarzz        亚马逊上的商品页面        304726   375
# 手投                                           亚马逊上的商品页面        330732   381
# 童鞋自动                                         亚马逊上的商品页面         52122    65
# Stranded Product Ad Promotion                亚马逊上的商品页面        714409   889
# Advertise 0722、0742Low Traffic - Hotmarzz    亚马逊上的商品页面        670580   759
#
#                                                                  花费     总销售额  \
# 广告活动名称                                       放置
# 自投                                           亚马逊上第一个页面的热门搜索  702.97  2453.64
# 0701测试                                       亚马逊上搜索结果的其余位置   214.79   927.44
# Advertise Top 0731、0701 Items - Hotmarzz     亚马逊上搜索结果的其余位置   119.75   456.72
# 自投                                           亚马逊上搜索结果的其余位置   589.50  2749.33
# 手投                                           亚马逊上搜索结果的其余位置    89.66   501.69
# Advertise Catalog38.24 - Hotmarzz            亚马逊上搜索结果的其余位置   103.16   282.82
# 厚底人字拖                                        亚马逊上的商品页面       125.05   317.81
# havaianas测试                                  亚马逊上的商品页面        87.02   427.03
# 男款鞋                                          亚马逊上的商品页面        38.88   109.93
# 棉拖                                           亚马逊上的商品页面       110.45   197.88
# 自投                                           亚马逊上的商品页面       974.34  3123.04
# 0701测试                                       亚马逊上的商品页面       616.89  1023.96
# Advertise Long Term Storage Items - Hotmarzz 亚马逊上的商品页面       289.53   527.67
# Advertise Catalog38.24 - Hotmarzz            亚马逊上的商品页面       266.05   941.41
# Advertise Top 0731、0701 Items - Hotmarzz     亚马逊上的商品页面       120.12   222.85
# Advertise New0739 Products - Hotmarzz        亚马逊上的商品页面        92.56   234.85
# 手投                                           亚马逊上的商品页面       197.52   451.72
# 童鞋自动                                         亚马逊上的商品页面        11.15    27.98
# Stranded Product Ad Promotion                亚马逊上的商品页面       282.31  1004.35
# Advertise 0722、0742Low Traffic - Hotmarzz    亚马逊上的商品页面       366.05   690.58
#
#                                                              总销售量  \
# 广告活动名称                                       放置
# 自投                                           亚马逊上第一个页面的热门搜索   156
# 0701测试                                       亚马逊上搜索结果的其余位置     56
# Advertise Top 0731、0701 Items - Hotmarzz     亚马逊上搜索结果的其余位置     28
# 自投                                           亚马逊上搜索结果的其余位置    167
# 手投                                           亚马逊上搜索结果的其余位置     31
# Advertise Catalog38.24 - Hotmarzz            亚马逊上搜索结果的其余位置     18
# 厚底人字拖                                        亚马逊上的商品页面         19
# havaianas测试                                  亚马逊上的商品页面         27
# 男款鞋                                          亚马逊上的商品页面          7
# 棉拖                                           亚马逊上的商品页面         12
# 自投                                           亚马逊上的商品页面        196
# 0701测试                                       亚马逊上的商品页面         64
# Advertise Long Term Storage Items - Hotmarzz 亚马逊上的商品页面         33
# Advertise Catalog38.24 - Hotmarzz            亚马逊上的商品页面         59
# Advertise Top 0731、0701 Items - Hotmarzz     亚马逊上的商品页面         15
# Advertise New0739 Products - Hotmarzz        亚马逊上的商品页面         15
# 手投                                           亚马逊上的商品页面         28
# 童鞋自动                                         亚马逊上的商品页面          2
# Stranded Product Ad Promotion                亚马逊上的商品页面         65
# Advertise 0722、0742Low Traffic - Hotmarzz    亚马逊上的商品页面         42
#
#                                                              点击率(点击量/展现量)
# 广告活动名称                                       放置
# 自投                                           亚马逊上第一个页面的热门搜索          2.88
# 0701测试                                       亚马逊上搜索结果的其余位置           1.15
# Advertise Top 0731、0701 Items - Hotmarzz     亚马逊上搜索结果的其余位置           0.79
# 自投                                           亚马逊上搜索结果的其余位置           0.73
# 手投                                           亚马逊上搜索结果的其余位置           0.60
# Advertise Catalog38.24 - Hotmarzz            亚马逊上搜索结果的其余位置           0.51
# 厚底人字拖                                        亚马逊上的商品页面               0.20
# havaianas测试                                  亚马逊上的商品页面               0.18
# 男款鞋                                          亚马逊上的商品页面               0.18
# 棉拖                                           亚马逊上的商品页面               0.17
# 自投                                           亚马逊上的商品页面               0.16
# 0701测试                                       亚马逊上的商品页面               0.14
# Advertise Long Term Storage Items - Hotmarzz 亚马逊上的商品页面               0.14
# Advertise Catalog38.24 - Hotmarzz            亚马逊上的商品页面               0.13
# Advertise Top 0731、0701 Items - Hotmarzz     亚马逊上的商品页面               0.12
# Advertise New0739 Products - Hotmarzz        亚马逊上的商品页面               0.12
# 手投                                           亚马逊上的商品页面               0.12
# 童鞋自动                                         亚马逊上的商品页面               0.12
# Stranded Product Ad Promotion                亚马逊上的商品页面               0.12
# Advertise 0722、0742Low Traffic - Hotmarzz    亚马逊上的商品页面               0.11

# %% [markdown]
# 解决问题：
#
# - 在具备一定展现量基础上，不同位置的点击率哪个表现更好。

# %% [markdown]
# ## 不同位置的性价比（花费、销量、销售额）对比

# %%
# Manipulating data and column names.
placement_df = workdf.groupby(['放置']).sum().sort_values(by=['展现量'], ascending=False).head(20)
placement_df['总销售额'] = placement_df['7天总销售额(￥)']
placement_df['总销售量'] = placement_df['7天总销售量(#)']
placement_df = placement_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
placement_df['性价比(总销售额/花费)'] = round(placement_df['总销售额'] / placement_df['花费'], 2)

placement_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                            展现量   点击量       花费     总销售额  总销售量  性价比(总销售额/花费)
# 放置
# 亚马逊上搜索结果的其余位置           653340  5059  1513.87  6747.18   412          4.46
# 亚马逊上第一个页面的热门搜索           96813  2862  1321.67  4365.71   279          3.30
# 亚马逊上的商品页面              6437993  9097  3616.59  9398.00   590          2.60
# Detail page on-Amazon     1451     1     0.21     0.00     0          0.00

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的广告位置。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
