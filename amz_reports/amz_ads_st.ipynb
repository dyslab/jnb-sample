# %% [markdown]
# Doc title: **Amazon Advertising Search Term Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Search Term Report' @Amazon Seller Central.
#
# 文章备注：亚马逊后台广告搜索词报告分析
#
# Last modified date: 2019-11-03 20:19:34

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_st_us_201910.xlsx', usecols=['广告活动名称', '广告组名称', '客户搜索词', '展现量', '点击量', '花费', '7天总销售额(￥)', '7天总销售量(#)'])

# %% [markdown]
# # 广告组数据排序（以销量为取值标准）

# %%
# Manipulating data and column names.
impr10_df = workdf.groupby(['广告活动名称', '广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False).head(20)
impr10_df['总销售额'] = impr10_df['7天总销售额(￥)']
impr10_df['总销售量'] = impr10_df['7天总销售量(#)']
impr10_df = impr10_df[['花费', '总销售额', '总销售量']]
impr10_df['卖出1件商品的平均花费'] = round(impr10_df['花费'] / impr10_df['总销售量'], 2)

impr10_df.sort_values(by=['卖出1件商品的平均花费'])
# Out:
#                                                            花费     总销售额  总销售量  \
# 广告活动名称                                    广告组名称
# 颜色分类                                      紫色拖鞋           3.76   109.93     7
#                                           黄色人字拖          5.91    57.96     4
#                                           粉色款式           4.69    48.97     3
# 童鞋自动                                      童鞋             6.50    55.96     4
# Stranded Product Ad Promotion             FBA Instock   51.25   317.80    20
# Advertise Top 0731、0701 Items - Hotmarzz  Others       238.22  1425.09    91
# Advertise 0722、0742Low Traffic - Hotmarzz Others       139.14   841.49    51
# 手投                                        白色系列          22.91   131.92     8
# Advertise Catalog38.24 - Hotmarzz         Others       124.69   680.57    43
# 颜色分类                                      蓝色            29.01   147.91     9
# havaianas测试                               斑点狗          332.58  1600.01    99
# 自投                                        自投           742.68  3147.03   197
# 男款鞋                                       全部男款          46.98   186.88    12
# 男款手投                                      全部款           27.69   108.93     7
# Advertise New0739 Products - Hotmarzz     Others       133.86   466.72    28
# 0701测试                                    0731          53.64   169.90    10
# 厚底人字拖                                     厚底人字拖全部      270.65   785.53    47
# 0701测试                                    平底           595.19  1331.14    86
# 颜色分类                                      全部黑色款式女款      55.59   121.92     8
# 手投                                        女款平底          84.25   111.93     7
#
#                                                        卖出1件商品的平均花费
# 广告活动名称                                    广告组名称
# 颜色分类                                      紫色拖鞋                0.54
#                                           黄色人字拖               1.48
#                                           粉色款式                1.56
# 童鞋自动                                      童鞋                  1.63
# Stranded Product Ad Promotion             FBA Instock         2.56
# Advertise Top 0731、0701 Items - Hotmarzz  Others              2.62
# Advertise 0722、0742Low Traffic - Hotmarzz Others              2.73
# 手投                                        白色系列                2.86
# Advertise Catalog38.24 - Hotmarzz         Others              2.90
# 颜色分类                                      蓝色                  3.22
# havaianas测试                               斑点狗                 3.36
# 自投                                        自投                  3.77
# 男款鞋                                       全部男款                3.92
# 男款手投                                      全部款                 3.96
# Advertise New0739 Products - Hotmarzz     Others              4.78
# 0701测试                                    0731                5.36
# 厚底人字拖                                     厚底人字拖全部             5.76
# 0701测试                                    平底                  6.92
# 颜色分类                                      全部黑色款式女款            6.95
# 手投                                        女款平底               12.04

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比（卖出1件商品花费越小，则性价比越高）的广告组。

# %% [markdown]
# # 客户搜索词数据排序（以展现量为取值标准）¶

# %%
# Manipulating data and column names.
st10_df = workdf.groupby(['广告组名称', '客户搜索词']).sum().sort_values(by=['展现量'], ascending=False).head(20)
st10_df['总销售额'] = st10_df['7天总销售额(￥)']
st10_df['总销售量'] = st10_df['7天总销售量(#)']
st10_df = st10_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
st10_df['性价比(总销售额/花费)'] = round(st10_df['总销售额'] / st10_df['花费'], 2)

st10_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                                         展现量  点击量      花费    总销售额  总销售量  \
# 广告组名称    客户搜索词
# 自投       havaianas women               5158   28    7.08   65.96     4
#          white flip flops for women    6509   55   27.87  157.90    10
# Others   havanas flip flops women      4700   80   22.93  127.92     8
# 斑点狗      havianas womens flip flops   44293  238  101.57  563.65    35
# 白色系列     white flip flops for women    5368   27   13.47   63.96     4
# Others   havaianas women               6021   57   16.49   67.96     4
# 斑点狗      havaianas flip flops women  147668  432  197.58  796.51    49
# 厚底人字拖全部  wedge flip flops for women   40682  224  101.13  366.78    22
# 平底       women flip flops             10491   27   22.24   75.95     5
# 厚底人字拖全部  wedge flip flops             26046  107   54.07  165.90    10
# 自投       flip flops                    7406    9    5.08   14.99     1
# 厚底人字拖全部  platform flip flops          27192  115   45.92  100.94     6
# 平底       flip flops for women        256669  409  405.71  883.43    57
# Others   flip flops for women         22644   94   37.00   78.95     5
# 全部黑色款式女款 black flip flops for women   34564   64   38.98   75.95     5
# 平底       womens flip flops            62088  107  103.10  184.88    12
# Others   havaianas flip flops women    6012   39   10.56   16.99     1
# 平底       flip flops women             10540   30   29.81   45.97     3
# 0731     flip flops for women          7442   41   36.20   32.98     2
# 全部款      flip flops for men            6552   14    9.92    0.00     0
#
#                                      性价比(总销售额/花费)
# 广告组名称    客户搜索词
# 自投       havaianas women                     9.32
#          white flip flops for women          5.67
# Others   havanas flip flops women            5.58
# 斑点狗      havianas womens flip flops          5.55
# 白色系列     white flip flops for women          4.75
# Others   havaianas women                     4.12
# 斑点狗      havaianas flip flops women          4.03
# 厚底人字拖全部  wedge flip flops for women          3.63
# 平底       women flip flops                    3.42
# 厚底人字拖全部  wedge flip flops                    3.07
# 自投       flip flops                          2.95
# 厚底人字拖全部  platform flip flops                 2.20
# 平底       flip flops for women                2.18
# Others   flip flops for women                2.13
# 全部黑色款式女款 black flip flops for women          1.95
# 平底       womens flip flops                   1.79
# Others   havaianas flip flops women          1.61
# 平底       flip flops women                    1.54
# 0731     flip flops for women                0.91
# 全部款      flip flops for men                  0.00

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的客户搜索词和广告组。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
