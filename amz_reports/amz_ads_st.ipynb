# %% [markdown]
# Doc title: **Amazon Advertising Search Term Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Search Term Report' @Amazon Seller Central.
#
# 文章备注：亚马逊后台广告搜索词报告分析
#
# Last modified date: 2019-08-05 05:02:39

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_st_us_201907.xlsx', usecols=['广告活动名称', '广告组名称', '客户搜索词', '展现量', '点击量', '花费', '7天总销售额(￥)', '7天总销售量(#)'])

# %% [markdown]
# # 广告组数据排序（以销量为取值标准）

# %%
# Manipulating data and column names.
impr10_df = workdf.groupby(['广告活动名称', '广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False).head(20)
impr10_df['总销售额'] = impr10_df['7天总销售额(￥)']
impr10_df['总销售量'] = impr10_df['7天总销售量(#)']
impr10_df = impr10_df[['花费', '总销售额', '总销售量']]
impr10_df['卖出1件商品的平均花费'] = round(impr10_df['花费'] / impr10_df['总销售量'], 2)

impr10_df.sort_values(by=['卖出1件商品的平均花费'])
# Out:
#                                                                花费     总销售额  \
# 广告活动名称                                       广告组名称
# 手投                                           黑色厚底            7.09    67.96
# Advertise Long Term Storage Items - Hotmarzz 0706           74.88   503.68
# 童鞋自动                                         童鞋             48.86   269.82
# Advertise 0722、0742Low Traffic - Hotmarzz    Others        578.87  3443.90
# 手投                                           纯色系列           84.54   474.70
# Advertise Long Term Storage Items - Hotmarzz Others        126.54   731.56
# 手投                                           女款平底纯色        196.79   975.38
# Advertise Top 0731、0701 Items - Hotmarzz     Others        588.21  2826.23
# 男款鞋                                          全部男款          153.06   669.57
# 黑色纯色女款                                       全部黑色款式女款       84.10   358.77
# Advertise Catalog38.24 - Hotmarzz            Others        461.47  1845.83
# 自投                                           自投           2407.10  9695.05
# havaianas测试                                  斑点狗           457.24  1780.90
# Advertise New0739 Products - Hotmarzz        Others        279.12   978.37
# Stranded Product Ad Promotion                FBA Instock   325.71  1140.27
# 男款手投                                         全部款            66.53   220.86
# 厚底人字拖                                        厚底人字拖全部       239.66   784.53
# Advertise Long Term Storage Items - Hotmarzz 0701-粉        360.09   839.44
# 0701测试                                       0731          490.59  1265.26
#                                              0701          651.07   939.38
#
#                                                           总销售量  卖出1件商品的平均花费
# 广告活动名称                                       广告组名称
# 手投                                           黑色厚底            4         1.77
# Advertise Long Term Storage Items - Hotmarzz 0706           32         2.34
# 童鞋自动                                         童鞋             18         2.71
# Advertise 0722、0742Low Traffic - Hotmarzz    Others        211         2.74
# 手投                                           纯色系列           30         2.82
# Advertise Long Term Storage Items - Hotmarzz Others         44         2.88
# 手投                                           女款平底纯色         62         3.17
# Advertise Top 0731、0701 Items - Hotmarzz     Others        177         3.32
# 男款鞋                                          全部男款           43         3.56
# 黑色纯色女款                                       全部黑色款式女款       23         3.66
# Advertise Catalog38.24 - Hotmarzz            Others        117         3.94
# 自投                                           自投            596         4.04
# havaianas测试                                  斑点狗           110         4.16
# Advertise New0739 Products - Hotmarzz        Others         63         4.43
# Stranded Product Ad Promotion                FBA Instock    73         4.46
# 男款手投                                         全部款            14         4.75
# 厚底人字拖                                        厚底人字拖全部        47         5.10
# Advertise Long Term Storage Items - Hotmarzz 0701-粉         57         6.32
# 0701测试                                       0731           74         6.63
#                                              0701           62        10.50

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比（卖出1件商品花费越小，则性价比越高）的广告组。

# %% [markdown]
# # 客户搜索词数据排序（以展现量为取值标准）¶

# %%
# Manipulating data and column names.
st10_df = workdf.groupby(['广告组名称', '客户搜索词']).sum().sort_values(by=['展现量'], ascending=False).head(20)
st10_df['总销售额'] = st10_df['7天总销售额(￥)']
st10_df['总销售量'] = st10_df['7天总销售量(#)']
st10_df = st10_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
st10_df['性价比(总销售额/花费)'] = round(st10_df['总销售额'] / st10_df['花费'], 2)

st10_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                                           展现量   点击量      花费     总销售额  总销售量  \
# 广告组名称    客户搜索词
# 斑点狗      havaianas                      73304   153   33.18   193.88    12
# Others   havianas womens flip flops     33217   335  108.11   474.72    28
# 斑点狗      havaianas flip flops women    240576   567  208.21   803.50    50
# Others   flip flops for women           88372   143   52.48   201.87    13
#          havaianas flip flops women    291865   977  327.28  1239.23    77
# 自投       havianas womens flip flops     66528   778  235.19   890.47    53
# 全部黑色款式女款 black flip flops for women     45404   106   67.12   252.84    16
# 斑点狗      havianas womens flip flops     43527   164   56.11   200.88    12
# Others   flip flops                     52441   134   49.01   164.89    11
# 自投       havaianas women                43740   138   35.76   112.93     7
#          havaianas flip flops women    223455  1524  482.20  1425.16    84
# 0731     havaianas flip flops women     49647   404  207.72   561.67    33
# 厚底人字拖全部  platform flip flops            37427   188   72.50   167.90    10
# 自投       flip flops for women           28709    86   28.54    61.96     4
# 0701     womens flip flops              46449    97   73.87   108.93     7
# 0701-粉   flip flops for women           60237    62   42.66    59.96     4
# 0701     flip flops for women          201112   495  505.60   710.53    47
# 0731     flip flops for women           53789    96   69.67    82.95     5
# 斑点狗      ipanema flip flops for women   38070   155   63.71    68.96     4
# 自投       wedge sandals for women        29996    84   27.71    16.99     1
#
#                                        性价比(总销售额/花费)
# 广告组名称    客户搜索词
# 斑点狗      havaianas                             5.84
# Others   havianas womens flip flops            4.39
# 斑点狗      havaianas flip flops women            3.86
# Others   flip flops for women                  3.85
#          havaianas flip flops women            3.79
# 自投       havianas womens flip flops            3.79
# 全部黑色款式女款 black flip flops for women            3.77
# 斑点狗      havianas womens flip flops            3.58
# Others   flip flops                            3.36
# 自投       havaianas women                       3.16
#          havaianas flip flops women            2.96
# 0731     havaianas flip flops women            2.70
# 厚底人字拖全部  platform flip flops                   2.32
# 自投       flip flops for women                  2.17
# 0701     womens flip flops                     1.47
# 0701-粉   flip flops for women                  1.41
# 0701     flip flops for women                  1.41
# 0731     flip flops for women                  1.19
# 斑点狗      ipanema flip flops for women          1.08
# 自投       wedge sandals for women               0.61

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的客户搜索词和广告组。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
