# %% [markdown]
# Doc title: **Amazon Advertising Search Term Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Search Term Report' @Amazon Seller Central.
#
# 文章备注：亚马逊后台广告搜索词报告分析
#
# Last modified date: 2019-10-05 03:08:08

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_st_us_201909.xlsx', usecols=['广告活动名称', '广告组名称', '客户搜索词', '展现量', '点击量', '花费', '7天总销售额(￥)', '7天总销售量(#)'])

# %% [markdown]
# # 广告组数据排序（以销量为取值标准）

# %%
# Manipulating data and column names.
impr10_df = workdf.groupby(['广告活动名称', '广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False).head(20)
impr10_df['总销售额'] = impr10_df['7天总销售额(￥)']
impr10_df['总销售量'] = impr10_df['7天总销售量(#)']
impr10_df = impr10_df[['花费', '总销售额', '总销售量']]
impr10_df['卖出1件商品的平均花费'] = round(impr10_df['花费'] / impr10_df['总销售量'], 2)

impr10_df.sort_values(by=['卖出1件商品的平均花费'])
# Out:
#                                                                花费     总销售额  \
# 广告活动名称                                       广告组名称
# 手投                                           黑色厚底            7.15   118.93
# Advertise Top 0731、0701 Items - Hotmarzz     Others        209.32   991.83
# Stranded Product Ad Promotion                FBA Instock   228.26  1097.59
# Advertise New0739 Products - Hotmarzz        Others        205.55  1011.86
# havaianas测试                                  斑点狗           191.39   889.93
# 男款鞋                                          全部男款           64.25   302.81
# 颜色分类                                         全部黑色款式女款       68.15   307.80
# Advertise Catalog38.24 - Hotmarzz            Others        155.82   703.55
# Advertise 0722、0742Low Traffic - Hotmarzz    Others        201.39   942.73
# 手投                                           女款平底          176.57   774.81
#                                              白色系列          110.16   485.70
# 0701测试                                       0731          293.84  1186.45
# 厚底人字拖                                        厚底人字拖全部       290.54  1172.30
# Advertise Long Term Storage Items - Hotmarzz Others         33.39   132.92
# 自投                                           自投           1990.44  5810.31
# 棉拖                                           棉拖0505         33.54    97.94
# 0701测试                                       0701          247.68   661.57
# 男款手投                                         全部款            59.10   138.91
# Advertise Long Term Storage Items - Hotmarzz 0706           35.18    63.26
#                                              特价产品           74.34   123.92
#
#                                                           总销售量  卖出1件商品的平均花费
# 广告活动名称                                       广告组名称
# 手投                                           黑色厚底            7         1.02
# Advertise Top 0731、0701 Items - Hotmarzz     Others         67         3.12
# Stranded Product Ad Promotion                FBA Instock    71         3.21
# Advertise New0739 Products - Hotmarzz        Others         64         3.21
# havaianas测试                                  斑点狗            57         3.36
# 男款鞋                                          全部男款           19         3.38
# 颜色分类                                         全部黑色款式女款       20         3.41
# Advertise Catalog38.24 - Hotmarzz            Others         45         3.46
# Advertise 0722、0742Low Traffic - Hotmarzz    Others         57         3.53
# 手投                                           女款平底           50         3.53
#                                              白色系列           30         3.67
# 0701测试                                       0731           75         3.92
# 厚底人字拖                                        厚底人字拖全部        70         4.15
# Advertise Long Term Storage Items - Hotmarzz Others          8         4.17
# 自投                                           自投            369         5.39
# 棉拖                                           棉拖0505          6         5.59
# 0701测试                                       0701           43         5.76
# 男款手投                                         全部款             9         6.57
# Advertise Long Term Storage Items - Hotmarzz 0706            4         8.80
#                                              特价产品            8         9.29

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比（卖出1件商品花费越小，则性价比越高）的广告组。

# %% [markdown]
# # 客户搜索词数据排序（以展现量为取值标准）¶

# %%
# Manipulating data and column names.
st10_df = workdf.groupby(['广告组名称', '客户搜索词']).sum().sort_values(by=['展现量'], ascending=False).head(20)
st10_df['总销售额'] = st10_df['7天总销售额(￥)']
st10_df['总销售量'] = st10_df['7天总销售量(#)']
st10_df = st10_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
st10_df['性价比(总销售额/花费)'] = round(st10_df['总销售额'] / st10_df['花费'], 2)

st10_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                                           展现量  点击量      花费    总销售额  总销售量  \
# 广告组名称    客户搜索词
# 厚底人字拖全部  platform flip flops            20143   90   32.88  182.89    11
# 斑点狗      havaianas flip flops women     57967  220   63.73  335.09    21
# Others   havaianas flip flops women     61668  404  124.26  596.52    38
# 0731     havianas womens flip flops     24284  172   58.71  278.72    18
# 全部黑色款式女款 black flip flops for women     27663   96   60.21  262.83    17
# 白色系列     white flip flops for women     49878  171  103.68  451.72    28
# 0731     havaianas flip flops women     28439  252   77.22  334.59    21
# 厚底人字拖全部  wedge flip flops               25605  155   64.85  234.86    14
#          wedge flip flops for women     56847  300  128.76  453.73    27
# 0701     womens flip flops              22242   54   36.16  125.92     8
# 斑点狗      havianas womens flip flops     18098  208   61.24  208.86    14
# 自投       flip flops                     51999  108   70.81  240.44    16
#          womens flip flops              25926   38   22.48   64.26     4
#          havianas womens flip flops     29827  181   82.25  218.56    14
# 0731     flip flops for women           60399  164   92.22  238.35    15
# 0701     flip flops for women          142394  274  169.03  415.73    27
# 全部款      flip flops for men             12516   18   13.54   31.98     2
# 斑点狗      ipanema flip flops for women   19019  136   36.66   77.85     5
# 自投       havaianas flip flops women     76380  233  103.43  192.08    12
#          flip flops for women           95273  110   69.80   96.24     6
#
#                                        性价比(总销售额/花费)
# 广告组名称    客户搜索词
# 厚底人字拖全部  platform flip flops                   5.56
# 斑点狗      havaianas flip flops women            5.26
# Others   havaianas flip flops women            4.80
# 0731     havianas womens flip flops            4.75
# 全部黑色款式女款 black flip flops for women            4.37
# 白色系列     white flip flops for women            4.36
# 0731     havaianas flip flops women            4.33
# 厚底人字拖全部  wedge flip flops                      3.62
#          wedge flip flops for women            3.52
# 0701     womens flip flops                     3.48
# 斑点狗      havianas womens flip flops            3.41
# 自投       flip flops                            3.40
#          womens flip flops                     2.86
#          havianas womens flip flops            2.66
# 0731     flip flops for women                  2.58
# 0701     flip flops for women                  2.46
# 全部款      flip flops for men                    2.36
# 斑点狗      ipanema flip flops for women          2.12
# 自投       havaianas flip flops women            1.86
#          flip flops for women                  1.38

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的客户搜索词和广告组。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
