# %% [markdown]
# Doc title: **Amazon Advertising Search Term Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Search Term Report' @Amazon Seller Central.
#
# 文章备注：亚马逊后台广告搜索词报告分析
#
# Last modified date: 2019-12-05 16:27:17

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_st_us_201911.xlsx', usecols=['广告活动名称', '广告组名称', '客户搜索词', '展现量', '点击量', '花费', '7天总销售额(￥)', '7天总销售量(#)'])

# %% [markdown]
# # 广告组数据排序（以销量为取值标准）

# %%
# Manipulating data and column names.
impr10_df = workdf.groupby(['广告活动名称', '广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False).head(20)
impr10_df['总销售额'] = impr10_df['7天总销售额(￥)']
impr10_df['总销售量'] = impr10_df['7天总销售量(#)']
impr10_df = impr10_df[['花费', '总销售额', '总销售量']]
impr10_df['卖出1件商品的平均花费'] = round(impr10_df['花费'] / impr10_df['总销售量'], 2)

impr10_df.sort_values(by=['卖出1件商品的平均花费'])
# Out:
#                                                         花费     总销售额  总销售量  \
# 广告活动名称                                    广告组名称
# 男款鞋                                       全部男款       23.32   138.91     9
# Advertise Top 0731、0701 Items - Hotmarzz  Others    289.50  1700.89   111
# Advertise New0739 Products - Hotmarzz     Others    123.48   748.54    46
# 颜色分类                                      蓝色         23.77   127.92     8
# 手投                                        黑色厚底        6.05    33.98     2
# 自投                                        自投        366.13  1758.91   109
# Advertise 0722、0742Low Traffic - Hotmarzz Others    115.10   502.69    31
# 男款手投                                      全部款        11.29    43.97     3
# Advertise Catalog38.24 - Hotmarzz         Others    114.67   456.71    29
# 童鞋自动                                      童鞋         16.93    57.96     4
# 0701测试                                    0731       25.48    99.94     6
# havaianas测试                               斑点狗       300.51   921.43    57
# 0701测试                                    平底        425.53  1103.29    71
# 手投                                        白色系列       12.37    33.98     2
# 厚底人字拖                                     厚底人字拖全部   205.91   490.71    29
# 颜色分类                                      粉色款式        7.11    15.99     1
#                                           全部黑色款式女款   34.40    32.98     2
#                                           紫色拖鞋        3.65     0.00     0
# 0701测试                                    asin广告      0.23     0.00     0
# 颜色分类                                      红色          2.83     0.00     0
#
#                                                     卖出1件商品的平均花费
# 广告活动名称                                    广告组名称
# 男款鞋                                       全部男款             2.59
# Advertise Top 0731、0701 Items - Hotmarzz  Others           2.61
# Advertise New0739 Products - Hotmarzz     Others           2.68
# 颜色分类                                      蓝色               2.97
# 手投                                        黑色厚底             3.02
# 自投                                        自投               3.36
# Advertise 0722、0742Low Traffic - Hotmarzz Others           3.71
# 男款手投                                      全部款              3.76
# Advertise Catalog38.24 - Hotmarzz         Others           3.95
# 童鞋自动                                      童鞋               4.23
# 0701测试                                    0731             4.25
# havaianas测试                               斑点狗              5.27
# 0701测试                                    平底               5.99
# 手投                                        白色系列             6.18
# 厚底人字拖                                     厚底人字拖全部          7.10
# 颜色分类                                      粉色款式             7.11
#                                           全部黑色款式女款        17.20
#                                           紫色拖鞋              inf
# 0701测试                                    asin广告            inf
# 颜色分类                                      红色                inf

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比（卖出1件商品花费越小，则性价比越高）的广告组。

# %% [markdown]
# # 客户搜索词数据排序（以展现量为取值标准）¶

# %%
# Manipulating data and column names.
st10_df = workdf.groupby(['广告组名称', '客户搜索词']).sum().sort_values(by=['展现量'], ascending=False).head(20)
st10_df['总销售额'] = st10_df['7天总销售额(￥)']
st10_df['总销售量'] = st10_df['7天总销售量(#)']
st10_df = st10_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
st10_df['性价比(总销售额/花费)'] = round(st10_df['总销售额'] / st10_df['花费'], 2)

st10_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                                         展现量  点击量      花费    总销售额  总销售量  \
# 广告组名称    客户搜索词
# 蓝色       blue flip flops               3298   17    7.98  112.93     7
# 自投       white flip flops for women    4172   49   18.64  170.89    11
# Others   havanas flip flops women      2779   34    9.73   50.97     3
#          havaianas women               3220   45    9.77   50.97     3
#          flip flops for women         45836  151   50.29  230.85    15
# 斑点狗      havianas womens flip flops   52398  219   89.36  406.75    25
# 平底       flip flops women             12691   45   34.31  134.91     9
# 厚底人字拖全部  womens wedge flip flops       2340   31    9.83   33.98     2
#          wedge flip flops             19591   88   40.59  117.93     7
#          wedge flip flops for women   36397  163   72.82  202.88    12
# 平底       flip flops for women        201154  326  264.70  664.57    43
#          womens flip flops            43001   88   71.48  161.90    10
# 自投       havaianas women               2677   31    7.37   15.99     1
# 平底       women flip flops              4487   19   15.45   32.98     2
# 斑点狗      havaianas flip flops women  123476  383  187.63  387.76    24
# 厚底人字拖全部  wedge flip flop               3125   19    9.98   16.99     1
# 全部黑色款式女款 black flip flops for women   18866   51   26.54   32.98     2
# 平底       woman flip flops              4015   29   15.38   15.99     1
# 厚底人字拖全部  platform flip flops          23290   71   27.10   16.99     1
#          wedge sandals                 7375   19    9.95    0.00     0
#
#                                      性价比(总销售额/花费)
# 广告组名称    客户搜索词
# 蓝色       blue flip flops                    14.15
# 自投       white flip flops for women          9.17
# Others   havanas flip flops women            5.24
#          havaianas women                     5.22
#          flip flops for women                4.59
# 斑点狗      havianas womens flip flops          4.55
# 平底       flip flops women                    3.93
# 厚底人字拖全部  womens wedge flip flops             3.46
#          wedge flip flops                    2.91
#          wedge flip flops for women          2.79
# 平底       flip flops for women                2.51
#          womens flip flops                   2.26
# 自投       havaianas women                     2.17
# 平底       women flip flops                    2.13
# 斑点狗      havaianas flip flops women          2.07
# 厚底人字拖全部  wedge flip flop                     1.70
# 全部黑色款式女款 black flip flops for women          1.24
# 平底       woman flip flops                    1.04
# 厚底人字拖全部  platform flip flops                 0.63
#          wedge sandals                       0.00

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的客户搜索词和广告组。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
