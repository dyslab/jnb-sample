# %% [markdown]
# Doc title: **Amazon FBA Inventory Event Detail Report**
#
# Article notes: Data came from 'Reports/Fulfillment/Inventory Event Detail Report' @Amazon Seller Central. Certain columns(e.g. fnskn, product-name) have been sterilized and removed.
#
# 文章备注：亚马逊后台FBA库存动作详情报告分析。其中一些列（如：fnsku, product-name）已删除。
#
# Last modified date: 2019-09-15 03:28:31

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，2019年6月份数据
workdf = pd.read_csv('data/amz_fba_inventory_details_us_201907-201908.csv')

# %% [markdown]
# # 操作类型统计

# %%
workdf.groupby(['transaction-type']).sum().sort_index()
# Out:
#                   quantity
# transaction-type
# Adjustments             -3
# CustomerReturns        554
# Receipts              6447
# Shipments            -5366
# VendorReturns          -39
# WhseTransfers          -13

# %% [markdown]
# # FBA仓库统计

# %%
targetdf = workdf.groupby(['fulfillment-center-id']).sum().sort_index()

print('商品出入库涉及FBA仓库数： {} 个。'.format(int(targetdf.count())))

targetdf
# Out:
# 商品出入库涉及FBA仓库数： 56 个。
#                        quantity
# fulfillment-center-id
# ABE2                          2
# ABE3                       1366
# ABE4                          0
# ACY1                        -10
# BDL2                          0
# BNA2                          0
# BNA3                        -41
# BUF9                          0
# BWI2                         -1
# CAE1                          0
# CHA1                         10
# CLE2                          0
# CMH1                          1
# DCA1                        -14
# DFW7                          0
# EWR4                         -3
# EWR9                         -1
# FTW6                         -1
# HIO9                          0
# IND1                         35
# IND4                       2485
# IND8                         -2
# JAX3                          0
# JFK8                        -13
# LAS2                          0
# LAS7                          2
# LEX1                          0
# ...

# %% [markdown]
# [返回目录](amz_fba_inventory_catalog.ipynb)
