# %% [markdown]
# Doc title: **Amazon Advertising Targeting Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Targeting Report' @Amazon Seller Central.
#
# 文章备注：亚马逊后台广告目标投放报告分析
#
# Last modified date: 2019-11-03 20:22:10

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_target_us_201910.xlsx', usecols=['广告活动名称', '广告组名称', '匹配类型', '投放', '展现量', '点击量', '花费', '7天总订单数(#)', '7天总销售额(￥)', '7天总销售量(#)'])

# %% [markdown]
# # 广告组数据排序（以销量为取值标准）

# %%
# Manipulating data and column names.
impr_df = workdf.groupby(['广告活动名称', '广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False).head(20)
impr_df['总销售额'] = impr_df['7天总销售额(￥)']
impr_df['总销售量'] = impr_df['7天总销售量(#)']
impr_df = impr_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
impr_df['点击率'] = round((impr_df['点击量'] / impr_df['展现量'] * 100), 2)
impr_df['卖出1件商品的平均花费'] = round(impr_df['花费'] / impr_df['总销售量'], 2)

impr_df.sort_values(by=['卖出1件商品的平均花费'])
# Out:
#                                                            展现量   点击量      花费  \
# 广告活动名称                                    广告组名称
# 颜色分类                                      紫色拖鞋            2169     7    3.76
#                                           黄色人字拖            770    15    5.91
# 童鞋自动                                      童鞋             20892    36    6.50
# 类似展示测试                                    0701、0731       9302    31   10.15
# Stranded Product Ad Promotion             FBA Instock    77496   162   51.25
# Advertise Top 0731、0701 Items - Hotmarzz  Others        392478   826  238.22
# Advertise 0722、0742Low Traffic - Hotmarzz Others        274562   528  138.57
# 手投                                        白色系列           11937    44   22.91
# Advertise Catalog38.24 - Hotmarzz         Others        184366   371  124.69
# 颜色分类                                      蓝色              9445    54   29.01
# havaianas测试                               斑点狗           226631   766  332.58
# 自投                                        自投           1288029  1795  742.10
# 男款鞋                                       全部男款           34096   168   46.98
# 男款手投                                      全部款            34136    52   27.69
# Advertise New0739 Products - Hotmarzz     Others        192581   452  133.98
# 0701测试                                    0731           15785    84   53.64
# 厚底人字拖                                     厚底人字拖全部       161401   595  269.98
# 0701测试                                    平底            392054   614  595.19
# 颜色分类                                      全部黑色款式女款       53256   101   56.31
# 手投                                        女款平底          130480   197   84.25
#
#                                                           总销售额  总销售量   点击率  \
# 广告活动名称                                    广告组名称
# 颜色分类                                      紫色拖鞋          109.93     7  0.32
#                                           黄色人字拖          57.96     4  1.95
# 童鞋自动                                      童鞋             55.96     4  0.17
# 类似展示测试                                    0701、0731      62.96     4  0.33
# Stranded Product Ad Promotion             FBA Instock   317.80    20  0.21
# Advertise Top 0731、0701 Items - Hotmarzz  Others       1410.10    90  0.21
# Advertise 0722、0742Low Traffic - Hotmarzz Others        841.49    51  0.19
# 手投                                        白色系列          131.92     8  0.37
# Advertise Catalog38.24 - Hotmarzz         Others        680.57    43  0.20
# 颜色分类                                      蓝色            147.91     9  0.57
# havaianas测试                               斑点狗          1568.03    97  0.34
# 自投                                        自投           3130.04   196  0.14
# 男款鞋                                       全部男款          186.88    12  0.49
# 男款手投                                      全部款           108.93     7  0.15
# Advertise New0739 Products - Hotmarzz     Others        466.72    28  0.23
# 0701测试                                    0731          169.90    10  0.53
# 厚底人字拖                                     厚底人字拖全部       785.53    47  0.37
# 0701测试                                    平底           1301.16    84  0.16
# 颜色分类                                      全部黑色款式女款      105.93     7  0.19
# 手投                                        女款平底          111.93     7  0.15
#
#                                                        卖出1件商品的平均花费
# 广告活动名称                                    广告组名称
# 颜色分类                                      紫色拖鞋                0.54
#                                           黄色人字拖               1.48
# 童鞋自动                                      童鞋                  1.63
# 类似展示测试                                    0701、0731           2.54
# Stranded Product Ad Promotion             FBA Instock         2.56
# Advertise Top 0731、0701 Items - Hotmarzz  Others              2.65
# Advertise 0722、0742Low Traffic - Hotmarzz Others              2.72
# 手投                                        白色系列                2.86
# Advertise Catalog38.24 - Hotmarzz         Others              2.90
# 颜色分类                                      蓝色                  3.22
# havaianas测试                               斑点狗                 3.43
# 自投                                        自投                  3.79
# 男款鞋                                       全部男款                3.91
# 男款手投                                      全部款                 3.96
# Advertise New0739 Products - Hotmarzz     Others              4.78
# 0701测试                                    0731                5.36
# 厚底人字拖                                     厚底人字拖全部             5.74
# 0701测试                                    平底                  7.09
# 颜色分类                                      全部黑色款式女款            8.04
# 手投                                        女款平底               12.04

# %% [markdown]
# 此表解决的问题为：
#
# - 找出销量最高的广告组。
#
# - 找出最具性价比的广告组。（卖出1件商品花费越小，则性价比越高）

# %% [markdown]
# # 投放数据排序（以展现量为取值标准）

# %%
# Manipulating data and column names.
target_df = workdf.groupby(['广告组名称', '匹配类型', '投放']).sum().sort_values(by=['展现量'], ascending=False).head(20)
target_df['总销售额'] = target_df['7天总销售额(￥)']
target_df['总销售量'] = target_df['7天总销售量(#)']
target_df = target_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
target_df['性价比(总销售额/花费)'] = round(target_df['总销售额'] / target_df['花费'], 2)

target_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                                                    展现量   点击量      花费     总销售额  \
# 广告组名称       匹配类型   投放
# 童鞋          -      substitutes                   17427    28    4.97    55.96
# FBA Instock -      close-match                   30512    98   34.81   283.82
#                    loose-match                   23075    28    5.78    33.98
# 斑点狗         EXACT  havianas womens flip flops    47398   241  102.93   563.65
# Others      BROAD  *                           1043987  2177  635.46  3398.88
# 自投          BROAD  *                           1288029  1795  742.10  3130.04
# 斑点狗         EXACT  havaianas flip flops women   150583   433  198.26   809.50
# 全部男款        BROAD  *                             34096   168   46.98   186.88
# 厚底人字拖全部     EXACT  wedge flip flops for women    45414   245  112.99   434.74
# 全部黑色款式女款    EXACT  black flips flops womens      17942    36   19.07    60.96
# 厚底人字拖全部     EXACT  wedge flip flop               29302   110   57.38   165.90
#                    Platform Flip Flops           29984   121   48.97   116.93
# 平底          EXACT  women's flip flops           105148   148  139.17   308.80
#                    flip flop for women          283915   448  446.51   963.38
# 女款平底        BROAD  flip flops womens             81255   100   44.25    80.95
#                    womens flip flops             24510    50   18.09    30.98
# 全部黑色款式女款    EXACT  black flip flops for women    26245    41   28.42    29.98
# FBA Instock -      substitutes                   23871    36   10.66     0.00
# 女款平底        PHRASE flip flops size               15638    27   14.12     0.00
# 厚底人字拖全部     EXACT  wedge sandals                 14965    14    6.33     0.00
#
#                                                总销售量  性价比(总销售额/花费)
# 广告组名称       匹配类型   投放
# 童鞋          -      substitutes                    4         11.26
# FBA Instock -      close-match                   18          8.15
#                    loose-match                    2          5.88
# 斑点狗         EXACT  havianas womens flip flops    35          5.48
# Others      BROAD  *                            212          5.35
# 自投          BROAD  *                            196          4.22
# 斑点狗         EXACT  havaianas flip flops women    50          4.08
# 全部男款        BROAD  *                             12          3.98
# 厚底人字拖全部     EXACT  wedge flip flops for women    26          3.85
# 全部黑色款式女款    EXACT  black flips flops womens       4          3.20
# 厚底人字拖全部     EXACT  wedge flip flop               10          2.89
#                    Platform Flip Flops            7          2.39
# 平底          EXACT  women's flip flops            20          2.22
#                    flip flop for women           62          2.16
# 女款平底        BROAD  flip flops womens              5          1.83
#                    womens flip flops              2          1.71
# 全部黑色款式女款    EXACT  black flip flops for women     2          1.05
# FBA Instock -      substitutes                    0          0.00
# 女款平底        PHRASE flip flops size                0          0.00
# 厚底人字拖全部     EXACT  wedge sandals                  0          0.00

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的投放项目。

# %% [markdown]
# # 性价比最高的Top 10广告组与全部广告组数据对比

# %% [markdown]
# *注：在某一项目组每投入1美元带来的销售额回报越高，则其性价比越高。*

# %% [markdown]
# ## Top 10广告组

# %%
# Top 10 Ads.
top10_df = workdf.groupby(['广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False)
top10_df['总销售额'] = top10_df['7天总销售额(￥)']
top10_df['性价比'] = round(top10_df['总销售额'] / top10_df['花费'], 2)
top10_df = top10_df[['展现量', '点击量', '花费', '总销售额', '性价比']].sort_values(by=['性价比'], ascending=False).head(10)

print('Top 10 广告组\n')

top10_df
# Out:
# Top 10 广告组
#                  展现量   点击量      花费     总销售额    性价比
# 广告组名称
# 紫色拖鞋            2169     7    3.76   109.93  29.24
# 红色              2622     3    1.49    30.98  20.79
# 粉色款式            2259    10    4.69    48.97  10.44
# 黄色人字拖            770    15    5.91    57.96   9.81
# 童鞋             20892    36    6.50    55.96   8.61
# 0701、0731       9302    31   10.15    62.96   6.20
# FBA Instock    77496   162   51.25   317.80   6.20
# 白色系列           11937    44   22.91   131.92   5.76
# Others       1043987  2177  635.46  3398.88   5.35
# 蓝色              9445    54   29.01   147.91   5.10

# %% [markdown]
# ## 数据对比

# %%
total_ds = workdf.sum()
top10_ds = top10_df.sum()

print('结论：')
print('\nTop 10广告组花费为：{0:.2f}美元； 全部广告组花费为：{1:.2f}美元； Top 10广告组占比：{2:.2f}%'.format(top10_ds['花费'], total_ds['花费'], top10_ds['花费'] / total_ds['花费'] * 100))
print('\nTop 10广告组共销售：{0:.2f}美元； 全部广告组共销售：{1:.2f}美元； Top 10广告组占比：{2:.2f}%'.format(top10_ds['总销售额'], total_ds['7天总销售额(￥)'], top10_ds['总销售额'] / total_ds['7天总销售额(￥)'] * 100))
# Out:
# 结论：
#
# Top 10广告组花费为：771.13美元； 全部广告组花费为：3011.07美元； Top 10广告组占比：25.61%
#
# Top 10广告组共销售：4363.27美元； 全部广告组共销售：11831.60美元； Top 10广告组占比：36.88%

# %% [markdown]
# # 产品广告活动订单率情况

# %%
target_df = workdf.groupby(['广告活动名称']).sum().head(20)
target_df['总订单量'] = target_df['7天总订单数(#)']
target_df['订单率'] = round(target_df['总订单量'] / target_df['点击量'] * 100, 2)

target_df[['展现量', '点击量', '总订单量', '订单率']].sort_values(by=['订单率'], ascending=False).fillna(0)
# Out:
#                                                展现量   点击量  总订单量    订单率
# 广告活动名称
# 颜色分类                                         70521   190    31  16.32
# 男款手投                                         34136    52     7  13.46
# 0701测试                                      408551   701    92  13.12
# 类似展示测试                                        9302    31     4  12.90
# havaianas测试                                 226631   766    97  12.66
# Stranded Product Ad Promotion                77496   162    20  12.35
# 童鞋自动                                         20892    36     4  11.11
# Advertise Catalog38.24 - Hotmarzz           184366   371    41  11.05
# 自投                                         1288029  1795   196  10.92
# Advertise Top 0731、0701 Items - Hotmarzz    392478   826    81   9.81
# Advertise 0722、0742Low Traffic - Hotmarzz   274562   528    51   9.66
# 厚底人字拖                                       161401   595    47   7.90
# 男款鞋                                          34096   168    12   7.14
# Advertise New0739 Products - Hotmarzz       192581   452    28   6.19
# 手投                                          145592   261    15   5.75
# 棉拖                                            7318    18     0   0.00
# 棉拖2                                            946     0     0   0.00

# %% [markdown]
# *注：订单率 = 订单量 / 点击量*
#
# 此表解决的问题为：
#
# - 了解产品广告活动的订单率情况。品牌广告的相关情况可见 **[amz_ads_brand.ipynb](amz_ads_brand.ipynb)** 的相关部分说明。

# %% [markdown]
# # 产品广告组订单率情况

# %%
target_df = workdf.groupby(['广告组名称']).sum().head(20)
target_df['总订单量'] = target_df['7天总订单数(#)']
target_df['订单率'] = round(target_df['总订单量'] / target_df['点击量'] * 100, 2)

target_df[['展现量', '点击量', '总订单量', '订单率']].sort_values(by=['订单率'], ascending=False).fillna(0)
# Out:
#                    展现量   点击量  总订单量     订单率
# 广告组名称
# 紫色拖鞋              2169     7     7  100.00
# 红色                2622     3     2   66.67
# 粉色款式              2259    10     3   30.00
# 白色系列             11937    44     8   18.18
# 全部款              34136    52     7   13.46
# 平底              392054   614    82   13.36
# 0701、0731         9302    31     4   12.90
# 斑点狗             226631   766    97   12.66
# FBA Instock      77496   162    20   12.35
# 0731             15785    84    10   11.90
# 童鞋               20892    36     4   11.11
# Others         1043987  2177   201    9.23
# 厚底人字拖全部         161401   595    47    7.90
# 全部男款             34096   168    12    7.14
# 全部黑色款式女款         53256   101     7    6.93
# 女款平底            130480   197     7    3.55
# girls sandals      339     2     0    0.00
# 棉拖0505            7318    18     0    0.00
# asin广告             373     1     0    0.00
# 棉拖                 946     0     0    0.00

# %% [markdown]
# *注：订单率 = 订单量 / 点击量*
#
# 此表解决的问题为：
#
# - 了解产品广告组的订单率情况。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
