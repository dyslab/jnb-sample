# %% [markdown]
# Doc title: **Amazon Advertising Targeting Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Targeting Report' @Amazon Seller Central.
#
# 文章备注：亚马逊后台广告目标投放报告分析
#
# Last modified date: 2019-12-05 16:33:04

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_target_us_201911.xlsx', usecols=['广告活动名称', '广告组名称', '匹配类型', '投放', '展现量', '点击量', '花费', '7天总订单数(#)', '7天总销售额(￥)', '7天总销售量(#)'])

# %% [markdown]
# # 广告组数据排序（以销量为取值标准）

# %%
# Manipulating data and column names.
impr_df = workdf.groupby(['广告活动名称', '广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False).head(20)
impr_df['总销售额'] = impr_df['7天总销售额(￥)']
impr_df['总销售量'] = impr_df['7天总销售量(#)']
impr_df = impr_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
impr_df['点击率'] = round((impr_df['点击量'] / impr_df['展现量'] * 100), 2)
impr_df['卖出1件商品的平均花费'] = round(impr_df['花费'] / impr_df['总销售量'], 2)

impr_df.sort_values(by=['卖出1件商品的平均花费'])
# Out:
#                                                          展现量   点击量      花费  \
# 广告活动名称                                    广告组名称
# Advertise Top 0731、0701 Items - Hotmarzz  Others      577699  1000  289.89
# 男款鞋                                       全部男款         31293   100   23.32
# Advertise New0739 Products - Hotmarzz     Others      213480   425  123.48
# 颜色分类                                      蓝色           16921    47   23.77
# 自投                                        自投         1053489  1352  366.28
# Advertise 0722、0742Low Traffic - Hotmarzz Others      291520   513  115.10
# 男款手投                                      全部款          16636    38   11.29
# Advertise Catalog38.24 - Hotmarzz         Others      217404   364  114.67
# 童鞋自动                                      童鞋           51338    78   16.93
# 0701测试                                    0731          7449    60   25.48
# havaianas测试                               斑点狗         206571   673  300.51
# 0701测试                                    平底          300064   547  425.53
# 手投                                        黑色厚底          3943    13    6.05
#                                           白色系列          5687    32   12.37
# 厚底人字拖                                     厚底人字拖全部     140313   477  205.91
# 颜色分类                                      粉色款式          3475    16    7.11
#                                           全部黑色款式女款     34671    67   34.40
# 0701测试                                    asin广告         458     1    0.23
# 类似展示测试                                    0701、0731     3883     9    2.32
# 颜色分类                                      紫色拖鞋          2452     5    3.65
#
#                                                         总销售额  总销售量   点击率  \
# 广告活动名称                                    广告组名称
# Advertise Top 0731、0701 Items - Hotmarzz  Others     1716.88   112  0.17
# 男款鞋                                       全部男款        138.91     9  0.32
# Advertise New0739 Products - Hotmarzz     Others      748.54    46  0.20
# 颜色分类                                      蓝色          127.92     8  0.28
# 自投                                        自投         1740.92   108  0.13
# Advertise 0722、0742Low Traffic - Hotmarzz Others      501.69    31  0.18
# 男款手投                                      全部款          43.97     3  0.23
# Advertise Catalog38.24 - Hotmarzz         Others      456.71    29  0.17
# 童鞋自动                                      童鞋           57.96     4  0.15
# 0701测试                                    0731         99.94     6  0.81
# havaianas测试                               斑点狗         921.43    57  0.33
# 0701测试                                    平底         1103.29    71  0.18
# 手投                                        黑色厚底         16.99     1  0.33
#                                           白色系列         33.98     2  0.56
# 厚底人字拖                                     厚底人字拖全部     490.71    29  0.34
# 颜色分类                                      粉色款式         15.99     1  0.46
#                                           全部黑色款式女款     32.98     2  0.19
# 0701测试                                    asin广告        0.00     0  0.22
# 类似展示测试                                    0701、0731     0.00     0  0.23
# 颜色分类                                      紫色拖鞋          0.00     0  0.20
#
#                                                      卖出1件商品的平均花费
# 广告活动名称                                    广告组名称
# Advertise Top 0731、0701 Items - Hotmarzz  Others            2.59
# 男款鞋                                       全部男款              2.59
# Advertise New0739 Products - Hotmarzz     Others            2.68
# 颜色分类                                      蓝色                2.97
# 自投                                        自投                3.39
# Advertise 0722、0742Low Traffic - Hotmarzz Others            3.71
# 男款手投                                      全部款               3.76
# Advertise Catalog38.24 - Hotmarzz         Others            3.95
# 童鞋自动                                      童鞋                4.23
# 0701测试                                    0731              4.25
# havaianas测试                               斑点狗               5.27
# 0701测试                                    平底                5.99
# 手投                                        黑色厚底              6.05
#                                           白色系列              6.18
# 厚底人字拖                                     厚底人字拖全部           7.10
# 颜色分类                                      粉色款式              7.11
#                                           全部黑色款式女款         17.20
# 0701测试                                    asin广告             inf
# 类似展示测试                                    0701、0731          inf
# 颜色分类                                      紫色拖鞋               inf

# %% [markdown]
# 此表解决的问题为：
#
# - 找出销量最高的广告组。
#
# - 找出最具性价比的广告组。（卖出1件商品花费越小，则性价比越高）

# %% [markdown]
# # 投放数据排序（以展现量为取值标准）

# %%
# Manipulating data and column names.
target_df = workdf.groupby(['广告组名称', '匹配类型', '投放']).sum().sort_values(by=['展现量'], ascending=False).head(20)
target_df['总销售额'] = target_df['7天总销售额(￥)']
target_df['总销售量'] = target_df['7天总销售量(#)']
target_df = target_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
target_df['性价比(总销售额/花费)'] = round(target_df['总销售额'] / target_df['花费'], 2)

target_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                                                展现量   点击量      花费     总销售额  \
# 广告组名称    匹配类型  投放
# 蓝色       EXACT blue flip flops                8992    19    8.88   112.93
# 厚底人字拖全部  EXACT flip flop wedges               5294    13    6.90    67.96
# 童鞋       -     loose-match                    5057     8    2.23    13.99
# 全部男款     BROAD *                             31293   100   23.32   138.91
# Others   BROAD *                           1300103  2302  643.14  3423.82
# 自投       BROAD *                           1053489  1352  366.28  1740.92
# 斑点狗      EXACT havianas womens flip flops    56817   228   93.83   422.74
#                ipanema sandals for women      6854     9    3.56    15.99
# 厚底人字拖全部  EXACT wedge flip flops for women    38550   172   75.67   202.88
# 平底       EXACT flip flop for women          223338   381  307.38   815.47
# 厚底人字拖全部  EXACT womens wedge flip flops        4278    38   13.20    33.98
#                wedge flip flop               28927   111   52.87   134.92
# 童鞋       -     substitutes                   44913    66   13.88    28.98
# 斑点狗      EXACT havaianas flip flops women   126171   391  190.61   387.76
# 平底       EXACT women's flip flops            73774   146  110.23   210.87
# 全部黑色款式女款 EXACT black flips flops womens      28775    58   30.36    32.98
# 厚底人字拖全部  EXACT Platform Flip Flops           28089    80   30.79    16.99
#                wedge sandals                 16338    21   10.25     0.00
#                guess shoes women              5427     4    1.02     0.00
# 全部款      EXACT sanuk mens flip flops          4854     3    1.52     0.00
#
#                                            总销售量  性价比(总销售额/花费)
# 广告组名称    匹配类型  投放
# 蓝色       EXACT blue flip flops                7         12.72
# 厚底人字拖全部  EXACT flip flop wedges               4          9.85
# 童鞋       -     loose-match                    1          6.27
# 全部男款     BROAD *                              9          5.96
# Others   BROAD *                            218          5.32
# 自投       BROAD *                            108          4.75
# 斑点狗      EXACT havianas womens flip flops    26          4.51
#                ipanema sandals for women      1          4.49
# 厚底人字拖全部  EXACT wedge flip flops for women    12          2.68
# 平底       EXACT flip flop for women           53          2.65
# 厚底人字拖全部  EXACT womens wedge flip flops        2          2.57
#                wedge flip flop                8          2.55
# 童鞋       -     substitutes                    2          2.09
# 斑点狗      EXACT havaianas flip flops women    24          2.03
# 平底       EXACT women's flip flops            13          1.91
# 全部黑色款式女款 EXACT black flips flops womens       2          1.09
# 厚底人字拖全部  EXACT Platform Flip Flops            1          0.55
#                wedge sandals                  0          0.00
#                guess shoes women              0          0.00
# 全部款      EXACT sanuk mens flip flops          0          0.00

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的投放项目。

# %% [markdown]
# # 性价比最高的Top 10广告组与全部广告组数据对比

# %% [markdown]
# *注：在某一项目组每投入1美元带来的销售额回报越高，则其性价比越高。*

# %% [markdown]
# ## Top 10广告组

# %%
# Top 10 Ads.
top10_df = workdf.groupby(['广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False)
top10_df['总销售额'] = top10_df['7天总销售额(￥)']
top10_df['性价比'] = round(top10_df['总销售额'] / top10_df['花费'], 2)
top10_df = top10_df[['展现量', '点击量', '花费', '总销售额', '性价比']].sort_values(by=['性价比'], ascending=False).head(10)

print('Top 10 广告组\n')

top10_df
# Out:
# Top 10 广告组
#             展现量   点击量      花费     总销售额   性价比
# 广告组名称
# 全部男款      31293   100   23.32   138.91  5.96
# 蓝色        16921    47   23.77   127.92  5.38
# Others  1300103  2302  643.14  3423.82  5.32
# 自投      1053489  1352  366.28  1740.92  4.75
# 0731       7449    60   25.48    99.94  3.92
# 全部款       16636    38   11.29    43.97  3.89
# 童鞋        51338    78   16.93    57.96  3.42
# 斑点狗      206571   673  300.51   921.43  3.07
# 黑色厚底       3943    13    6.05    16.99  2.81
# 白色系列       5687    32   12.37    33.98  2.75

# %% [markdown]
# ## 数据对比

# %%
total_ds = workdf.sum()
top10_ds = top10_df.sum()

print('结论：')
print('\nTop 10广告组花费为：{0:.2f}美元； 全部广告组花费为：{1:.2f}美元； Top 10广告组占比：{2:.2f}%'.format(top10_ds['花费'], total_ds['花费'], top10_ds['花费'] / total_ds['花费'] * 100))
print('\nTop 10广告组共销售：{0:.2f}美元； 全部广告组共销售：{1:.2f}美元； Top 10广告组占比：{2:.2f}%'.format(top10_ds['总销售额'], total_ds['7天总销售额(￥)'], top10_ds['总销售额'] / total_ds['7天总销售额(￥)'] * 100))
# Out:
# 结论：
#
# Top 10广告组花费为：1429.14美元； 全部广告组花费为：2112.80美元； Top 10广告组占比：67.64%
#
# Top 10广告组共销售：6605.84美元； 全部广告组共销售：8248.81美元； Top 10广告组占比：80.08%

# %% [markdown]
# # 产品广告活动订单率情况

# %%
target_df = workdf.groupby(['广告活动名称']).sum().head(20)
target_df['总订单量'] = target_df['7天总订单数(#)']
target_df['订单率'] = round(target_df['总订单量'] / target_df['点击量'] * 100, 2)

target_df[['展现量', '点击量', '总订单量', '订单率']].sort_values(by=['订单率'], ascending=False).fillna(0)
# Out:
#                                                展现量   点击量  总订单量    订单率
# 广告活动名称
# 0701测试                                      308362   608    77  12.66
# Advertise New0739 Products - Hotmarzz       213480   425    46  10.82
# Advertise Top 0731、0701 Items - Hotmarzz    577699  1000   106  10.60
# havaianas测试                                 206571   673    57   8.47
# 男款鞋                                          31293   100     8   8.00
# 自投                                         1053489  1352   108   7.99
# Advertise Catalog38.24 - Hotmarzz           217404   364    29   7.97
# 男款手投                                         16636    38     3   7.89
# 颜色分类                                         62367   146    11   7.53
# 手投                                            9630    45     3   6.67
# 厚底人字拖                                       140313   477    29   6.08
# Advertise 0722、0742Low Traffic - Hotmarzz   291520   513    31   6.04
# 童鞋自动                                         51338    78     4   5.13
# 类似展示测试                                        3883     9     0   0.00

# %% [markdown]
# *注：订单率 = 订单量 / 点击量*
#
# 此表解决的问题为：
#
# - 了解产品广告活动的订单率情况。品牌广告的相关情况可见 **[amz_ads_brand.ipynb](amz_ads_brand.ipynb)** 的相关部分说明。

# %% [markdown]
# # 产品广告组订单率情况

# %%
target_df = workdf.groupby(['广告组名称']).sum().head(20)
target_df['总订单量'] = target_df['7天总订单数(#)']
target_df['订单率'] = round(target_df['总订单量'] / target_df['点击量'] * 100, 2)

target_df[['展现量', '点击量', '总订单量', '订单率']].sort_values(by=['订单率'], ascending=False).fillna(0)
# Out:
#                    展现量   点击量  总订单量    订单率
# 广告组名称
# 蓝色               16921    47     8  17.02
# 平底              300064   547    71  12.98
# 0731              7449    60     6  10.00
# Others         1300103  2302   212   9.21
# 斑点狗             206571   673    57   8.47
# 全部男款             31293   100     8   8.00
# 自投             1053489  1352   108   7.99
# 全部款              16636    38     3   7.89
# 黑色厚底              3943    13     1   7.69
# 白色系列              5687    32     2   6.25
# 粉色款式              3475    16     1   6.25
# 厚底人字拖全部         140313   477    29   6.08
# 童鞋               51338    78     4   5.13
# 全部黑色款式女款         34671    67     2   2.99
# 紫色拖鞋              2452     5     0   0.00
# 红色                3312     6     0   0.00
# asin广告             458     1     0   0.00
# 黄色人字拖             1536     5     0   0.00
# 0701、0731         3883     9     0   0.00
# girls sandals      391     0     0   0.00

# %% [markdown]
# *注：订单率 = 订单量 / 点击量*
#
# 此表解决的问题为：
#
# - 了解产品广告组的订单率情况。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
