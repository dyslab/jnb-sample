# %% [markdown]
# Doc title: **Amazon Advertising Targeting Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Targeting Report' @Amazon Seller Central.
#
# 文章备注：亚马逊后台广告目标投放报告分析
#
# Last modified date: 2019-08-05 04:45:48

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_target_us_201907.xlsx', usecols=['广告活动名称', '广告组名称', '匹配类型', '投放', '展现量', '点击量', '花费', '7天总订单数(#)', '7天总销售额(￥)', '7天总销售量(#)'])

# %% [markdown]
# # 广告组数据排序（以销量为取值标准）

# %%
# Manipulating data and column names.
impr_df = workdf.groupby(['广告活动名称', '广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False).head(20)
impr_df['总销售额'] = impr_df['7天总销售额(￥)']
impr_df['总销售量'] = impr_df['7天总销售量(#)']
impr_df = impr_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
impr_df['点击率'] = round((impr_df['点击量'] / impr_df['展现量'] * 100), 2)
impr_df['卖出1件商品的平均花费'] = round(impr_df['花费'] / impr_df['总销售量'], 2)

impr_df.sort_values(by=['卖出1件商品的平均花费'])
# Out:
#                                                               展现量   点击量  \
# 广告活动名称                                       广告组名称
# 手投                                           黑色厚底            3501    17
# Advertise Long Term Storage Items - Hotmarzz 0706          137476   219
# Advertise 0722、0742Low Traffic - Hotmarzz    Others        728360  2032
# 童鞋自动                                         童鞋             89019   175
# Advertise Long Term Storage Items - Hotmarzz Others        163949   418
# 手投                                           纯色系列           21986   157
#                                              女款平底纯色        231700   578
# Advertise Top 0731、0701 Items - Hotmarzz     Others        547227  1878
# 男款鞋                                          全部男款          163355   484
# 黑色纯色女款                                       全部黑色款式女款       53448   136
# 自投                                           自投           2145392  7932
# Advertise Catalog38.24 - Hotmarzz            Others        790506  1259
# havaianas测试                                  斑点狗           495377  1386
# Advertise New0739 Products - Hotmarzz        Others        616652   728
# Stranded Product Ad Promotion                FBA Instock   828422   932
# 男款手投                                         全部款            64404   146
# 厚底人字拖                                        厚底人字拖全部       147399   660
# Advertise Long Term Storage Items - Hotmarzz 0701-粉        501096   855
# 0701测试                                       0731          166504   923
#                                              0701          284581   690
#
#                                                                花费     总销售额  \
# 广告活动名称                                       广告组名称
# 手投                                           黑色厚底            7.09    67.96
# Advertise Long Term Storage Items - Hotmarzz 0706           74.99   503.68
# Advertise 0722、0742Low Traffic - Hotmarzz    Others        579.40  3411.92
# 童鞋自动                                         童鞋             48.86   253.83
# Advertise Long Term Storage Items - Hotmarzz Others        126.93   731.56
# 手投                                           纯色系列           84.54   442.72
#                                              女款平底纯色        196.89   960.39
# Advertise Top 0731、0701 Items - Hotmarzz     Others        588.62  2762.27
# 男款鞋                                          全部男款          153.06   669.57
# 黑色纯色女款                                       全部黑色款式女款       84.82   358.77
# 自投                                           自投           2410.01  9445.20
# Advertise Catalog38.24 - Hotmarzz            Others        461.57  1712.91
# havaianas测试                                  斑点狗           459.34  1732.93
# Advertise New0739 Products - Hotmarzz        Others        279.33   978.37
# Stranded Product Ad Promotion                FBA Instock   329.16  1092.30
# 男款手投                                         全部款            66.53   204.87
# 厚底人字拖                                        厚底人字拖全部       239.66   767.54
# Advertise Long Term Storage Items - Hotmarzz 0701-粉        361.79   866.42
# 0701测试                                       0731          491.37  1200.30
#                                              0701          651.07   954.37
#
#                                                           总销售量   点击率  \
# 广告活动名称                                       广告组名称
# 手投                                           黑色厚底            4  0.49
# Advertise Long Term Storage Items - Hotmarzz 0706           32  0.16
# Advertise 0722、0742Low Traffic - Hotmarzz    Others        209  0.28
# 童鞋自动                                         童鞋             17  0.20
# Advertise Long Term Storage Items - Hotmarzz Others         44  0.25
# 手投                                           纯色系列           28  0.71
#                                              女款平底纯色         61  0.25
# Advertise Top 0731、0701 Items - Hotmarzz     Others        173  0.34
# 男款鞋                                          全部男款           43  0.30
# 黑色纯色女款                                       全部黑色款式女款       23  0.25
# 自投                                           自投            581  0.37
# Advertise Catalog38.24 - Hotmarzz            Others        109  0.16
# havaianas测试                                  斑点狗           107  0.28
# Advertise New0739 Products - Hotmarzz        Others         63  0.12
# Stranded Product Ad Promotion                FBA Instock    70  0.11
# 男款手投                                         全部款            13  0.23
# 厚底人字拖                                        厚底人字拖全部        46  0.45
# Advertise Long Term Storage Items - Hotmarzz 0701-粉         59  0.17
# 0701测试                                       0731           70  0.55
#                                              0701           63  0.24
#
#                                                           卖出1件商品的平均花费
# 广告活动名称                                       广告组名称
# 手投                                           黑色厚底                1.77
# Advertise Long Term Storage Items - Hotmarzz 0706                2.34
# Advertise 0722、0742Low Traffic - Hotmarzz    Others              2.77
# 童鞋自动                                         童鞋                  2.87
# Advertise Long Term Storage Items - Hotmarzz Others              2.88
# 手投                                           纯色系列                3.02
#                                              女款平底纯色              3.23
# Advertise Top 0731、0701 Items - Hotmarzz     Others              3.40
# 男款鞋                                          全部男款                3.56
# 黑色纯色女款                                       全部黑色款式女款            3.69
# 自投                                           自投                  4.15
# Advertise Catalog38.24 - Hotmarzz            Others              4.23
# havaianas测试                                  斑点狗                 4.29
# Advertise New0739 Products - Hotmarzz        Others              4.43
# Stranded Product Ad Promotion                FBA Instock         4.70
# 男款手投                                         全部款                 5.12
# 厚底人字拖                                        厚底人字拖全部             5.21
# Advertise Long Term Storage Items - Hotmarzz 0701-粉              6.13
# 0701测试                                       0731                7.02
#                                              0701               10.33

# %% [markdown]
# 此表解决的问题为：
#
# - 找出销量最高的广告组。
#
# - 找出最具性价比的广告组。（卖出1件商品花费越小，则性价比越高）

# %% [markdown]
# # 投放数据排序（以展现量为取值标准）

# %%
# Manipulating data and column names.
target_df = workdf.groupby(['广告组名称', '匹配类型', '投放']).sum().sort_values(by=['展现量'], ascending=False).head(20)
target_df['总销售额'] = target_df['7天总销售额(￥)']
target_df['总销售量'] = target_df['7天总销售量(#)']
target_df = target_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
target_df['性价比(总销售额/花费)'] = round(target_df['总销售额'] / target_df['花费'], 2)

target_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                                                        展现量   点击量       花费  \
# 广告组名称       匹配类型   投放
# 0706        -      loose-match                       60887   120    39.30
#                    substitutes                       60242    61    22.42
# 女款平底纯色      BROAD  womens flip flops                142411   379   120.91
# 童鞋          -      substitutes                       75405   130    32.87
# 斑点狗         BROAD  havaianas                        146729   382    84.24
# Others      BROAD  *                               2846694  6315  2035.85
# 全部男款        BROAD  *                                163355   484   153.06
# 全部黑色款式女款    EXACT  black flip flops for women        52597   131    82.90
# 斑点狗         EXACT  havaianas flip flops for women   200601   456   168.95
# 自投          BROAD  *                               2145392  7932  2410.01
# 女款平底纯色      PHRASE flip flops size                   46952   127    47.63
# FBA Instock -      loose-match                      123520   344   103.00
# 斑点狗         EXACT  havianas womens flip flops        45084   165    56.74
# 0701-粉      -      substitutes                      163715   149    55.66
# FBA Instock -      substitutes                      683109   514   202.16
# 0701-粉      -      loose-match                      158705   487   175.74
# 0731        EXACT  havaianas flip flops women        50510   406   208.41
# 0701-粉      -      close-match                      178676   219   130.39
# 0701        EXACT  flip flop for women              210546   514   530.54
# 0731        EXACT  flip flops for women              65294   120    84.78
#
#                                                       总销售额  总销售量  性价比(总销售额/花费)
# 广告组名称       匹配类型   投放
# 0706        -      loose-match                      344.78    22          8.77
#                    substitutes                      142.91     9          6.37
# 女款平底纯色      BROAD  womens flip flops                738.53    47          6.11
# 童鞋          -      substitutes                      161.89    11          4.93
# 斑点狗         BROAD  havaianas                        401.75    25          4.77
# Others      BROAD  *                               9597.03   598          4.71
# 全部男款        BROAD  *                                669.57    43          4.37
# 全部黑色款式女款    EXACT  black flip flops for women       358.77    23          4.33
# 斑点狗         EXACT  havaianas flip flops for women   672.58    42          3.98
# 自投          BROAD  *                               9445.20   581          3.92
# 女款平底纯色      PHRASE flip flops size                  174.89    11          3.67
# FBA Instock -      loose-match                      338.78    22          3.29
# 斑点狗         EXACT  havianas womens flip flops       184.89    11          3.26
# 0701-粉      -      substitutes                      178.88    13          3.21
# FBA Instock -      substitutes                      567.64    36          2.81
# 0701-粉      -      loose-match                      475.68    32          2.71
# 0731        EXACT  havaianas flip flops women       530.69    31          2.55
# 0701-粉      -      close-match                      211.86    14          1.62
# 0701        EXACT  flip flop for women              755.50    50          1.42
# 0731        EXACT  flip flops for women             117.93     7          1.39

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的投放项目。

# %% [markdown]
# # 性价比最高的Top 10广告组与全部广告组数据对比

# %% [markdown]
# *注：在某一项目组每投入1美元带来的销售额回报越高，则其性价比越高。*

# %% [markdown]
# ## Top 10广告组

# %%
# Top 10 Ads.
top10_df = workdf.groupby(['广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False)
top10_df['总销售额'] = top10_df['7天总销售额(￥)']
top10_df['性价比'] = round(top10_df['总销售额'] / top10_df['花费'], 2)
top10_df = top10_df[['展现量', '点击量', '花费', '总销售额', '性价比']].sort_values(by=['性价比'], ascending=False).head(10)

print('Top 10 广告组\n')

top10_df
# Out:
# Top 10 广告组
#               展现量   点击量       花费     总销售额   性价比
# 广告组名称
# 黑色厚底         3501    17     7.09    67.96  9.59
# 0706       137476   219    74.99   503.68  6.72
# 纯色系列        21986   157    84.54   442.72  5.24
# 童鞋          89019   175    48.86   253.83  5.20
# 女款平底纯色     231700   578   196.89   960.39  4.88
# Others    2846694  6315  2035.85  9597.03  4.71
# 全部男款       163355   484   153.06   669.57  4.37
# 全部黑色款式女款    53448   136    84.82   358.77  4.23
# 自投        2145392  7932  2410.01  9445.20  3.92
# 斑点狗        495377  1386   459.34  1732.93  3.77

# %% [markdown]
# ## 数据对比

# %%
total_ds = workdf.sum()
top10_ds = top10_df.sum()

print('结论：')
print('\nTop 10广告组花费为：{0:.2f}美元； 全部广告组花费为：{1:.2f}美元； Top 10广告组占比：{2:.2f}%'.format(top10_ds['花费'], total_ds['花费'], top10_ds['花费'] / total_ds['花费'] * 100))
print('\nTop 10广告组共销售：{0:.2f}美元； 全部广告组共销售：{1:.2f}美元； Top 10广告组占比：{2:.2f}%'.format(top10_ds['总销售额'], total_ds['7天总销售额(￥)'], top10_ds['总销售额'] / total_ds['7天总销售额(￥)'] * 100))
# Out:
# 结论：
#
# Top 10广告组花费为：5555.45美元； 全部广告组花费为：7708.70美元； Top 10广告组占比：72.07%
#
# Top 10广告组共销售：24032.08美元； 全部广告组共销售：29152.35美元； Top 10广告组占比：82.44%

# %% [markdown]
# # 产品广告活动订单率情况

# %%
target_df = workdf.groupby(['广告活动名称']).sum().head(20)
target_df['总订单量'] = target_df['7天总订单数(#)']
target_df['订单率'] = round(target_df['总订单量'] / target_df['点击量'] * 100, 2)

target_df[['展现量', '点击量', '总订单量', '订单率']].sort_values(by=['订单率'], ascending=False).fillna(0)
# Out:
#                                                   展现量   点击量  总订单量    订单率
# 广告活动名称
# 黑色纯色女款                                          53448   136    23  16.91
# 棉拖                                              23452    19     3  15.79
# 手投                                             257341   752    90  11.97
# Advertise 0722、0742Low Traffic - Hotmarzz      728360  2032   208  10.24
# 童鞋自动                                            89019   175    17   9.71
# Advertise Top 0731、0701 Items - Hotmarzz       547227  1878   171   9.11
# 男款手投                                            64404   146    13   8.90
# 男款鞋                                            163355   484    43   8.88
# Advertise Long Term Storage Items - Hotmarzz   802521  1492   131   8.78
# Advertise New0739 Products - Hotmarzz          616652   728    63   8.65
# Advertise Catalog38.24 - Hotmarzz              790506  1259   105   8.34
# 0701测试                                         456741  1620   133   8.21
# havaianas测试                                    495377  1386   107   7.72
# Stranded Product Ad Promotion                  828422   932    70   7.51
# 自投                                            2145392  7932   577   7.27
# 厚底人字拖                                          147399   660    46   6.97
# 捡漏                                                  3     0     0   0.00

# %% [markdown]
# *注：订单率 = 订单量 / 点击量*
#
# 此表解决的问题为：
#
# - 了解产品广告活动的订单率情况。品牌广告的相关情况可见 **[amz_ads_brand.ipynb](amz_ads_brand.ipynb)** 的相关部分说明。

# %% [markdown]
# # 产品广告组订单率情况

# %%
target_df = workdf.groupby(['广告组名称']).sum().head(20)
target_df['总订单量'] = target_df['7天总订单数(#)']
target_df['订单率'] = round(target_df['总订单量'] / target_df['点击量'] * 100, 2)

target_df[['展现量', '点击量', '总订单量', '订单率']].sort_values(by=['订单率'], ascending=False).fillna(0)
# Out:
#                    展现量   点击量  总订单量    订单率
# 广告组名称
# 黑色厚底              3501    17     4  23.53
# 纯色系列             21986   157    27  17.20
# 全部黑色款式女款         53448   136    23  16.91
# 棉拖0505           23452    19     3  15.79
# 0706            137476   219    31  14.16
# 女款平底纯色          231700   578    59  10.21
# 童鞋               89019   175    17   9.71
# Others         2846694  6315   591   9.36
# 0701            284581   690    63   9.13
# 全部款              64404   146    13   8.90
# 全部男款            163355   484    43   8.88
# 斑点狗             495377  1386   107   7.72
# 0731            166504   923    70   7.58
# FBA Instock     828422   932    70   7.51
# 自投             2145392  7932   577   7.27
# 厚底人字拖全部         147399   660    46   6.97
# 0701-粉          501096   855    56   6.55
# girls sandals     1152     3     0   0.00
# 07311             4504     4     0   0.00
# 捡漏                   3     0     0   0.00

# %% [markdown]
# *注：订单率 = 订单量 / 点击量*
#
# 此表解决的问题为：
#
# - 了解产品广告组的订单率情况。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
