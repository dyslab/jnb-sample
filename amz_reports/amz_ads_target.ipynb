# %% [markdown]
# Doc title: **Amazon Advertising Targeting Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Targeting Report' @Amazon Seller Central.
#
# 文章备注：亚马逊后台广告目标投放报告分析
#
# Last modified date: 2019-09-12 17:04:08

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_target_us_201908.xlsx', usecols=['广告活动名称', '广告组名称', '匹配类型', '投放', '展现量', '点击量', '花费', '7天总订单数(#)', '7天总销售额(￥)', '7天总销售量(#)'])

# %% [markdown]
# # 广告组数据排序（以销量为取值标准）

# %%
# Manipulating data and column names.
impr_df = workdf.groupby(['广告活动名称', '广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False).head(20)
impr_df['总销售额'] = impr_df['7天总销售额(￥)']
impr_df['总销售量'] = impr_df['7天总销售量(#)']
impr_df = impr_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
impr_df['点击率'] = round((impr_df['点击量'] / impr_df['展现量'] * 100), 2)
impr_df['卖出1件商品的平均花费'] = round(impr_df['花费'] / impr_df['总销售量'], 2)

impr_df.sort_values(by=['卖出1件商品的平均花费'])
# Out:
#                                                               展现量   点击量  \
# 广告活动名称                                       广告组名称
# 童鞋自动                                         童鞋             62363   160
# Advertise Long Term Storage Items - Hotmarzz 0701-粉         19684    44
# havaianas测试                                  斑点狗           153799   604
# Stranded Product Ad Promotion                FBA Instock   734929  1048
# 手投                                           纯色系列           66844   234
# 自投                                           自投           2131766  6557
# Advertise New0739 Products - Hotmarzz        Others        331936   766
# 0701测试                                       0701          228347   308
# Advertise Catalog38.24 - Hotmarzz            Others        716118  1198
# Advertise Top 0731、0701 Items - Hotmarzz     Others        372165  1178
# 黑色纯色女款                                       全部黑色款式女款       37848   235
# 厚底人字拖                                        厚底人字拖全部       186908   619
# Advertise Long Term Storage Items - Hotmarzz Others        150444   266
# 手投                                           女款平底          297729   387
# 男款手投                                         全部款            41467   139
# 男款鞋                                          全部男款           97125   316
# Advertise 0722、0742Low Traffic - Hotmarzz    Others        698535  1006
# 0701测试                                       0731          599929  1538
# 棉拖                                           棉拖0505         60466   110
# Advertise Long Term Storage Items - Hotmarzz 0706          174456   236
#
#                                                                花费     总销售额  \
# 广告活动名称                                       广告组名称
# 童鞋自动                                         童鞋             32.84   155.89
# Advertise Long Term Storage Items - Hotmarzz 0701-粉         20.04    92.94
# havaianas测试                                  斑点狗           179.57   773.81
# Stranded Product Ad Promotion                FBA Instock   326.83  1232.20
# 手投                                           纯色系列          135.75   540.67
# 自投                                           自投           2266.81  8295.03
# Advertise New0739 Products - Hotmarzz        Others        217.30   792.12
# 0701测试                                       0701          170.19   560.63
# Advertise Catalog38.24 - Hotmarzz            Others        381.48  1222.23
# Advertise Top 0731、0701 Items - Hotmarzz     Others        437.55  1290.17
# 黑色纯色女款                                       全部黑色款式女款      190.09   549.64
# 厚底人字拖                                        厚底人字拖全部       207.11   618.63
# Advertise Long Term Storage Items - Hotmarzz Others        157.58   455.72
# 手投                                           女款平底          160.63   444.72
# 男款手投                                         全部款            60.30   158.90
# 男款鞋                                          全部男款           93.78   236.85
# Advertise 0722、0742Low Traffic - Hotmarzz    Others        444.31  1146.31
# 0701测试                                       0731          687.82  1421.76
# 棉拖                                           棉拖0505        115.87   197.88
# Advertise Long Term Storage Items - Hotmarzz 0706          137.81   186.88
#
#                                                           总销售量   点击率  \
# 广告活动名称                                       广告组名称
# 童鞋自动                                         童鞋             11  0.26
# Advertise Long Term Storage Items - Hotmarzz 0701-粉          6  0.22
# havaianas测试                                  斑点狗            49  0.39
# Stranded Product Ad Promotion                FBA Instock    80  0.14
# 手投                                           纯色系列           33  0.35
# 自投                                           自投            517  0.31
# Advertise New0739 Products - Hotmarzz        Others         48  0.23
# 0701测试                                       0701           37  0.13
# Advertise Catalog38.24 - Hotmarzz            Others         77  0.17
# Advertise Top 0731、0701 Items - Hotmarzz     Others         83  0.32
# 黑色纯色女款                                       全部黑色款式女款       36  0.62
# 厚底人字拖                                        厚底人字拖全部        37  0.33
# Advertise Long Term Storage Items - Hotmarzz Others         28  0.18
# 手投                                           女款平底           28  0.13
# 男款手投                                         全部款            10  0.34
# 男款鞋                                          全部男款           15  0.33
# Advertise 0722、0742Low Traffic - Hotmarzz    Others         69  0.14
# 0701测试                                       0731           84  0.26
# 棉拖                                           棉拖0505         12  0.18
# Advertise Long Term Storage Items - Hotmarzz 0706           12  0.14
#
#                                                           卖出1件商品的平均花费
# 广告活动名称                                       广告组名称
# 童鞋自动                                         童鞋                  2.99
# Advertise Long Term Storage Items - Hotmarzz 0701-粉              3.34
# havaianas测试                                  斑点狗                 3.66
# Stranded Product Ad Promotion                FBA Instock         4.09
# 手投                                           纯色系列                4.11
# 自投                                           自投                  4.38
# Advertise New0739 Products - Hotmarzz        Others              4.53
# 0701测试                                       0701                4.60
# Advertise Catalog38.24 - Hotmarzz            Others              4.95
# Advertise Top 0731、0701 Items - Hotmarzz     Others              5.27
# 黑色纯色女款                                       全部黑色款式女款            5.28
# 厚底人字拖                                        厚底人字拖全部             5.60
# Advertise Long Term Storage Items - Hotmarzz Others              5.63
# 手投                                           女款平底                5.74
# 男款手投                                         全部款                 6.03
# 男款鞋                                          全部男款                6.25
# Advertise 0722、0742Low Traffic - Hotmarzz    Others              6.44
# 0701测试                                       0731                8.19
# 棉拖                                           棉拖0505              9.66
# Advertise Long Term Storage Items - Hotmarzz 0706               11.48

# %% [markdown]
# 此表解决的问题为：
#
# - 找出销量最高的广告组。
#
# - 找出最具性价比的广告组。（卖出1件商品花费越小，则性价比越高）

# %% [markdown]
# # 投放数据排序（以展现量为取值标准）

# %%
# Manipulating data and column names.
target_df = workdf.groupby(['广告组名称', '匹配类型', '投放']).sum().sort_values(by=['展现量'], ascending=False).head(20)
target_df['总销售额'] = target_df['7天总销售额(￥)']
target_df['总销售量'] = target_df['7天总销售量(#)']
target_df = target_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
target_df['性价比(总销售额/花费)'] = round(target_df['总销售额'] / target_df['花费'], 2)

target_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                                                        展现量   点击量       花费  \
# 广告组名称       匹配类型   投放
# FBA Instock -      loose-match                      125402   248    54.02
# 童鞋          -      substitutes                       59930   141    28.32
# 女款平底        BROAD  womens flip flops                124362   149    52.32
# 纯色系列        EXACT  white flip flops for women        62976   213   128.70
# 自投          BROAD  *                               2131766  6557  2266.81
# FBA Instock -      substitutes                      460497   487   163.39
#                    close-match                      148699   312   108.81
# 0701        EXACT  flip flop for women              114240   132    75.41
# 女款平底        PHRASE flip flops size                   69067    90    39.06
# Others      BROAD  *                               2269198  4414  1638.22
# 全部男款        BROAD  *                                 97125   316    93.78
# 0731        EXACT  havaianas flip flops women       138723   583   206.05
# 0701        EXACT  flip flops for women              56067    71    40.58
# 0731        EXACT  havianas womens flip flops        87555   279   108.09
# 棉拖0505      BROAD  *                                 60466   110   115.87
# 斑点狗         EXACT  havaianas flip flops for women    88377   228    69.61
# 0731        EXACT  flip flops for women             280537   360   230.21
# 0706        -      substitutes                       76454    78    42.22
# 女款平底        BROAD  shower shoes                      54133    52    29.51
# 0706        -      loose-match                       52105    73    42.77
#
#                                                       总销售额  总销售量  性价比(总销售额/花费)
# 广告组名称       匹配类型   投放
# FBA Instock -      loose-match                      288.81    19          5.35
# 童鞋          -      substitutes                      127.91     9          4.52
# 女款平底        BROAD  womens flip flops                207.87    13          3.97
# 纯色系列        EXACT  white flip flops for women       489.70    30          3.80
# 自投          BROAD  *                               8295.03   517          3.66
# FBA Instock -      substitutes                      573.63    37          3.51
#                    close-match                      369.76    24          3.40
# 0701        EXACT  flip flop for women              255.83    17          3.39
# 女款平底        PHRASE flip flops size                  126.92     8          3.25
# Others      BROAD  *                               4906.55   305          3.00
# 全部男款        BROAD  *                                236.85    15          2.53
# 0731        EXACT  havaianas flip flops women       508.00    30          2.47
# 0701        EXACT  flip flops for women              92.94     6          2.29
# 0731        EXACT  havianas womens flip flops       207.88    12          1.92
# 棉拖0505      BROAD  *                                197.88    12          1.71
# 斑点狗         EXACT  havaianas flip flops for women   113.93     7          1.64
# 0731        EXACT  flip flops for women             352.09    21          1.53
# 0706        -      substitutes                       44.97     3          1.07
# 女款平底        BROAD  shower shoes                      30.98     2          1.05
# 0706        -      loose-match                       44.97     3          1.05

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的投放项目。

# %% [markdown]
# # 性价比最高的Top 10广告组与全部广告组数据对比

# %% [markdown]
# *注：在某一项目组每投入1美元带来的销售额回报越高，则其性价比越高。*

# %% [markdown]
# ## Top 10广告组

# %%
# Top 10 Ads.
top10_df = workdf.groupby(['广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False)
top10_df['总销售额'] = top10_df['7天总销售额(￥)']
top10_df['性价比'] = round(top10_df['总销售额'] / top10_df['花费'], 2)
top10_df = top10_df[['展现量', '点击量', '花费', '总销售额', '性价比']].sort_values(by=['性价比'], ascending=False).head(10)

print('Top 10 广告组\n')

top10_df
# Out:
# Top 10 广告组
#                    展现量   点击量       花费     总销售额    性价比
# 广告组名称
# girls sandals     6892     8     4.02    69.95  17.40
# 童鞋               62363   160    32.84   155.89   4.75
# 0701-粉           19684    44    20.04    92.94   4.64
# 斑点狗             153799   604   179.57   773.81   4.31
# 纯色系列             66844   234   135.75   540.67   3.98
# FBA Instock     734929  1048   326.83  1232.20   3.77
# 自投             2131766  6557  2266.81  8295.03   3.66
# 0701            228347   308   170.19   560.63   3.29
# Others         2269198  4414  1638.22  4906.55   3.00
# 厚底人字拖全部         186908   619   207.11   618.63   2.99

# %% [markdown]
# ## 数据对比

# %%
total_ds = workdf.sum()
top10_ds = top10_df.sum()

print('结论：')
print('\nTop 10广告组花费为：{0:.2f}美元； 全部广告组花费为：{1:.2f}美元； Top 10广告组占比：{2:.2f}%'.format(top10_ds['花费'], total_ds['花费'], top10_ds['花费'] / total_ds['花费'] * 100))
print('\nTop 10广告组共销售：{0:.2f}美元； 全部广告组共销售：{1:.2f}美元； Top 10广告组占比：{2:.2f}%'.format(top10_ds['总销售额'], total_ds['7天总销售额(￥)'], top10_ds['总销售额'] / total_ds['7天总销售额(￥)'] * 100))
# Out:
# 结论：
#
# Top 10广告组花费为：4981.38美元； 全部广告组花费为：6454.12美元； Top 10广告组占比：77.18%
#
# Top 10广告组共销售：17246.30美元； 全部广告组共销售：20476.91美元； Top 10广告组占比：84.22%

# %% [markdown]
# # 产品广告活动订单率情况

# %%
target_df = workdf.groupby(['广告活动名称']).sum().head(20)
target_df['总订单量'] = target_df['7天总订单数(#)']
target_df['订单率'] = round(target_df['总订单量'] / target_df['点击量'] * 100, 2)

target_df[['展现量', '点击量', '总订单量', '订单率']].sort_values(by=['订单率'], ascending=False).fillna(0)
# Out:
#                                                   展现量   点击量  总订单量    订单率
# 广告活动名称
# 黑色纯色女款                                          37848   235    36  15.32
# 棉拖                                              60466   110    12  10.91
# 手投                                             369654   661    62   9.38
# havaianas测试                                    153799   604    49   8.11
# Advertise Long Term Storage Items - Hotmarzz   344584   546    44   8.06
# 自投                                            2131766  6557   513   7.82
# Stranded Product Ad Promotion                  734929  1048    79   7.54
# 男款手投                                            41467   139    10   7.19
# Advertise Top 0731、0701 Items - Hotmarzz       372165  1178    82   6.96
# Advertise 0722、0742Low Traffic - Hotmarzz      698535  1006    69   6.86
# 0701测试                                         849495  1873   124   6.62
# Advertise Catalog38.24 - Hotmarzz              716118  1198    77   6.43
# Advertise New0739 Products - Hotmarzz          331936   766    48   6.27
# 童鞋自动                                            62363   160    10   6.25
# 厚底人字拖                                          186908   619    37   5.98
# 男款鞋                                             97125   316    15   4.75
# 秒杀活动                                             1948     8     0   0.00

# %% [markdown]
# *注：订单率 = 订单量 / 点击量*
#
# 此表解决的问题为：
#
# - 了解产品广告活动的订单率情况。品牌广告的相关情况可见 **[amz_ads_brand.ipynb](amz_ads_brand.ipynb)** 的相关部分说明。

# %% [markdown]
# # 产品广告组订单率情况

# %%
target_df = workdf.groupby(['广告组名称']).sum().head(20)
target_df['总订单量'] = target_df['7天总订单数(#)']
target_df['订单率'] = round(target_df['总订单量'] / target_df['点击量'] * 100, 2)

target_df[['展现量', '点击量', '总订单量', '订单率']].sort_values(by=['订单率'], ascending=False).fillna(0)
# Out:
#                    展现量   点击量  总订单量    订单率
# 广告组名称
# girls sandals     6892     8     5  62.50
# 全部黑色款式女款         37848   235    36  15.32
# 纯色系列             66844   234    32  13.68
# 0701            228347   308    37  12.01
# 0701-粉           19684    44     5  11.36
# 棉拖0505           60466   110    12  10.91
# 斑点狗             153799   604    49   8.11
# 自投             2131766  6557   513   7.82
# FBA Instock     734929  1048    79   7.54
# 女款平底            297729   387    28   7.24
# 全部款              41467   139    10   7.19
# Others         2269198  4414   304   6.89
# 童鞋               62363   160    10   6.25
# 厚底人字拖全部         186908   619    37   5.98
# 0731            599929  1538    82   5.33
# 黑色厚底              4910    40     2   5.00
# 全部男款             97125   316    15   4.75
# 0706            174456   236    11   4.66
# 07311            14327    19     0   0.00
# 秒杀                1948     8     0   0.00

# %% [markdown]
# *注：订单率 = 订单量 / 点击量*
#
# 此表解决的问题为：
#
# - 了解产品广告组的订单率情况。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
