# %% [markdown]
# Doc title: **Amazon Advertising Targeting Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Targeting Report' @Amazon Seller Central.
#
# 文章备注：亚马逊后台广告目标投放报告分析
#
# Last modified date: 2019-10-05 03:10:32

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_target_us_201909.xlsx', usecols=['广告活动名称', '广告组名称', '匹配类型', '投放', '展现量', '点击量', '花费', '7天总订单数(#)', '7天总销售额(￥)', '7天总销售量(#)'])

# %% [markdown]
# # 广告组数据排序（以销量为取值标准）

# %%
# Manipulating data and column names.
impr_df = workdf.groupby(['广告活动名称', '广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False).head(20)
impr_df['总销售额'] = impr_df['7天总销售额(￥)']
impr_df['总销售量'] = impr_df['7天总销售量(#)']
impr_df = impr_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
impr_df['点击率'] = round((impr_df['点击量'] / impr_df['展现量'] * 100), 2)
impr_df['卖出1件商品的平均花费'] = round(impr_df['花费'] / impr_df['总销售量'], 2)

impr_df.sort_values(by=['卖出1件商品的平均花费'])
# Out:
#                                                               展现量   点击量  \
# 广告活动名称                                       广告组名称
# 手投                                           黑色厚底            3214    15
# Advertise Top 0731、0701 Items - Hotmarzz     Others        134951   654
# Stranded Product Ad Promotion                FBA Instock   370131   752
# Advertise New0739 Products - Hotmarzz        Others        163041   653
# havaianas测试                                  斑点狗           112474   667
# 男款鞋                                          全部男款           49853   213
# 颜色分类                                         全部黑色款式女款       31362   122
# Advertise Catalog38.24 - Hotmarzz            Others        210832   585
# Advertise 0722、0742Low Traffic - Hotmarzz    Others        234774   667
# 手投                                           女款平底          260477   441
#                                              白色系列           54228   185
# 0701测试                                       0731          149504   776
# 厚底人字拖                                        厚底人字拖全部       168985   711
# Advertise Long Term Storage Items - Hotmarzz Others         48858    65
# 自投                                           自投           2428222  3864
# 棉拖                                           棉拖0505         24870    32
# 0701测试                                       0701          211637   418
# 男款手投                                         全部款            52629   124
# Advertise Long Term Storage Items - Hotmarzz 0706           46345    68
#                                              特价产品           60418    98
#
#                                                                花费     总销售额  \
# 广告活动名称                                       广告组名称
# 手投                                           黑色厚底            7.15   118.93
# Advertise Top 0731、0701 Items - Hotmarzz     Others        209.32   991.83
# Stranded Product Ad Promotion                FBA Instock   228.26  1097.59
# Advertise New0739 Products - Hotmarzz        Others        205.55  1011.86
# havaianas测试                                  斑点狗           191.39   889.93
# 男款鞋                                          全部男款           64.25   302.81
# 颜色分类                                         全部黑色款式女款       68.15   307.80
# Advertise Catalog38.24 - Hotmarzz            Others        156.13   703.55
# Advertise 0722、0742Low Traffic - Hotmarzz    Others        201.39   942.73
# 手投                                           女款平底          176.57   774.81
#                                              白色系列          110.16   485.70
# 0701测试                                       0731          293.84  1186.45
# 厚底人字拖                                        厚底人字拖全部       290.54  1172.30
# Advertise Long Term Storage Items - Hotmarzz Others         33.39   132.92
# 自投                                           自投           1990.44  5828.30
# 棉拖                                           棉拖0505         33.54    97.94
# 0701测试                                       0701          247.68   630.59
# 男款手投                                         全部款            59.10   138.91
# Advertise Long Term Storage Items - Hotmarzz 0706           35.18    63.26
#                                              特价产品           74.34   123.92
#
#                                                           总销售量   点击率  \
# 广告活动名称                                       广告组名称
# 手投                                           黑色厚底            7  0.47
# Advertise Top 0731、0701 Items - Hotmarzz     Others         67  0.48
# Stranded Product Ad Promotion                FBA Instock    71  0.20
# Advertise New0739 Products - Hotmarzz        Others         64  0.40
# havaianas测试                                  斑点狗            57  0.59
# 男款鞋                                          全部男款           19  0.43
# 颜色分类                                         全部黑色款式女款       20  0.39
# Advertise Catalog38.24 - Hotmarzz            Others         45  0.28
# Advertise 0722、0742Low Traffic - Hotmarzz    Others         57  0.28
# 手投                                           女款平底           50  0.17
#                                              白色系列           30  0.34
# 0701测试                                       0731           75  0.52
# 厚底人字拖                                        厚底人字拖全部        70  0.42
# Advertise Long Term Storage Items - Hotmarzz Others          8  0.13
# 自投                                           自投            370  0.16
# 棉拖                                           棉拖0505          6  0.13
# 0701测试                                       0701           41  0.20
# 男款手投                                         全部款             9  0.24
# Advertise Long Term Storage Items - Hotmarzz 0706            4  0.15
#                                              特价产品            8  0.16
#
#                                                           卖出1件商品的平均花费
# 广告活动名称                                       广告组名称
# 手投                                           黑色厚底                1.02
# Advertise Top 0731、0701 Items - Hotmarzz     Others              3.12
# Stranded Product Ad Promotion                FBA Instock         3.21
# Advertise New0739 Products - Hotmarzz        Others              3.21
# havaianas测试                                  斑点狗                 3.36
# 男款鞋                                          全部男款                3.38
# 颜色分类                                         全部黑色款式女款            3.41
# Advertise Catalog38.24 - Hotmarzz            Others              3.47
# Advertise 0722、0742Low Traffic - Hotmarzz    Others              3.53
# 手投                                           女款平底                3.53
#                                              白色系列                3.67
# 0701测试                                       0731                3.92
# 厚底人字拖                                        厚底人字拖全部             4.15
# Advertise Long Term Storage Items - Hotmarzz Others              4.17
# 自投                                           自投                  5.38
# 棉拖                                           棉拖0505              5.59
# 0701测试                                       0701                6.04
# 男款手投                                         全部款                 6.57
# Advertise Long Term Storage Items - Hotmarzz 0706                8.80
#                                              特价产品                9.29

# %% [markdown]
# 此表解决的问题为：
#
# - 找出销量最高的广告组。
#
# - 找出最具性价比的广告组。（卖出1件商品花费越小，则性价比越高）

# %% [markdown]
# # 投放数据排序（以展现量为取值标准）

# %%
# Manipulating data and column names.
target_df = workdf.groupby(['广告组名称', '匹配类型', '投放']).sum().sort_values(by=['展现量'], ascending=False).head(20)
target_df['总销售额'] = target_df['7天总销售额(￥)']
target_df['总销售量'] = target_df['7天总销售量(#)']
target_df = target_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
target_df['性价比(总销售额/花费)'] = round(target_df['总销售额'] / target_df['花费'], 2)

target_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                                                        展现量   点击量       花费  \
# 广告组名称       匹配类型   投放
# 斑点狗         EXACT  havaianas flip flops for women    51255   216    56.70
# FBA Instock -      close-match                      103222   334   123.42
# 女款平底        PHRASE flip flops size                   56992    83    40.60
# 全部男款        BROAD  *                                 49853   213    64.25
# Others      BROAD  *                                792456  2624   805.78
# 0731        EXACT  havaianas flip flops women        29492   266    80.84
# 0701        EXACT  womans flip flops                 25567    59    27.35
# 全部黑色款式女款    EXACT  black flip flops for women        30475   102    63.34
# 白色系列        EXACT  white flip flops for women        52058   176   106.19
# 女款平底        BROAD  womens flip flops                152309   268    93.43
# FBA Instock -      loose-match                       89438   190    40.42
#                    substitutes                      177287   228    64.42
# 厚底人字拖全部     EXACT  wedge flip flops for women        60468   312   134.73
#                    wedge flip flops                  32909   185    79.62
# 自投          BROAD  *                               2428222  3864  1990.44
# 特价产品        -      substitutes                       39592    46    35.93
# 0701        EXACT  flip flop for women              160171   298   181.32
# 0731        EXACT  flip flops for women              70308   195   106.60
# 厚底人字拖全部     EXACT  guess shoes women                 27067    32    10.23
# 0706        -      loose-match                       26273    32    13.93
#
#                                                       总销售额  总销售量  性价比(总销售额/花费)
# 广告组名称       匹配类型   投放
# 斑点狗         EXACT  havaianas flip flops for women   318.80    20          5.62
# FBA Instock -      close-match                      686.86    44          5.57
# 女款平底        PHRASE flip flops size                  206.87    14          5.10
# 全部男款        BROAD  *                                302.81    19          4.71
# Others      BROAD  *                               3782.89   241          4.69
# 0731        EXACT  havaianas flip flops women       366.87    23          4.54
# 0701        EXACT  womans flip flops                123.92     8          4.53
# 全部黑色款式女款    EXACT  black flip flops for women       277.82    18          4.39
# 白色系列        EXACT  white flip flops for women       451.72    28          4.25
# 女款平底        BROAD  womens flip flops                395.05    25          4.23
# FBA Instock -      loose-match                      163.89    11          4.05
#                    substitutes                      246.84    16          3.83
# 厚底人字拖全部     EXACT  wedge flip flops for women       504.70    30          3.75
#                    wedge flip flops                 234.86    14          2.95
# 自投          BROAD  *                               5828.30   370          2.93
# 特价产品        -      substitutes                       94.94     6          2.64
# 0701        EXACT  flip flop for women              459.70    30          2.54
# 0731        EXACT  flip flops for women             238.35    15          2.24
# 厚底人字拖全部     EXACT  guess shoes women                  0.00     0          0.00
# 0706        -      loose-match                        0.00     0          0.00

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的投放项目。

# %% [markdown]
# # 性价比最高的Top 10广告组与全部广告组数据对比

# %% [markdown]
# *注：在某一项目组每投入1美元带来的销售额回报越高，则其性价比越高。*

# %% [markdown]
# ## Top 10广告组

# %%
# Top 10 Ads.
top10_df = workdf.groupby(['广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False)
top10_df['总销售额'] = top10_df['7天总销售额(￥)']
top10_df['性价比'] = round(top10_df['总销售额'] / top10_df['花费'], 2)
top10_df = top10_df[['展现量', '点击量', '花费', '总销售额', '性价比']].sort_values(by=['性价比'], ascending=False).head(10)

print('Top 10 广告组\n')

top10_df
# Out:
# Top 10 广告组
#                   展现量   点击量      花费     总销售额    性价比
# 广告组名称
# 黑色厚底             3214    15    7.15   118.93  16.63
# girls sandals    1241     4    1.46    13.99   9.58
# 0701-粉           9790    22    7.64    59.96   7.85
# 童鞋              23196    46    9.09    60.96   6.71
# 0701、0731        2528     9    3.12    15.29   4.90
# FBA Instock    370131   752  228.26  1097.59   4.81
# 全部男款            49853   213   64.25   302.81   4.71
# Others         792456  2624  805.78  3782.89   4.69
# 斑点狗            112474   667  191.39   889.93   4.65
# 全部黑色款式女款        31362   122   68.15   307.80   4.52

# %% [markdown]
# ## 数据对比

# %%
total_ds = workdf.sum()
top10_ds = top10_df.sum()

print('结论：')
print('\nTop 10广告组花费为：{0:.2f}美元； 全部广告组花费为：{1:.2f}美元； Top 10广告组占比：{2:.2f}%'.format(top10_ds['花费'], total_ds['花费'], top10_ds['花费'] / total_ds['花费'] * 100))
print('\nTop 10广告组共销售：{0:.2f}美元； 全部广告组共销售：{1:.2f}美元； Top 10广告组占比：{2:.2f}%'.format(top10_ds['总销售额'], total_ds['7天总销售额(￥)'], top10_ds['总销售额'] / total_ds['7天总销售额(￥)'] * 100))
# Out:
# 结论：
#
# Top 10广告组花费为：1386.29美元； 全部广告组花费为：4708.05美元； Top 10广告组占比：29.45%
#
# Top 10广告组共销售：6650.15美元； 全部广告组共销售：17152.33美元； Top 10广告组占比：38.77%

# %% [markdown]
# # 产品广告活动订单率情况

# %%
target_df = workdf.groupby(['广告活动名称']).sum().head(20)
target_df['总订单量'] = target_df['7天总订单数(#)']
target_df['订单率'] = round(target_df['总订单量'] / target_df['点击量'] * 100, 2)

target_df[['展现量', '点击量', '总订单量', '订单率']].sort_values(by=['订单率'], ascending=False).fillna(0)
# Out:
#                                                   展现量   点击量  总订单量    订单率
# 广告活动名称
# 棉拖                                              24870    32     6  18.75
# 颜色分类                                            31362   122    20  16.39
# 手投                                             318104   641    85  13.26
# 类似展示测试                                           2528     9     1  11.11
# Advertise Top 0731、0701 Items - Hotmarzz       134951   654    67  10.24
# 厚底人字拖                                          168985   711    69   9.70
# Advertise New0739 Products - Hotmarzz          163041   653    63   9.65
# 自投                                            2428222  3864   367   9.50
# Advertise Long Term Storage Items - Hotmarzz   165411   253    24   9.49
# 0701测试                                         369381  1227   116   9.45
# Stranded Product Ad Promotion                  370131   752    71   9.44
# 男款鞋                                             49853   213    19   8.92
# 童鞋自动                                            23196    46     4   8.70
# Advertise 0722、0742Low Traffic - Hotmarzz      234774   667    57   8.55
# havaianas测试                                    112474   667    55   8.25
# Advertise Catalog38.24 - Hotmarzz              210832   585    45   7.69
# 男款手投                                            52629   124     9   7.26
# 棉拖2                                              5551     5     0   0.00

# %% [markdown]
# *注：订单率 = 订单量 / 点击量*
#
# 此表解决的问题为：
#
# - 了解产品广告活动的订单率情况。品牌广告的相关情况可见 **[amz_ads_brand.ipynb](amz_ads_brand.ipynb)** 的相关部分说明。

# %% [markdown]
# # 产品广告组订单率情况

# %%
target_df = workdf.groupby(['广告组名称']).sum().head(20)
target_df['总订单量'] = target_df['7天总订单数(#)']
target_df['订单率'] = round(target_df['总订单量'] / target_df['点击量'] * 100, 2)

target_df[['展现量', '点击量', '总订单量', '订单率']].sort_values(by=['订单率'], ascending=False).fillna(0)
# Out:
#                   展现量   点击量  总订单量    订单率
# 广告组名称
# girls sandals    1241     4     1  25.00
# 棉拖0505          24870    32     6  18.75
# 0701-粉           9790    22     4  18.18
# 全部黑色款式女款        31362   122    20  16.39
# 白色系列            54228   185    29  15.68
# 女款平底           260477   441    50  11.34
# 0701、0731        2528     9     1  11.11
# 0701           211637   418    41   9.81
# 厚底人字拖全部        168985   711    69   9.70
# 0731           149504   776    74   9.54
# FBA Instock    370131   752    71   9.44
# Others         792456  2624   240   9.15
# 全部男款            49853   213    19   8.92
# 童鞋              23196    46     4   8.70
# 斑点狗            112474   667    55   8.25
# 特价产品            60418    98     8   8.16
# 全部款             52629   124     9   7.26
# 0706            46345    68     4   5.88
# 棉拖               5551     5     0   0.00
# asin广告           6999    29     0   0.00

# %% [markdown]
# *注：订单率 = 订单量 / 点击量*
#
# 此表解决的问题为：
#
# - 了解产品广告组的订单率情况。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
