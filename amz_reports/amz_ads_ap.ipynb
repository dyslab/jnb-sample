# %% [markdown]
# Doc title: **Amazon Advertising Advertised Product Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Advertised Product Report' @Amazon Seller Central. Certain columns which contained the product ASIN has been removed from the file.
#
# 文章备注：亚马逊后台广告产品报告分析。其中包含ASIN数据的列已从文件中删除。
#
# Last modified date: 2019-11-03 20:12:05

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_ap_us_201910.xlsx', usecols=['广告活动名称', '广告组名称', '广告SKU', '展现量', '点击量', '花费', '7天总销售额(￥)', '7天总销售量(#)', '7天内其他SKU销售量(#)', '7天内其他SKU销售额(￥)'])

# %% [markdown]
# # 广告组数据排序（以销量为取值标准）

# %% [markdown]
# *注：此部分结果请查看 [amz_ads_target.ipynb](amz_ads_target.ipynb) 中相关内容。*

# %% [raw]
# # Manipulating data and column names.
# impr_df = workdf.groupby(['广告活动名称', '广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False).head(20)
# impr_df['总销售额'] = impr_df['7天总销售额(￥)']
# impr_df['总销售量'] = impr_df['7天总销售量(#)']
# impr_df = impr_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
# impr_df['点击率'] = round((impr_df['点击量'] / impr_df['展现量'] * 100), 2)
# impr_df['卖出1件商品的平均花费'] = round(impr_df['花费'] / impr_df['总销售量'], 2)
#
# impr_df.sort_values(by=['卖出1件商品的平均花费'])
#
# # Note: Regarding the result is as same as the analyzation in 'amz_ads_target.ipynb', check it out there as well as this section was annotated as a raw data cell.

# %% [markdown]
# 此表解决的问题为：
#
# - 找出展现量最高的广告组。
#
# - 找出最具性价比的广告组。（卖出1件商品花费越小，则性价比越高）

# %% [markdown]
# # 广告产品数据排序（以展现量为取值标准）

# %% [markdown]
# ## 最具性价比的广告产品以及其所在的广告组

# %%
# Manipulating data and column names.
ap_df = workdf.groupby(['广告活动名称', '广告组名称', '广告SKU']).sum().sort_values(by=['展现量'], ascending=False).head(20)
ap_df['总销售额'] = ap_df['7天总销售额(￥)']
ap_df['总销售量'] = ap_df['7天总销售量(#)']
ap_df = ap_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
ap_df['性价比(总销售额/花费)'] = round(ap_df['总销售额'] / ap_df['花费'], 2)

ap_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                                                                   展现量  点击量  \
# 广告活动名称                                    广告组名称   广告SKU
# 自投                                        自投      HM0738-Z-35   41155   40
# Advertise Top 0731、0701 Items - Hotmarzz  Others  HM0701-F-37   75787  159
# 自投                                        自投      HM0733-1741   58977   17
# Advertise 0722、0742Low Traffic - Hotmarzz Others  HM0722-L-37   62572  143
#                                                   HM0722-X-40   39871   27
# Advertise Top 0731、0701 Items - Hotmarzz  Others  HM0701-X-40   60641  151
# 自投                                        自投      HM0722-B-38   90005  144
#                                                   HM0722-H-40   93439   69
#                                                   HM0709-237   109110   60
#                                                   HM0722-B-37   43609  104
# 0701测试                                    平底      HM0740-3240   54122   60
#                                                   HM0701-F-37  106303  207
# Advertise New0739 Products - Hotmarzz     Others  HM0709-1237   55200   50
#                                                   HM0729-M-37   42851   59
# 手投                                        女款平底    HM0738-141    45417   89
# 自投                                        自投      HM0903-1636   37937   56
# 厚底人字拖                                     厚底人字拖全部 HM0722-L-37   78098  198
# 0701测试                                    平底      HM0729-L-37   39117   12
#                                                   HM0738-140    56621   59
# 自投                                        自投      HM0722-M-39   72642   80
#
#                                                                    花费    总销售额  \
# 广告活动名称                                    广告组名称   广告SKU
# 自投                                        自投      HM0738-Z-35   14.62  149.91
# Advertise Top 0731、0701 Items - Hotmarzz  Others  HM0701-F-37   49.13  383.76
# 自投                                        自投      HM0733-1741    6.55   47.97
# Advertise 0722、0742Low Traffic - Hotmarzz Others  HM0722-L-37   40.51  294.82
#                                                   HM0722-X-40    8.82   49.97
# Advertise Top 0731、0701 Items - Hotmarzz  Others  HM0701-X-40   49.14  220.85
# 自投                                        自投      HM0722-B-38   56.97  247.85
#                                                   HM0722-H-40   40.00  149.91
#                                                   HM0709-237    18.88   62.96
#                                                   HM0722-B-37   46.44  136.92
# 0701测试                                    平底      HM0740-3240   53.17  126.92
#                                                   HM0701-F-37  200.22  442.70
# Advertise New0739 Products - Hotmarzz     Others  HM0709-1237   14.10   30.98
#                                                   HM0729-M-37   14.84   30.98
# 手投                                        女款平底    HM0738-141    41.90   80.95
# 自投                                        自投      HM0903-1636   24.35   45.97
# 厚底人字拖                                     厚底人字拖全部 HM0722-L-37  100.04  183.89
# 0701测试                                    平底      HM0729-L-37    8.81   15.99
#                                                   HM0738-140    53.67   61.96
# 自投                                        自投      HM0722-M-39   30.42   32.98
#
#                                                                总销售量  \
# 广告活动名称                                    广告组名称   广告SKU
# 自投                                        自投      HM0738-Z-35     9
# Advertise Top 0731、0701 Items - Hotmarzz  Others  HM0701-F-37    24
# 自投                                        自投      HM0733-1741     3
# Advertise 0722、0742Low Traffic - Hotmarzz Others  HM0722-L-37    18
#                                                   HM0722-X-40     3
# Advertise Top 0731、0701 Items - Hotmarzz  Others  HM0701-X-40    15
# 自投                                        自投      HM0722-B-38    15
#                                                   HM0722-H-40     9
#                                                   HM0709-237      4
#                                                   HM0722-B-37     8
# 0701测试                                    平底      HM0740-3240     8
#                                                   HM0701-F-37    30
# Advertise New0739 Products - Hotmarzz     Others  HM0709-1237     2
#                                                   HM0729-M-37     2
# 手投                                        女款平底    HM0738-141      5
# 自投                                        自投      HM0903-1636     3
# 厚底人字拖                                     厚底人字拖全部 HM0722-L-37    11
# 0701测试                                    平底      HM0729-L-37     1
#                                                   HM0738-140      4
# 自投                                        自投      HM0722-M-39     2
#
#                                                                性价比(总销售额/花费)
# 广告活动名称                                    广告组名称   广告SKU
# 自投                                        自投      HM0738-Z-35         10.25
# Advertise Top 0731、0701 Items - Hotmarzz  Others  HM0701-F-37          7.81
# 自投                                        自投      HM0733-1741          7.32
# Advertise 0722、0742Low Traffic - Hotmarzz Others  HM0722-L-37          7.28
#                                                   HM0722-X-40          5.67
# Advertise Top 0731、0701 Items - Hotmarzz  Others  HM0701-X-40          4.49
# 自投                                        自投      HM0722-B-38          4.35
#                                                   HM0722-H-40          3.75
#                                                   HM0709-237           3.33
#                                                   HM0722-B-37          2.95
# 0701测试                                    平底      HM0740-3240          2.39
#                                                   HM0701-F-37          2.21
# Advertise New0739 Products - Hotmarzz     Others  HM0709-1237          2.20
#                                                   HM0729-M-37          2.09
# 手投                                        女款平底    HM0738-141           1.93
# 自投                                        自投      HM0903-1636          1.89
# 厚底人字拖                                     厚底人字拖全部 HM0722-L-37          1.84
# 0701测试                                    平底      HM0729-L-37          1.81
#                                                   HM0738-140           1.15
# 自投                                        自投      HM0722-M-39          1.08

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的广告产品以及其所在的广告组。

# %% [markdown]
# ## 最具性价比的广告产品（不考虑其所在的广告组）

# %%
# Manipulating data and column names.
ap_df = workdf.groupby(['广告SKU']).sum().sort_values(by=['展现量'], ascending=False).head(20)
ap_df['总销售额'] = ap_df['7天总销售额(￥)']
ap_df['总销售量'] = ap_df['7天总销售量(#)']
ap_df = ap_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
ap_df['性价比(总销售额/花费)'] = round(ap_df['总销售额'] / ap_df['花费'], 2)

ap_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                 展现量  点击量      花费     总销售额  总销售量  性价比(总销售额/花费)
# 广告SKU
# HM0733-1741   60099   21    7.67    64.96     4          8.47
# HM0724-F-41   71583  135   50.44   269.83    17          5.35
# HM0731-Z-39   79983  412  211.39  1026.40    60          4.86
# HM0722-B-38  104545  271   95.47   462.72    28          4.85
# HM0722-X-40   43882   38   15.00    66.96     4          4.46
# HM0731-Z-35   58579  291  115.21   511.70    30          4.44
# HM0701-X-40   62703  158   52.78   220.85    15          4.18
# HM0722-B-37   50165  145   60.14   204.88    12          3.41
# HM0709-237   110276   60   18.88    62.96     4          3.33
# HM0701-F-37  182090  366  249.35   826.46    54          3.31
# HM0722-L-37  141956  351  145.68   478.71    29          3.29
# HM0701-H-41   85401  246  162.71   461.69    31          2.84
# HM0722-H-40  114555  124   69.23   181.89    11          2.63
# HM0729-M-37   63732   94   29.64    75.95     5          2.56
# HM0722-M-39   74026   88   34.22    81.95     5          2.39
# HM0740-3240   54122   60   53.17   126.92     8          2.39
# HM0709-1237   55200   50   14.10    30.98     2          2.20
# HM0738-140    77634   88   63.85   123.92     8          1.94
# HM0738-141    65771  131   67.27   128.92     8          1.92
# HM0729-L-37   49740   23   12.10    15.99     1          1.32

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的广告产品（不考虑其所在的广告组）。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
