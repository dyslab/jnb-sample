# %% [markdown]
# Doc title: **Amazon Advertising Advertised Product Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Advertised Product Report' @Amazon Seller Central. Certain columns which contained the product ASIN has been removed from the file.
#
# 文章备注：亚马逊后台广告产品报告分析。其中包含ASIN数据的列已从文件中删除。
#
# Last modified date: 2019-12-05 16:40:46

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_ap_us_201911.xlsx', usecols=['广告活动名称', '广告组名称', '广告SKU', '展现量', '点击量', '花费', '7天总销售额(￥)', '7天总销售量(#)', '7天内其他SKU销售量(#)', '7天内其他SKU销售额(￥)'])

# %% [markdown]
# # 广告组数据排序（以销量为取值标准）

# %% [markdown]
# *注：此部分结果请查看 [amz_ads_target.ipynb](amz_ads_target.ipynb) 中相关内容。*

# %% [raw]
# # Manipulating data and column names.
# impr_df = workdf.groupby(['广告活动名称', '广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False).head(20)
# impr_df['总销售额'] = impr_df['7天总销售额(￥)']
# impr_df['总销售量'] = impr_df['7天总销售量(#)']
# impr_df = impr_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
# impr_df['点击率'] = round((impr_df['点击量'] / impr_df['展现量'] * 100), 2)
# impr_df['卖出1件商品的平均花费'] = round(impr_df['花费'] / impr_df['总销售量'], 2)
#
# impr_df.sort_values(by=['卖出1件商品的平均花费'])
#
# # Note: Regarding the result is as same as the analyzation in 'amz_ads_target.ipynb', check it out there as well as this section was annotated as a raw data cell.

# %% [markdown]
# 此表解决的问题为：
#
# - 找出展现量最高的广告组。
#
# - 找出最具性价比的广告组。（卖出1件商品花费越小，则性价比越高）

# %% [markdown]
# # 广告产品数据排序（以展现量为取值标准）

# %% [markdown]
# ## 最具性价比的广告产品以及其所在的广告组

# %%
# Manipulating data and column names.
ap_df = workdf.groupby(['广告活动名称', '广告组名称', '广告SKU']).sum().sort_values(by=['展现量'], ascending=False).head(20)
ap_df['总销售额'] = ap_df['7天总销售额(￥)']
ap_df['总销售量'] = ap_df['7天总销售量(#)']
ap_df = ap_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
ap_df['性价比(总销售额/花费)'] = round(ap_df['总销售额'] / ap_df['花费'], 2)

ap_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                                                                  展现量  点击量  \
# 广告活动名称                                    广告组名称  广告SKU
# 自投                                        自投     HM0722-L-36   48454   60
#                                                  HM0722-M-39   61024   46
#                                                  HM0724-F-35   36422   49
# Advertise Top 0731、0701 Items - Hotmarzz  Others HM0701-F-37  105130  172
#                                                  HM0701-F-38   69329  111
# Advertise New0739 Products - Hotmarzz     Others HM0729-M-37   89504  111
# Advertise Top 0731、0701 Items - Hotmarzz  Others HM0731-Z-39   40768  102
# Advertise 0722、0742Low Traffic - Hotmarzz Others HM0722-L-37   46031   99
# Advertise Top 0731、0701 Items - Hotmarzz  Others HM0701-H-39   65549   36
#                                                  HM0701-X-40   49834  127
# Advertise Catalog38.24 - Hotmarzz         Others HM0738-V-35   47119   72
# 自投                                        自投     HM0709-237   154951   62
#                                                  HM0725-139    51775   24
#                                                  HM0719-1237   60480  114
# 0701测试                                    平底     HM0701-F-37   72774  180
#                                                  HM0741-0240   43894   53
#                                                  HM0738-140    50202   48
# Advertise Catalog38.24 - Hotmarzz         Others HM0724-F-41   46030  108
# Advertise New0739 Products - Hotmarzz     Others HM0709-1237   44681   42
# 自投                                        自投     HM0722-M-40   78353   65
#
#                                                                   花费    总销售额  \
# 广告活动名称                                    广告组名称  广告SKU
# 自投                                        自投     HM0722-L-36   18.34  217.87
#                                                  HM0722-M-39   10.21   82.95
#                                                  HM0724-F-35   13.03   82.95
# Advertise Top 0731、0701 Items - Hotmarzz  Others HM0701-F-37   53.64  318.79
#                                                  HM0701-F-38   35.33  199.87
# Advertise New0739 Products - Hotmarzz     Others HM0729-M-37   30.04  157.90
# Advertise Top 0731、0701 Items - Hotmarzz  Others HM0731-Z-39   27.09  135.92
# Advertise 0722、0742Low Traffic - Hotmarzz Others HM0722-L-37   21.15  101.94
# Advertise Top 0731、0701 Items - Hotmarzz  Others HM0701-H-39    8.55   33.98
#                                                  HM0701-X-40   36.37  135.91
# Advertise Catalog38.24 - Hotmarzz         Others HM0738-V-35   25.55   93.94
# 自投                                        自投     HM0709-237    14.07   46.97
#                                                  HM0725-139     5.62   16.99
#                                                  HM0719-1237   31.78   92.94
# 0701测试                                    平底     HM0701-F-37  136.41  394.73
#                                                  HM0741-0240   39.84   95.94
#                                                  HM0738-140    33.73   80.95
# Advertise Catalog38.24 - Hotmarzz         Others HM0724-F-41   31.09   64.96
# Advertise New0739 Products - Hotmarzz     Others HM0709-1237   12.48    0.00
# 自投                                        自投     HM0722-M-40   12.47    0.00
#
#                                                               总销售量  \
# 广告活动名称                                    广告组名称  广告SKU
# 自投                                        自投     HM0722-L-36    13
#                                                  HM0722-M-39     5
#                                                  HM0724-F-35     5
# Advertise Top 0731、0701 Items - Hotmarzz  Others HM0701-F-37    21
#                                                  HM0701-F-38    13
# Advertise New0739 Products - Hotmarzz     Others HM0729-M-37    10
# Advertise Top 0731、0701 Items - Hotmarzz  Others HM0731-Z-39     8
# Advertise 0722、0742Low Traffic - Hotmarzz Others HM0722-L-37     6
# Advertise Top 0731、0701 Items - Hotmarzz  Others HM0701-H-39     2
#                                                  HM0701-X-40     9
# Advertise Catalog38.24 - Hotmarzz         Others HM0738-V-35     6
# 自投                                        自投     HM0709-237      3
#                                                  HM0725-139      1
#                                                  HM0719-1237     6
# 0701测试                                    平底     HM0701-F-37    27
#                                                  HM0741-0240     6
#                                                  HM0738-140      5
# Advertise Catalog38.24 - Hotmarzz         Others HM0724-F-41     4
# Advertise New0739 Products - Hotmarzz     Others HM0709-1237     0
# 自投                                        自投     HM0722-M-40     0
#
#                                                               性价比(总销售额/花费)
# 广告活动名称                                    广告组名称  广告SKU
# 自投                                        自投     HM0722-L-36         11.88
#                                                  HM0722-M-39          8.12
#                                                  HM0724-F-35          6.37
# Advertise Top 0731、0701 Items - Hotmarzz  Others HM0701-F-37          5.94
#                                                  HM0701-F-38          5.66
# Advertise New0739 Products - Hotmarzz     Others HM0729-M-37          5.26
# Advertise Top 0731、0701 Items - Hotmarzz  Others HM0731-Z-39          5.02
# Advertise 0722、0742Low Traffic - Hotmarzz Others HM0722-L-37          4.82
# Advertise Top 0731、0701 Items - Hotmarzz  Others HM0701-H-39          3.97
#                                                  HM0701-X-40          3.74
# Advertise Catalog38.24 - Hotmarzz         Others HM0738-V-35          3.68
# 自投                                        自投     HM0709-237           3.34
#                                                  HM0725-139           3.02
#                                                  HM0719-1237          2.92
# 0701测试                                    平底     HM0701-F-37          2.89
#                                                  HM0741-0240          2.41
#                                                  HM0738-140           2.40
# Advertise Catalog38.24 - Hotmarzz         Others HM0724-F-41          2.09
# Advertise New0739 Products - Hotmarzz     Others HM0709-1237          0.00
# 自投                                        自投     HM0722-M-40          0.00

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的广告产品以及其所在的广告组。

# %% [markdown]
# ## 最具性价比的广告产品（不考虑其所在的广告组）

# %%
# Manipulating data and column names.
ap_df = workdf.groupby(['广告SKU']).sum().sort_values(by=['展现量'], ascending=False).head(20)
ap_df['总销售额'] = ap_df['7天总销售额(￥)']
ap_df['总销售量'] = ap_df['7天总销售量(#)']
ap_df = ap_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
ap_df['性价比(总销售额/花费)'] = round(ap_df['总销售额'] / ap_df['花费'], 2)

ap_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                 展现量  点击量      花费    总销售额  总销售量  性价比(总销售额/花费)
# 广告SKU
# HM0722-L-36   51947   65   20.79  217.87    13         10.48
# HM0722-M-39   62917   56   14.70   98.94     6          6.73
# HM0725-139    73006   42    8.59   48.97     3          5.70
# HM0701-F-38   69329  111   35.33  199.87    13          5.66
# HM0729-M-37  100747  129   38.65  157.90    10          4.09
# HM0731-Z-39   95233  366  161.34  636.63    37          3.95
# HM0724-F-41   70687  138   46.39  177.89    11          3.83
# HM0701-F-37  177904  352  190.05  713.52    48          3.75
# HM0701-X-40   49834  127   36.37  135.91     9          3.74
# HM0738-V-35   47119   72   25.55   93.94     6          3.68
# HM0701-H-39   66509   39    9.38   33.98     2          3.62
# HM0709-237   155281   62   14.07   46.97     3          3.34
# HM0741-0240   57523   73   46.11  144.91     9          3.14
# HM0719-1237   60480  114   31.78   92.94     6          2.92
# HM0722-L-37   71136  220   67.83  186.89    11          2.76
# HM0722-B-38   45472  119   36.09   98.94     6          2.74
# HM0738-140    71414   71   42.14  109.93     7          2.61
# HM0701-H-41   66054  178  104.55  220.85    15          2.11
# HM0722-M-40   95876  114   33.11   67.96     4          2.05
# HM0722-L-38   49963   73   33.16   64.96     4          1.96

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的广告产品（不考虑其所在的广告组）。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
