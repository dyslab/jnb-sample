# %% [markdown]
# Doc title: **Amazon Advertising Advertised Product Report**
#
# Article notes: Data came from 'Reports/Advertising Reports/Sponsored Products/Advertised Product Report' @Amazon Seller Central. Certain columns which contained the product ASIN has been removed from the file.
#
# 文章备注：亚马逊后台广告产品报告分析。其中包含ASIN数据的列已从文件中删除。
#
# Last modified date: 2019-10-05 02:57:59

# %%
# 引入pandas数据分析模块
import pandas as pd

# 数据范例：美国站，月度数据
workdf = pd.read_excel('data/amz_ads_ap_us_201909.xlsx', usecols=['广告活动名称', '广告组名称', '广告SKU', '展现量', '点击量', '花费', '7天总销售额(￥)', '7天总销售量(#)', '7天内其他SKU销售量(#)', '7天内其他SKU销售额(￥)'])

# %% [markdown]
# # 广告组数据排序（以销量为取值标准）

# %% [markdown]
# *注：此部分结果请查看 [amz_ads_target.ipynb](amz_ads_target.ipynb) 中相关内容。*

# %% [raw]
# # Manipulating data and column names.
# impr_df = workdf.groupby(['广告活动名称', '广告组名称']).sum().sort_values(by=['7天总销售量(#)'], ascending=False).head(20)
# impr_df['总销售额'] = impr_df['7天总销售额(￥)']
# impr_df['总销售量'] = impr_df['7天总销售量(#)']
# impr_df = impr_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
# impr_df['点击率'] = round((impr_df['点击量'] / impr_df['展现量'] * 100), 2)
# impr_df['卖出1件商品的平均花费'] = round(impr_df['花费'] / impr_df['总销售量'], 2)
#
# impr_df.sort_values(by=['卖出1件商品的平均花费'])
#
# # Note: Regarding the result is as same as the analyzation in 'amz_ads_target.ipynb', check it out there as well as this section was annotated as a raw data cell.

# %% [markdown]
# 此表解决的问题为：
#
# - 找出展现量最高的广告组。
#
# - 找出最具性价比的广告组。（卖出1件商品花费越小，则性价比越高）

# %% [markdown]
# # 广告产品数据排序（以展现量为取值标准）

# %% [markdown]
# ## 最具性价比的广告产品以及其所在的广告组

# %%
# Manipulating data and column names.
ap_df = workdf.groupby(['广告活动名称', '广告组名称', '广告SKU']).sum().sort_values(by=['展现量'], ascending=False).head(20)
ap_df['总销售额'] = ap_df['7天总销售额(￥)']
ap_df['总销售量'] = ap_df['7天总销售量(#)']
ap_df = ap_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
ap_df['性价比(总销售额/花费)'] = round(ap_df['总销售额'] / ap_df['花费'], 2)

ap_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                                                           展现量  点击量      花费  \
# 广告活动名称                        广告组名称       广告SKU
# Stranded Product Ad Promotion FBA Instock HM0701-B-37  108992  188   53.40
# 厚底人字拖                         厚底人字拖全部     HM0722-L-37   62034  240  108.29
# 手投                            女款平底        HM0738-141    97933  178   76.47
# 自投                            自投          HM0722-B-38   92989  216  113.08
# Stranded Product Ad Promotion FBA Instock HM0805-3244   59716   74   19.52
# 自投                            自投          HM0722-M-39  200312  249  120.25
#                                           HM0719-1237  118874  217  110.83
#                                           HM0733-1741  114327   66   32.67
#                                           HM0731-Z-35  139585  457  246.75
#                                           HM0724-F-35   81463  115   55.87
#                                           HM0722-B-37   57854   93   52.39
# 0701测试                        0701        HM0701-F-37   91043  199  113.73
# 自投                            自投          HM0722-H-40   86790  118   60.73
#                                           HM0738-Z-35   68778   83   45.68
#                                           HM0701-B-42   91239  219  132.68
#                                           HM0739-240    74495   76   38.39
#                                           HM0701-F-41   64980   77   39.44
#                                           HM0738-V-41   77771   82   40.43
#                                           HM0903-1636  100866  148   77.69
#                                           HM0742-0235   54143   41   25.05
#
#                                                          总销售额  总销售量  \
# 广告活动名称                        广告组名称       广告SKU
# Stranded Product Ad Promotion FBA Instock HM0701-B-37  279.81    19
# 厚底人字拖                         厚底人字拖全部     HM0722-L-37  435.74    26
# 手投                            女款平底        HM0738-141   265.13    18
# 自投                            自投          HM0722-B-38  388.77    23
# Stranded Product Ad Promotion FBA Instock HM0805-3244   62.96     4
# 自投                            自投          HM0722-M-39  362.78    22
#                                           HM0719-1237  333.79    21
#                                           HM0733-1741   94.94     6
#                                           HM0731-Z-35  690.26    44
#                                           HM0724-F-35  146.91     9
#                                           HM0722-B-37  131.92     8
# 0701测试                        0701        HM0701-F-37  281.81    19
# 自投                            自投          HM0722-H-40  149.91     9
#                                           HM0738-Z-35  107.93     7
#                                           HM0701-B-42  302.80    20
#                                           HM0739-240    79.95     5
#                                           HM0701-F-41   72.95     5
#                                           HM0738-V-41   61.96     4
#                                           HM0903-1636  101.93     7
#                                           HM0742-0235   31.98     2
#
#                                                        性价比(总销售额/花费)
# 广告活动名称                        广告组名称       广告SKU
# Stranded Product Ad Promotion FBA Instock HM0701-B-37          5.24
# 厚底人字拖                         厚底人字拖全部     HM0722-L-37          4.02
# 手投                            女款平底        HM0738-141           3.47
# 自投                            自投          HM0722-B-38          3.44
# Stranded Product Ad Promotion FBA Instock HM0805-3244          3.23
# 自投                            自投          HM0722-M-39          3.02
#                                           HM0719-1237          3.01
#                                           HM0733-1741          2.91
#                                           HM0731-Z-35          2.80
#                                           HM0724-F-35          2.63
#                                           HM0722-B-37          2.52
# 0701测试                        0701        HM0701-F-37          2.48
# 自投                            自投          HM0722-H-40          2.47
#                                           HM0738-Z-35          2.36
#                                           HM0701-B-42          2.28
#                                           HM0739-240           2.08
#                                           HM0701-F-41          1.85
#                                           HM0738-V-41          1.53
#                                           HM0903-1636          1.31
#                                           HM0742-0235          1.28

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的广告产品以及其所在的广告组。

# %% [markdown]
# ## 最具性价比的广告产品（不考虑其所在的广告组）

# %%
# Manipulating data and column names.
ap_df = workdf.groupby(['广告SKU']).sum().sort_values(by=['展现量'], ascending=False).head(20)
ap_df['总销售额'] = ap_df['7天总销售额(￥)']
ap_df['总销售量'] = ap_df['7天总销售量(#)']
ap_df = ap_df[['展现量', '点击量', '花费', '总销售额', '总销售量']]
ap_df['性价比(总销售额/花费)'] = round(ap_df['总销售额'] / ap_df['花费'], 2)

ap_df.sort_values(by=['性价比(总销售额/花费)'], ascending=False)
# Out:
#                 展现量  点击量      花费     总销售额  总销售量  性价比(总销售额/花费)
# 广告SKU
# HM0701-B-37  138411  222   71.42   381.74    26          5.35
# HM0722-B-38  103226  278  131.91   587.65    35          4.45
# HM0722-L-37  127560  456  181.05   785.53    47          4.34
# HM0731-Z-39   73221  708  256.32  1087.01    69          4.24
# HM0701-F-37  120239  320  151.29   545.93    37          3.61
# HM0738-141   133375  302  155.35   519.97    34          3.35
# HM0731-Z-35  177649  805  366.07  1219.82    78          3.33
# HM0733-1741  114813   70   33.82   110.93     7          3.28
# HM0701-H-41   80967  322  184.84   590.60    40          3.20
# HM0722-M-39  200312  249  120.25   362.78    22          3.02
# HM0719-1237  118874  217  110.83   333.79    21          3.01
# HM0724-F-35   81463  115   55.87   146.91     9          2.63
# HM0731-Z-36   91944  299  127.50   317.40    20          2.49
# HM0739-240    78144   78   39.11    95.94     6          2.45
# HM0722-H-40  112377  182   91.07   216.87    13          2.38
# HM0701-B-42   91239  219  132.68   302.80    20          2.28
# HM0738-Z-35   81226  111   55.62   123.92     8          2.23
# HM0701-F-41   64980   77   39.44    72.95     5          1.85
# HM0738-V-41   77771   82   40.43    61.96     4          1.53
# HM0903-1636  101715  150   78.36   101.93     7          1.30

# %% [markdown]
# 此表解决的问题为：
#
# - 找出最具性价比的广告产品（不考虑其所在的广告组）。

# %% [markdown]
# **[返回目录](amz_ads_catalog.ipynb)**
