# %%
# Install wheels by the magic commands below and restart at the very first time before running the following cells.
#
# %pip install pyecharts
#

# %% [markdown]
# # 柱状图/折线图/饼图（pandas数据源）

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(
    {
        '商品名称': ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子", "鞋子", "帽子"],
        '广州HM': [35, 25, 66, 39, 35, 78, 73, 55],
        '杭州美乐': [25, 33, 46, 30, 15, 46, 63, 43]
    }
)
df
# Out:
#   商品名称  广州HM  杭州美乐
# 0   衬衫    35    25
# 1  羊毛衫    25    33
# 2  雪纺衫    66    46
# 3   裤子    39    30
# 4  高跟鞋    35    15
# 5   袜子    78    46
# 6   鞋子    73    63
# 7   帽子    55    43

# %%
df.columns.to_list()
# Out:
# ['商品名称', '广州HM', '杭州美乐']

# %%
from pyecharts import options as opts
from pyecharts.globals import ThemeType

# %%
from pyecharts.charts import Bar

bar = (
    Bar(init_opts = opts.InitOpts(width="720px", height="360px", theme = ThemeType.WESTEROS))
    .add_xaxis(df['商品名称'].to_list())
    .add_yaxis("广州HM", df['广州HM'].to_list())
    .add_yaxis("杭州美乐", df['杭州美乐'].to_list())
    .set_global_opts(title_opts = opts.TitleOpts(title="柱状图测试样板主标题", subtitle="副标题测试"))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'westeros':'https://assets.pyecharts.org/assets/themes/westeros'
#         }
#     });
# </script>
#
#     <div id="a73cc61dea13415c91a40a5c7e39c8b1" style="width:720px; height:360px;"></div>
#
#
# <script>
#     require(['echarts', 'westeros'], function(echarts) {
#         var chart_a73cc61dea13415c91a40a5c7e39c8b1 = echarts.init(
#             document.getElementById('a73cc61dea13415c91a40a5c7e39c8b1'), 'westeros', {renderer: 'canvas'});
#         var option_a73cc61dea13415c91a40a5c7e39c8b1 = {
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5e7f\u5ddeHM",
#             "data": [
#                 35,
#                 25,
#                 66,
#                 39,
#                 35,
#                 78,
#                 73,
#                 55
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u676d\u5dde\u7f8e\u4e50",
#             "data": [
#                 25,
#                 33,
#                 46,
#                 30,
#                 15,
#                 46,
#                 63,
#                 43
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e7f\u5ddeHM",
#                 "\u676d\u5dde\u7f8e\u4e50"
#             ],
#             "selected": {
#                 "\u5e7f\u5ddeHM": true,
#                 "\u676d\u5dde\u7f8e\u4e50": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u978b\u5b50",
#                 "\u5e3d\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u6d4b\u8bd5\u6837\u677f\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898\u6d4b\u8bd5"
#         }
#     ]
# };
#         chart_a73cc61dea13415c91a40a5c7e39c8b1.setOption(option_a73cc61dea13415c91a40a5c7e39c8b1);
#     });
# </script>

# %%
from pyecharts.charts import Line

line = (
    Line(init_opts = opts.InitOpts(width="800px", height="400px", theme = ThemeType.ROMA))
    .add_xaxis(df['商品名称'].to_list())
    .add_yaxis("广州HM", df['广州HM'].to_list())
    .add_yaxis("杭州美乐", df['杭州美乐'].to_list())
    .set_global_opts(title_opts = opts.TitleOpts(title="折线图测试样板主标题", subtitle="副标题测试"))
)
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'roma':'https://assets.pyecharts.org/assets/themes/roma'
#         }
#     });
# </script>
#
#     <div id="cb64de76cd6b4b15bd53daddcf809c02" style="width:800px; height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'roma'], function(echarts) {
#         var chart_cb64de76cd6b4b15bd53daddcf809c02 = echarts.init(
#             document.getElementById('cb64de76cd6b4b15bd53daddcf809c02'), 'roma', {renderer: 'canvas'});
#         var option_cb64de76cd6b4b15bd53daddcf809c02 = {
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5e7f\u5ddeHM",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     35
#                 ],
#                 [
#                     "\u7f8a\u6bdb\u886b",
#                     25
#                 ],
#                 [
#                     "\u96ea\u7eba\u886b",
#                     66
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     39
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     35
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     78
#                 ],
#                 [
#                     "\u978b\u5b50",
#                     73
#                 ],
#                 [
#                     "\u5e3d\u5b50",
#                     55
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u676d\u5dde\u7f8e\u4e50",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     25
#                 ],
#                 [
#                     "\u7f8a\u6bdb\u886b",
#                     33
#                 ],
#                 [
#                     "\u96ea\u7eba\u886b",
#                     46
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     30
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     15
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     46
#                 ],
#                 [
#                     "\u978b\u5b50",
#                     63
#                 ],
#                 [
#                     "\u5e3d\u5b50",
#                     43
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e7f\u5ddeHM",
#                 "\u676d\u5dde\u7f8e\u4e50"
#             ],
#             "selected": {
#                 "\u5e7f\u5ddeHM": true,
#                 "\u676d\u5dde\u7f8e\u4e50": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u978b\u5b50",
#                 "\u5e3d\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6298\u7ebf\u56fe\u6d4b\u8bd5\u6837\u677f\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898\u6d4b\u8bd5"
#         }
#     ]
# };
#         chart_cb64de76cd6b4b15bd53daddcf809c02.setOption(option_cb64de76cd6b4b15bd53daddcf809c02);
#     });
# </script>

# %%
from pyecharts.charts import Pie

pie = (
    Pie(init_opts = opts.InitOpts(width="800px", height="400px"))
    .add(
        "", 
        [list(z) for z in zip(df['商品名称'].to_list()[2:7], df['广州HM'].to_list()[2:7])],
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="饼图测试样板"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}：{c}件"))
)

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="cd807d083c2d4dbd91e546caa88124ff" style="width:800px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_cd807d083c2d4dbd91e546caa88124ff = echarts.init(
#             document.getElementById('cd807d083c2d4dbd91e546caa88124ff'), 'white', {renderer: 'canvas'});
#         var option_cd807d083c2d4dbd91e546caa88124ff = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 35
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 78
#                 },
#                 {
#                     "name": "\u978b\u5b50",
#                     "value": 73
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}\uff1a{c}\u4ef6"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u978b\u5b50"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u997c\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_cd807d083c2d4dbd91e546caa88124ff.setOption(option_cd807d083c2d4dbd91e546caa88124ff);
#     });
# </script>

# %%
from pyecharts.charts import Radar

datadefs=[("攻击力", 100), ("防御力", 100), ("机动力", 100), ("持久力", 100), ("经济力", 100)]

datadf = pd.DataFrame(
    {
        '张小五': np.random.randint(20,100,size=5),
        '李大六': np.random.randint(20,100,size=5)
    }
)

rd = (
    Radar(init_opts = opts.InitOpts(theme = ThemeType.INFOGRAPHIC))
    .add_schema(
        schema=[opts.RadarIndicatorItem(name=datadefs[i][0], max_=datadefs[i][1]) for i in range(len(datadefs))]
    )
    .add("张小五", [datadf['张小五'].to_list()])
    .add("李大六", [datadf['李大六'].to_list()])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="雷达图测试样板"))
)

rd.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'infographic':'https://assets.pyecharts.org/assets/themes/infographic'
#         }
#     });
# </script>
#
#     <div id="19e2fe1116b14982ab49e75904c7d37e" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'infographic'], function(echarts) {
#         var chart_19e2fe1116b14982ab49e75904c7d37e = echarts.init(
#             document.getElementById('19e2fe1116b14982ab49e75904c7d37e'), 'infographic', {renderer: 'canvas'});
#         var option_19e2fe1116b14982ab49e75904c7d37e = {
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u5f20\u5c0f\u4e94",
#             "data": [
#                 [
#                     72,
#                     62,
#                     44,
#                     85,
#                     92
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u674e\u5927\u516d",
#             "data": [
#                 [
#                     96,
#                     92,
#                     92,
#                     28,
#                     35
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5f20\u5c0f\u4e94",
#                 "\u674e\u5927\u516d"
#             ],
#             "selected": {
#                 "\u5f20\u5c0f\u4e94": true,
#                 "\u674e\u5927\u516d": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radar": {
#         "indicator": [
#             {
#                 "name": "\u653b\u51fb\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u9632\u5fa1\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u673a\u52a8\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u6301\u4e45\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u7ecf\u6d4e\u529b",
#                 "max": 100
#             }
#         ],
#         "name": {
#             "textStyle": {}
#         },
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             }
#         },
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "onZero": true,
#             "onZeroAxisIndex": 0
#         }
#     },
#     "title": [
#         {
#             "text": "\u96f7\u8fbe\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_19e2fe1116b14982ab49e75904c7d37e.setOption(option_19e2fe1116b14982ab49e75904c7d37e);
#     });
# </script>

# %% [markdown]
# # 其他数据图（自定义或随机数据源）

# %%
from pyecharts.charts import Polar

po = (
    Polar(init_opts = opts.InitOpts(width="800px", height="400px"))
    .add(
        "",
        #[[0,55], [1,25], [2, 84], [3, 72], [4, 37]],
        [(i, np.random.randint(0, 100)) for i in range(20)],
        type_="effectScatter",
        effect_opts=opts.EffectOpts(scale=6, period=4),
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="极坐标随机散点图测试样板"))
)

po.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="4ebd49f5793d417b9eab649a3f4b7862" style="width:800px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_4ebd49f5793d417b9eab649a3f4b7862 = echarts.init(
#             document.getElementById('4ebd49f5793d417b9eab649a3f4b7862'), 'white', {renderer: 'canvas'});
#         var option_4ebd49f5793d417b9eab649a3f4b7862 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "polar",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 6,
#                 "period": 4
#             },
#             "symbolSize": 4,
#             "data": [
#                 [
#                     0,
#                     47
#                 ],
#                 [
#                     1,
#                     24
#                 ],
#                 [
#                     2,
#                     48
#                 ],
#                 [
#                     3,
#                     41
#                 ],
#                 [
#                     4,
#                     22
#                 ],
#                 [
#                     5,
#                     96
#                 ],
#                 [
#                     6,
#                     35
#                 ],
#                 [
#                     7,
#                     22
#                 ],
#                 [
#                     8,
#                     35
#                 ],
#                 [
#                     9,
#                     18
#                 ],
#                 [
#                     10,
#                     53
#                 ],
#                 [
#                     11,
#                     93
#                 ],
#                 [
#                     12,
#                     48
#                 ],
#                 [
#                     13,
#                     70
#                 ],
#                 [
#                     14,
#                     74
#                 ],
#                 [
#                     15,
#                     51
#                 ],
#                 [
#                     16,
#                     3
#                 ],
#                 [
#                     17,
#                     3
#                 ],
#                 [
#                     18,
#                     39
#                 ],
#                 [
#                     19,
#                     55
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radiusAxis": {
#         "scale": false
#     },
#     "angleAxis": {
#         "clockwise": false
#     },
#     "polar": {},
#     "title": [
#         {
#             "text": "\u6781\u5750\u6807\u968f\u673a\u6563\u70b9\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_4ebd49f5793d417b9eab649a3f4b7862.setOption(option_4ebd49f5793d417b9eab649a3f4b7862);
#     });
# </script>

# %%
from pyecharts.charts import Gauge

fp = 30
try:
    fp = float(input('工作进度? (0-100) '))
except ValueError as e:
    print(e)

gauge = (
    Gauge()
    .add(
        "工作进度", 
        [("百分比%", fp)],
        axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(
                    color=[(0.3, "#37ca92"), (0.7, "#67c3c0"), (1, "#f0668d")], width=30
                )
            ),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="仪表盘测试样板"))
)
gauge.render_notebook()
# Out:
# 工作进度? (0-100) 62.66
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="d885ea37339a46eaa9e6a9795fe5cb3c" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_d885ea37339a46eaa9e6a9795fe5cb3c = echarts.init(
#             document.getElementById('d885ea37339a46eaa9e6a9795fe5cb3c'), 'white', {renderer: 'canvas'});
#         var option_d885ea37339a46eaa9e6a9795fe5cb3c = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "name": "\u5de5\u4f5c\u8fdb\u5ea6",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u767e\u5206\u6bd4%",
#                     "value": 62.66
#                 }
#             ],
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 30,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": [
#                         [
#                             0.3,
#                             "#37ca92"
#                         ],
#                         [
#                             0.7,
#                             "#67c3c0"
#                         ],
#                         [
#                             1,
#                             "#f0668d"
#                         ]
#                     ]
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5de5\u4f5c\u8fdb\u5ea6"
#             ],
#             "selected": {
#                 "\u5de5\u4f5c\u8fdb\u5ea6": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4eea\u8868\u76d8\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_d885ea37339a46eaa9e6a9795fe5cb3c.setOption(option_d885ea37339a46eaa9e6a9795fe5cb3c);
#     });
# </script>

# %%
from pyecharts.charts import Liquid
from pyecharts.commons import utils

lq = (
    Liquid()
    .add(
        "工作进度", 
        [fp / 100, fp / 100],
        tooltip_opts=opts.TooltipOpts(
            formatter=utils.JsCode("""function (param) {
                return param.seriesName + ': ' + (Math.round(param.value * 10000) / 100) + '%';
            }
            """),
        )
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="水量图测试样板"))
)

lq.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#     <div id="57e49ed74f404e1c99be22f337c3aab7" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-liquidfill'], function(echarts) {
#         var chart_57e49ed74f404e1c99be22f337c3aab7 = echarts.init(
#             document.getElementById('57e49ed74f404e1c99be22f337c3aab7'), 'white', {renderer: 'canvas'});
#         var option_57e49ed74f404e1c99be22f337c3aab7 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "\u5de5\u4f5c\u8fdb\u5ea6",
#             "data": [
#                 0.6265999999999999,
#                 0.6265999999999999
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "formatter": function (param) {                return param.seriesName + ': ' + (Math.round(param.value * 10000) / 100) + '%';            }            ,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6c34\u91cf\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_57e49ed74f404e1c99be22f337c3aab7.setOption(option_57e49ed74f404e1c99be22f337c3aab7);
#     });
# </script>

# %%
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType

words =('张三丰','Hello World','网红李','河边小草','打包件','王八蛋','笑死我','哈哈哈','有间客栈','解放军','中美关系','贸易战','中国航母')

wordsfrequency = [(words[i], np.random.randint(500,5000)) for i in range(len(words))]
wc = (
    WordCloud()
    .add(
        "",
        wordsfrequency,
        # 词云图轮廓，有 'ARROW', 'DIAMOND', 'RECT', 'ROUND_RECT', 'TRIANGLE'可选
        shape=SymbolType.DIAMOND
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="词云样板"))
)

print(wordsfrequency)
wc.render_notebook()
# Out:
# [('张三丰', 3935), ('Hello World', 1065), ('网红李', 4907), ('河边小草', 2979), ('打包件', 4255), ('王八蛋', 1917), ('笑死我', 4239), ('哈哈哈', 2808), ('有间客栈', 2455), ('解放军', 3210), ('中美关系', 3884), ('贸易战', 3844), ('中国航母', 3763)]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#     <div id="b9744f12270d45fb8690aad829953711" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-wordcloud'], function(echarts) {
#         var chart_b9744f12270d45fb8690aad829953711 = echarts.init(
#             document.getElementById('b9744f12270d45fb8690aad829953711'), 'white', {renderer: 'canvas'});
#         var option_b9744f12270d45fb8690aad829953711 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "\u5f20\u4e09\u4e30",
#                     "value": 3935,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,58,58)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Hello World",
#                     "value": 1065,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(62,145,134)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f51\u7ea2\u674e",
#                     "value": 4907,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,120,154)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6cb3\u8fb9\u5c0f\u8349",
#                     "value": 2979,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,115,25)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6253\u5305\u4ef6",
#                     "value": 4255,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(116,120,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u738b\u516b\u86cb",
#                     "value": 1917,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,122,84)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7b11\u6b7b\u6211",
#                     "value": 4239,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(89,68,92)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u54c8\u54c8\u54c8",
#                     "value": 2808,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(67,67,131)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6709\u95f4\u5ba2\u6808",
#                     "value": 2455,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(62,148,154)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u89e3\u653e\u519b",
#                     "value": 3210,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(97,120,95)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u7f8e\u5173\u7cfb",
#                     "value": 3884,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,8,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8d38\u6613\u6218",
#                     "value": 3844,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(82,118,34)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u56fd\u822a\u6bcd",
#                     "value": 3763,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,41,0)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u8bcd\u4e91\u6837\u677f"
#         }
#     ]
# };
#         chart_b9744f12270d45fb8690aad829953711.setOption(option_b9744f12270d45fb8690aad829953711);
#     });
# </script>

# %%
import random
from pyecharts.charts import Scatter3D

sd3 = (
    Scatter3D()
    .add(
        "", 
        [[random.randint(0, 100), random.randint(0, 100), random.randint(0, 100)] for _ in range(30)],
        grid3d_opts = opts.Grid3DOpts(width=100, height=100, depth=100)
    )
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="三维散点图测试样板")
    )
)

sd3.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min'
#         }
#     });
# </script>
#
#     <div id="c297106d2b6c45c880130aae70f91f57" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-gl'], function(echarts) {
#         var chart_c297106d2b6c45c880130aae70f91f57 = echarts.init(
#             document.getElementById('c297106d2b6c45c880130aae70f91f57'), 'white', {renderer: 'canvas'});
#         var option_c297106d2b6c45c880130aae70f91f57 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter3D",
#             "data": [
#                 [
#                     98,
#                     82,
#                     5
#                 ],
#                 [
#                     66,
#                     48,
#                     49
#                 ],
#                 [
#                     15,
#                     45,
#                     17
#                 ],
#                 [
#                     30,
#                     9,
#                     9
#                 ],
#                 [
#                     22,
#                     25,
#                     74
#                 ],
#                 [
#                     11,
#                     24,
#                     28
#                 ],
#                 [
#                     46,
#                     45,
#                     56
#                 ],
#                 [
#                     74,
#                     86,
#                     77
#                 ],
#                 [
#                     0,
#                     36,
#                     64
#                 ],
#                 [
#                     89,
#                     68,
#                     37
#                 ],
#                 [
#                     69,
#                     99,
#                     14
#                 ],
#                 [
#                     27,
#                     55,
#                     63
#                 ],
#                 [
#                     95,
#                     27,
#                     26
#                 ],
#                 [
#                     6,
#                     57,
#                     78
#                 ],
#                 [
#                     59,
#                     54,
#                     59
#                 ],
#                 [
#                     15,
#                     100,
#                     1
#                 ],
#                 [
#                     17,
#                     5,
#                     28
#                 ],
#                 [
#                     81,
#                     95,
#                     80
#                 ],
#                 [
#                     77,
#                     45,
#                     89
#                 ],
#                 [
#                     33,
#                     35,
#                     36
#                 ],
#                 [
#                     3,
#                     0,
#                     43
#                 ],
#                 [
#                     80,
#                     56,
#                     5
#                 ],
#                 [
#                     99,
#                     66,
#                     41
#                 ],
#                 [
#                     93,
#                     51,
#                     40
#                 ],
#                 [
#                     94,
#                     59,
#                     17
#                 ],
#                 [
#                     30,
#                     82,
#                     25
#                 ],
#                 [
#                     43,
#                     91,
#                     58
#                 ],
#                 [
#                     40,
#                     20,
#                     47
#                 ],
#                 [
#                     40,
#                     2,
#                     50
#                 ],
#                 [
#                     99,
#                     9,
#                     49
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     },
#     "xAxis3D": {
#         "nameGap": 20,
#         "type": "category",
#         "axisLabel": {
#             "margin": 8
#         }
#     },
#     "yAxis3D": {
#         "nameGap": 20,
#         "type": "category",
#         "axisLabel": {
#             "margin": 8
#         }
#     },
#     "zAxis3D": {
#         "nameGap": 20,
#         "type": "value",
#         "axisLabel": {
#             "margin": 8
#         }
#     },
#     "grid3D": {
#         "boxWidth": 100,
#         "boxHeight": 100,
#         "boxDepth": 100,
#         "viewControl": {
#             "autoRotate": false,
#             "autoRotateSpeed": 10,
#             "rotateSensitivity": 1
#         }
#     },
#     "title": [
#         {
#             "text": "\u4e09\u7ef4\u6563\u70b9\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_c297106d2b6c45c880130aae70f91f57.setOption(option_c297106d2b6c45c880130aae70f91f57);
#     });
# </script>

# %% [markdown]
# # 地理图表
#
# ## pyecharts地图数据链接
#
# ### [中国常用城市地图代码 maptype](https://github.com/pyecharts/pyecharts/blob/master/pyecharts/datasets/map_filename.json)
#
# ### [中国常用城市地图坐标数据](https://github.com/pyecharts/pyecharts/blob/master/pyecharts/datasets/city_coordinates.json)
#
# ### [世界各国地理代码](https://github.com/pyecharts/pyecharts/blob/master/pyecharts/datasets/countries_regions_db.json)

# %% [markdown]
# ## Geo Object

# %% [markdown]
# ### Random Data Initialization

# %%
cites = ["广东", "北京", "上海", "兰州", "台北", "乌鲁木齐", "西安", "成都", "哈尔滨"]

# 注意： 
#
# 因np.random.randint生成的数列元素数据类型为NumPy int类型(numpy.int64, 而非pyecharts能够识别的Python int类型。
# 故此需要使用int(i)进行二次封装转换成Python int类型数列。
#
citiesdataset = [list(x) for x in zip(cites, [int(i) for i in np.random.randint(1, 100, size=len(cites))])]
print(citiesdataset)
# Out:
# [['广东', 74], ['北京', 59], ['上海', 27], ['兰州', 55], ['台北', 58], ['乌鲁木齐', 1], ['西安', 72], ['成都', 53], ['哈尔滨', 69]]

# %% [markdown]
# ### Geo Samples

# %%
from pyecharts.charts import Geo
from pyecharts.globals import ChartType

geo1 = (
    Geo()
    .add(
        "关注度", 
        # [['台北', 96], ['广州', 45], ['北京', 34], ['上海', 85]],
        citiesdataset,
        type_=ChartType.EFFECT_SCATTER
    )
    .add_schema(maptype="china")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(is_piecewise=True),
        title_opts=opts.TitleOpts(title="地理图表Geo基本示例"))
)

geo1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="7d5dada665d5421c88827932dce78c8f" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_7d5dada665d5421c88827932dce78c8f = echarts.init(
#             document.getElementById('7d5dada665d5421c88827932dce78c8f'), 'white', {renderer: 'canvas'});
#         var option_7d5dada665d5421c88827932dce78c8f = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "\u5173\u6ce8\u5ea6",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         74
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         59
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         27
#                     ]
#                 },
#                 {
#                     "name": "\u5170\u5dde",
#                     "value": [
#                         103.73,
#                         36.03,
#                         55
#                     ]
#                 },
#                 {
#                     "name": "\u53f0\u5317",
#                     "value": [
#                         121.3,
#                         25.03,
#                         58
#                     ]
#                 },
#                 {
#                     "name": "\u4e4c\u9c81\u6728\u9f50",
#                     "value": [
#                         87.68,
#                         43.77,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         72
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         53
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         69
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5173\u6ce8\u5ea6"
#             ],
#             "selected": {
#                 "\u5173\u6ce8\u5ea6": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5730\u7406\u56fe\u8868Geo\u57fa\u672c\u793a\u4f8b"
#         }
#     ],
#     "visualMap": {
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#         chart_7d5dada665d5421c88827932dce78c8f.setOption(option_7d5dada665d5421c88827932dce78c8f);
#     });
# </script>

# %%
geo2 = (
    Geo()
    .add(
        "关注度", 
        citiesdataset,
        type_=ChartType.HEATMAP
    )
    .add_schema(maptype="china")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="地理图表Geo热力图示例"))
)

geo2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="5c9fedb1a00e442faa6830ba239836d5" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_5c9fedb1a00e442faa6830ba239836d5 = echarts.init(
#             document.getElementById('5c9fedb1a00e442faa6830ba239836d5'), 'white', {renderer: 'canvas'});
#         var option_5c9fedb1a00e442faa6830ba239836d5 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u5173\u6ce8\u5ea6",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         74
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         59
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         27
#                     ]
#                 },
#                 {
#                     "name": "\u5170\u5dde",
#                     "value": [
#                         103.73,
#                         36.03,
#                         55
#                     ]
#                 },
#                 {
#                     "name": "\u53f0\u5317",
#                     "value": [
#                         121.3,
#                         25.03,
#                         58
#                     ]
#                 },
#                 {
#                     "name": "\u4e4c\u9c81\u6728\u9f50",
#                     "value": [
#                         87.68,
#                         43.77,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         72
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         53
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         69
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5173\u6ce8\u5ea6"
#             ],
#             "selected": {
#                 "\u5173\u6ce8\u5ea6": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5730\u7406\u56fe\u8868Geo\u70ed\u529b\u56fe\u793a\u4f8b"
#         }
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#         chart_5c9fedb1a00e442faa6830ba239836d5.setOption(option_5c9fedb1a00e442faa6830ba239836d5);
#     });
# </script>

# %% [markdown]
# ## Map Object

# %% [markdown]
# ### Random Data Initialization

# %%
provinces = ["广东", "北京", "上海", "浙江", "新疆", "四川", "湖北", "内蒙古", "黑龙江"]

# 注意： 
#
# 因np.random.randint生成的数列元素数据类型为NumPy int类型(numpy.int64, 而非pyecharts能够识别的Python int类型。
# 故此需要使用int(i)进行二次封装转换成Python int类型数列。
#
provincesdataset = [list(x) for x in zip(provinces, [int(i) for i in np.random.randint(100, 1000, size=len(provinces))])]
print(provincesdataset)
# Out:
# [['广东', 856], ['北京', 781], ['上海', 947], ['浙江', 772], ['新疆', 210], ['四川', 174], ['湖北', 541], ['内蒙古', 395], ['黑龙江', 952]]

# %% [markdown]
# ### Map Samples

# %%
from pyecharts.charts import Map

map1 = (
    Map()
    .add(
        "Map关注度", 
        provincesdataset,
        "china"
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(
            min_=100, 
            max_=1000, 
            is_piecewise=True,
            split_number=6,
            range_color=["#EEFFEE", "#003F00"]
        ),
        title_opts=opts.TitleOpts(title="地理图表Map基本示例")
    )
)

map1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="d6937d888d4543439cb611f2423539d4" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_d6937d888d4543439cb611f2423539d4 = echarts.init(
#             document.getElementById('d6937d888d4543439cb611f2423539d4'), 'white', {renderer: 'canvas'});
#         var option_d6937d888d4543439cb611f2423539d4 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Map\u5173\u6ce8\u5ea6",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 856
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 781
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 947
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 772
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 210
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 174
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 541
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 395
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 952
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Map\u5173\u6ce8\u5ea6"
#             ],
#             "selected": {
#                 "Map\u5173\u6ce8\u5ea6": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5730\u7406\u56fe\u8868Map\u57fa\u672c\u793a\u4f8b"
#         }
#     ],
#     "visualMap": {
#         "type": "piecewise",
#         "min": 100,
#         "max": 1000,
#         "inRange": {
#             "color": [
#                 "#EEFFEE",
#                 "#003F00"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 6,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#         chart_d6937d888d4543439cb611f2423539d4.setOption(option_d6937d888d4543439cb611f2423539d4);
#     });
# </script>

# %%
map2 = (
    Map()
    .add(
        "", 
        [],
        "world",
        is_roam = False,
        center = [90,25],
        zoom = 2.5
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        # visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="地理图表Map基本示例（世界地图-亚洲主要地区）")
    )
)

map2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#     <div id="9b47f66026b14ae9a0a0af7c2f2d267f" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'world'], function(echarts) {
#         var chart_9b47f66026b14ae9a0a0af7c2f2d267f = echarts.init(
#             document.getElementById('9b47f66026b14ae9a0a0af7c2f2d267f'), 'white', {renderer: 'canvas'});
#         var option_9b47f66026b14ae9a0a0af7c2f2d267f = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [],
#             "roam": false,
#             "center": [
#                 90,
#                 25
#             ],
#             "zoom": 2.5,
#             "showLegendSymbol": true,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5730\u7406\u56fe\u8868Map\u57fa\u672c\u793a\u4f8b\uff08\u4e16\u754c\u5730\u56fe-\u4e9a\u6d32\u4e3b\u8981\u5730\u533a\uff09"
#         }
#     ]
# };
#         chart_9b47f66026b14ae9a0a0af7c2f2d267f.setOption(option_9b47f66026b14ae9a0a0af7c2f2d267f);
#     });
# </script>
