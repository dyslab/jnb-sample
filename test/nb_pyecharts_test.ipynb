# %%
# Install wheels by the magic commands below and restart at the very first time before running the following cells.
#
# %pip install pyecharts
#

# %% [markdown]
# # 柱状图/折线图/饼图（pandas数据源）

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(
    {
        '商品名称': ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子", "鞋子", "帽子"],
        '广州HM': [35, 25, 66, 39, 35, 78, 73, 55],
        '杭州美乐': [25, 33, 46, 30, 15, 46, 63, 43]
    }
)
df
# Out:
#   商品名称  广州HM  杭州美乐
# 0   衬衫    35    25
# 1  羊毛衫    25    33
# 2  雪纺衫    66    46
# 3   裤子    39    30
# 4  高跟鞋    35    15
# 5   袜子    78    46
# 6   鞋子    73    63
# 7   帽子    55    43

# %%
df.columns.to_list()
# Out:
# ['商品名称', '广州HM', '杭州美乐']

# %%
from pyecharts import options as opts
from pyecharts.globals import ThemeType

# %%
from pyecharts.charts import Bar

bar = (
    Bar(init_opts = opts.InitOpts(width="720px", height="360px", theme = ThemeType.WESTEROS))
    .add_xaxis(df['商品名称'].to_list())
    .add_yaxis("广州HM", df['广州HM'].to_list())
    .add_yaxis("杭州美乐", df['杭州美乐'].to_list())
    .set_global_opts(title_opts = opts.TitleOpts(title="柱状图测试样板主标题", subtitle="副标题测试"))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'westeros':'https://assets.pyecharts.org/assets/themes/westeros'
#         }
#     });
# </script>
#
#     <div id="635eea09a5144c9c9d9bc8838d5cdc2b" style="width:720px; height:360px;"></div>
#
#
# <script>
#     require(['echarts', 'westeros'], function(echarts) {
#         var chart_635eea09a5144c9c9d9bc8838d5cdc2b = echarts.init(
#             document.getElementById('635eea09a5144c9c9d9bc8838d5cdc2b'), 'westeros', {renderer: 'canvas'});
#         var option_635eea09a5144c9c9d9bc8838d5cdc2b = {
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5e7f\u5ddeHM",
#             "data": [
#                 35,
#                 25,
#                 66,
#                 39,
#                 35,
#                 78,
#                 73,
#                 55
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u676d\u5dde\u7f8e\u4e50",
#             "data": [
#                 25,
#                 33,
#                 46,
#                 30,
#                 15,
#                 46,
#                 63,
#                 43
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e7f\u5ddeHM",
#                 "\u676d\u5dde\u7f8e\u4e50"
#             ],
#             "selected": {
#                 "\u5e7f\u5ddeHM": true,
#                 "\u676d\u5dde\u7f8e\u4e50": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u978b\u5b50",
#                 "\u5e3d\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u6d4b\u8bd5\u6837\u677f\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898\u6d4b\u8bd5"
#         }
#     ]
# };
#         chart_635eea09a5144c9c9d9bc8838d5cdc2b.setOption(option_635eea09a5144c9c9d9bc8838d5cdc2b);
#     });
# </script>

# %%
from pyecharts.charts import Line

line = (
    Line(init_opts = opts.InitOpts(width="800px", height="400px", theme = ThemeType.ROMA))
    .add_xaxis(df['商品名称'].to_list())
    .add_yaxis("广州HM", df['广州HM'].to_list())
    .add_yaxis("杭州美乐", df['杭州美乐'].to_list())
    .set_global_opts(title_opts = opts.TitleOpts(title="折线图测试样板主标题", subtitle="副标题测试"))
)
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'roma':'https://assets.pyecharts.org/assets/themes/roma'
#         }
#     });
# </script>
#
#     <div id="8d4348fe73b2458ea87db850443eeeae" style="width:800px; height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'roma'], function(echarts) {
#         var chart_8d4348fe73b2458ea87db850443eeeae = echarts.init(
#             document.getElementById('8d4348fe73b2458ea87db850443eeeae'), 'roma', {renderer: 'canvas'});
#         var option_8d4348fe73b2458ea87db850443eeeae = {
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5e7f\u5ddeHM",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     35
#                 ],
#                 [
#                     "\u7f8a\u6bdb\u886b",
#                     25
#                 ],
#                 [
#                     "\u96ea\u7eba\u886b",
#                     66
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     39
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     35
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     78
#                 ],
#                 [
#                     "\u978b\u5b50",
#                     73
#                 ],
#                 [
#                     "\u5e3d\u5b50",
#                     55
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u676d\u5dde\u7f8e\u4e50",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     25
#                 ],
#                 [
#                     "\u7f8a\u6bdb\u886b",
#                     33
#                 ],
#                 [
#                     "\u96ea\u7eba\u886b",
#                     46
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     30
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     15
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     46
#                 ],
#                 [
#                     "\u978b\u5b50",
#                     63
#                 ],
#                 [
#                     "\u5e3d\u5b50",
#                     43
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e7f\u5ddeHM",
#                 "\u676d\u5dde\u7f8e\u4e50"
#             ],
#             "selected": {
#                 "\u5e7f\u5ddeHM": true,
#                 "\u676d\u5dde\u7f8e\u4e50": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u978b\u5b50",
#                 "\u5e3d\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6298\u7ebf\u56fe\u6d4b\u8bd5\u6837\u677f\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898\u6d4b\u8bd5"
#         }
#     ]
# };
#         chart_8d4348fe73b2458ea87db850443eeeae.setOption(option_8d4348fe73b2458ea87db850443eeeae);
#     });
# </script>

# %%
from pyecharts.charts import Pie

pie = (
    Pie(init_opts = opts.InitOpts(width="800px", height="400px"))
    .add(
        "", 
        [list(z) for z in zip(df['商品名称'].to_list()[2:7], df['广州HM'].to_list()[2:7])],
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="饼图测试样板"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}：{c}件"))
)

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="e359c88a6d7c49a3ad6fa34b725be690" style="width:800px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_e359c88a6d7c49a3ad6fa34b725be690 = echarts.init(
#             document.getElementById('e359c88a6d7c49a3ad6fa34b725be690'), 'white', {renderer: 'canvas'});
#         var option_e359c88a6d7c49a3ad6fa34b725be690 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 35
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 78
#                 },
#                 {
#                     "name": "\u978b\u5b50",
#                     "value": 73
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}\uff1a{c}\u4ef6"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u978b\u5b50"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u997c\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_e359c88a6d7c49a3ad6fa34b725be690.setOption(option_e359c88a6d7c49a3ad6fa34b725be690);
#     });
# </script>

# %%
from pyecharts.charts import Radar

datadefs=[("攻击力", 100), ("防御力", 100), ("机动力", 100), ("持久力", 100), ("经济力", 100)]

datadf = pd.DataFrame(
    {
        '张小五': np.random.randint(20,100,size=5),
        '李大六': np.random.randint(20,100,size=5)
    }
)

rd = (
    Radar(init_opts = opts.InitOpts(theme = ThemeType.INFOGRAPHIC))
    .add_schema(
        schema=[opts.RadarIndicatorItem(name=datadefs[i][0], max_=datadefs[i][1]) for i in range(len(datadefs))]
    )
    .add("张小五", [datadf['张小五'].to_list()])
    .add("李大六", [datadf['李大六'].to_list()])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="雷达图测试样板"))
)

rd.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'infographic':'https://assets.pyecharts.org/assets/themes/infographic'
#         }
#     });
# </script>
#
#     <div id="3245affa4ded49cb8a6a7d13cda5c58d" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'infographic'], function(echarts) {
#         var chart_3245affa4ded49cb8a6a7d13cda5c58d = echarts.init(
#             document.getElementById('3245affa4ded49cb8a6a7d13cda5c58d'), 'infographic', {renderer: 'canvas'});
#         var option_3245affa4ded49cb8a6a7d13cda5c58d = {
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u5f20\u5c0f\u4e94",
#             "data": [
#                 [
#                     52,
#                     32,
#                     47,
#                     63,
#                     77
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u674e\u5927\u516d",
#             "data": [
#                 [
#                     70,
#                     95,
#                     25,
#                     80,
#                     43
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5f20\u5c0f\u4e94",
#                 "\u674e\u5927\u516d"
#             ],
#             "selected": {
#                 "\u5f20\u5c0f\u4e94": true,
#                 "\u674e\u5927\u516d": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radar": {
#         "indicator": [
#             {
#                 "name": "\u653b\u51fb\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u9632\u5fa1\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u673a\u52a8\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u6301\u4e45\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u7ecf\u6d4e\u529b",
#                 "max": 100
#             }
#         ],
#         "name": {
#             "textStyle": {}
#         },
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             }
#         },
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "onZero": true,
#             "onZeroAxisIndex": 0
#         }
#     },
#     "title": [
#         {
#             "text": "\u96f7\u8fbe\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_3245affa4ded49cb8a6a7d13cda5c58d.setOption(option_3245affa4ded49cb8a6a7d13cda5c58d);
#     });
# </script>

# %% [markdown]
# # 其他数据图（自定义或随机数据源）

# %%
from pyecharts.charts import Polar

po = (
    Polar(init_opts = opts.InitOpts(width="800px", height="400px"))
    .add(
        "",
        #[[0,55], [1,25], [2, 84], [3, 72], [4, 37]],
        [(i, np.random.randint(0, 100)) for i in range(20)],
        type_="effectScatter",
        effect_opts=opts.EffectOpts(scale=6, period=4),
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="极坐标随机散点图测试样板"))
)

po.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="4ab5915da1a04d019b55838946ffa555" style="width:800px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_4ab5915da1a04d019b55838946ffa555 = echarts.init(
#             document.getElementById('4ab5915da1a04d019b55838946ffa555'), 'white', {renderer: 'canvas'});
#         var option_4ab5915da1a04d019b55838946ffa555 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "polar",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 6,
#                 "period": 4
#             },
#             "symbolSize": 4,
#             "data": [
#                 [
#                     0,
#                     6
#                 ],
#                 [
#                     1,
#                     77
#                 ],
#                 [
#                     2,
#                     21
#                 ],
#                 [
#                     3,
#                     90
#                 ],
#                 [
#                     4,
#                     29
#                 ],
#                 [
#                     5,
#                     95
#                 ],
#                 [
#                     6,
#                     95
#                 ],
#                 [
#                     7,
#                     21
#                 ],
#                 [
#                     8,
#                     15
#                 ],
#                 [
#                     9,
#                     85
#                 ],
#                 [
#                     10,
#                     76
#                 ],
#                 [
#                     11,
#                     7
#                 ],
#                 [
#                     12,
#                     76
#                 ],
#                 [
#                     13,
#                     27
#                 ],
#                 [
#                     14,
#                     80
#                 ],
#                 [
#                     15,
#                     40
#                 ],
#                 [
#                     16,
#                     38
#                 ],
#                 [
#                     17,
#                     27
#                 ],
#                 [
#                     18,
#                     79
#                 ],
#                 [
#                     19,
#                     57
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radiusAxis": {
#         "scale": false
#     },
#     "angleAxis": {
#         "clockwise": false
#     },
#     "polar": {},
#     "title": [
#         {
#             "text": "\u6781\u5750\u6807\u968f\u673a\u6563\u70b9\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_4ab5915da1a04d019b55838946ffa555.setOption(option_4ab5915da1a04d019b55838946ffa555);
#     });
# </script>

# %%
from pyecharts.charts import Gauge

fp = 30
try:
    fp = float(input('工作进度? (0-100) '))
except ValueError as e:
    print(e)

gauge = (
    Gauge()
    .add(
        "工作进度", 
        [("百分比%", fp)],
        axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(
                    color=[(0.3, "#37ca92"), (0.7, "#67c3c0"), (1, "#f0668d")], width=30
                )
            ),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="仪表盘测试样板"))
)
gauge.render_notebook()
# Out:
# 工作进度? (0-100) 61.2
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="fe409777e1734c85ac7d1d141d129edb" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_fe409777e1734c85ac7d1d141d129edb = echarts.init(
#             document.getElementById('fe409777e1734c85ac7d1d141d129edb'), 'white', {renderer: 'canvas'});
#         var option_fe409777e1734c85ac7d1d141d129edb = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "name": "\u5de5\u4f5c\u8fdb\u5ea6",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u767e\u5206\u6bd4%",
#                     "value": 61.2
#                 }
#             ],
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 30,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": [
#                         [
#                             0.3,
#                             "#37ca92"
#                         ],
#                         [
#                             0.7,
#                             "#67c3c0"
#                         ],
#                         [
#                             1,
#                             "#f0668d"
#                         ]
#                     ]
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5de5\u4f5c\u8fdb\u5ea6"
#             ],
#             "selected": {
#                 "\u5de5\u4f5c\u8fdb\u5ea6": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4eea\u8868\u76d8\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_fe409777e1734c85ac7d1d141d129edb.setOption(option_fe409777e1734c85ac7d1d141d129edb);
#     });
# </script>

# %%
from pyecharts.charts import Liquid
from pyecharts.commons import utils

lq = (
    Liquid()
    .add(
        "工作进度", 
        [fp / 100, fp / 100],
        tooltip_opts=opts.TooltipOpts(
            formatter=utils.JsCode("""function (param) {
                return param.seriesName + ': ' + (Math.round(param.value * 10000) / 100) + '%';
            }
            """),
        )
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="水量图测试样板"))
)

lq.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#     <div id="a9de21c5ee5d4d7c8bda1f5fb82cb069" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-liquidfill'], function(echarts) {
#         var chart_a9de21c5ee5d4d7c8bda1f5fb82cb069 = echarts.init(
#             document.getElementById('a9de21c5ee5d4d7c8bda1f5fb82cb069'), 'white', {renderer: 'canvas'});
#         var option_a9de21c5ee5d4d7c8bda1f5fb82cb069 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "\u5de5\u4f5c\u8fdb\u5ea6",
#             "data": [
#                 0.612,
#                 0.612
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "formatter": function (param) {                return param.seriesName + ': ' + (Math.round(param.value * 10000) / 100) + '%';            }            ,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6c34\u91cf\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_a9de21c5ee5d4d7c8bda1f5fb82cb069.setOption(option_a9de21c5ee5d4d7c8bda1f5fb82cb069);
#     });
# </script>

# %%
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType

words =('张三丰','Hello World','网红李','河边小草','打包件','王八蛋','笑死我','哈哈哈','有间客栈','解放军','中美关系','贸易战','中国航母')

wordsfrequency = [(words[i], np.random.randint(500,5000)) for i in range(len(words))]
wc = (
    WordCloud()
    .add(
        "",
        wordsfrequency,
        # 词云图轮廓，有 'ARROW', 'DIAMOND', 'RECT', 'ROUND_RECT', 'TRIANGLE'可选
        shape=SymbolType.DIAMOND
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="词云样板"))
)

print(wordsfrequency)
wc.render_notebook()
# Out:
# [('张三丰', 808), ('Hello World', 2987), ('网红李', 2999), ('河边小草', 2512), ('打包件', 4125), ('王八蛋', 3521), ('笑死我', 1296), ('哈哈哈', 4308), ('有间客栈', 2882), ('解放军', 725), ('中美关系', 4615), ('贸易战', 1470), ('中国航母', 4836)]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#     <div id="0459fbe5479c44adb47fc10f74b302f0" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-wordcloud'], function(echarts) {
#         var chart_0459fbe5479c44adb47fc10f74b302f0 = echarts.init(
#             document.getElementById('0459fbe5479c44adb47fc10f74b302f0'), 'white', {renderer: 'canvas'});
#         var option_0459fbe5479c44adb47fc10f74b302f0 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "\u5f20\u4e09\u4e30",
#                     "value": 808,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(33,51,67)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Hello World",
#                     "value": 2987,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(140,160,88)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f51\u7ea2\u674e",
#                     "value": 2999,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(70,4,60)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6cb3\u8fb9\u5c0f\u8349",
#                     "value": 2512,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(103,58,102)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6253\u5305\u4ef6",
#                     "value": 4125,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(104,14,108)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u738b\u516b\u86cb",
#                     "value": 3521,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(135,155,132)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7b11\u6b7b\u6211",
#                     "value": 1296,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,50,105)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u54c8\u54c8\u54c8",
#                     "value": 4308,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(63,73,73)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6709\u95f4\u5ba2\u6808",
#                     "value": 2882,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,30,141)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u89e3\u653e\u519b",
#                     "value": 725,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(74,58,20)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u7f8e\u5173\u7cfb",
#                     "value": 4615,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(92,46,143)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8d38\u6613\u6218",
#                     "value": 1470,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(25,126,38)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u56fd\u822a\u6bcd",
#                     "value": 4836,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(45,66,126)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u8bcd\u4e91\u6837\u677f"
#         }
#     ]
# };
#         chart_0459fbe5479c44adb47fc10f74b302f0.setOption(option_0459fbe5479c44adb47fc10f74b302f0);
#     });
# </script>

# %% [markdown]
# # 地理图表
#
# ## pyecharts地图数据链接
#
# ### [中国常用城市地图代码 maptype](https://github.com/pyecharts/pyecharts/blob/master/pyecharts/datasets/map_filename.json)
#
# ### [中国常用城市地图坐标数据](https://github.com/pyecharts/pyecharts/blob/master/pyecharts/datasets/city_coordinates.json)
#
# ### [世界各国地理代码](https://github.com/pyecharts/pyecharts/blob/master/pyecharts/datasets/countries_regions_db.json)
