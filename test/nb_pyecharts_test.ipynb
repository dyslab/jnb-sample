# %%
# Install wheels by the magic commands below and restart at the very first time before running the following cells.
#
# %pip install pyecharts
#

# %% [markdown]
# # 柱状图/折线图/饼图（pandas数据源）

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(
    {
        '商品名称': ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子", "鞋子", "帽子"],
        '广州HM': [35, 25, 66, 39, 35, 78, 73, 55],
        '杭州美乐': [25, 33, 46, 30, 15, 46, 63, 43]
    }
)
df
# Out:
#   商品名称  广州HM  杭州美乐
# 0   衬衫    35    25
# 1  羊毛衫    25    33
# 2  雪纺衫    66    46
# 3   裤子    39    30
# 4  高跟鞋    35    15
# 5   袜子    78    46
# 6   鞋子    73    63
# 7   帽子    55    43

# %%
df.columns.to_list()
# Out:
# ['商品名称', '广州HM', '杭州美乐']

# %%
from pyecharts import options as opts
from pyecharts.globals import ThemeType

# %%
from pyecharts.charts import Bar

bar = (
    Bar(init_opts = opts.InitOpts(width="720px", height="360px", theme = ThemeType.WESTEROS))
    .add_xaxis(df['商品名称'].to_list())
    .add_yaxis("广州HM", df['广州HM'].to_list())
    .add_yaxis("杭州美乐", df['杭州美乐'].to_list())
    .set_global_opts(title_opts = opts.TitleOpts(title="柱状图测试样板主标题", subtitle="副标题测试"))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'westeros':'https://assets.pyecharts.org/assets/themes/westeros'
#         }
#     });
# </script>
#
#     <div id="7c42f4d87b7148d0a3b061fe488a57ee" style="width:720px; height:360px;"></div>
#
#
# <script>
#     require(['echarts', 'westeros'], function(echarts) {
#         var chart_7c42f4d87b7148d0a3b061fe488a57ee = echarts.init(
#             document.getElementById('7c42f4d87b7148d0a3b061fe488a57ee'), 'westeros', {renderer: 'canvas'});
#         var option_7c42f4d87b7148d0a3b061fe488a57ee = {
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5e7f\u5ddeHM",
#             "data": [
#                 35,
#                 25,
#                 66,
#                 39,
#                 35,
#                 78,
#                 73,
#                 55
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u676d\u5dde\u7f8e\u4e50",
#             "data": [
#                 25,
#                 33,
#                 46,
#                 30,
#                 15,
#                 46,
#                 63,
#                 43
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e7f\u5ddeHM",
#                 "\u676d\u5dde\u7f8e\u4e50"
#             ],
#             "selected": {
#                 "\u5e7f\u5ddeHM": true,
#                 "\u676d\u5dde\u7f8e\u4e50": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u978b\u5b50",
#                 "\u5e3d\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u6d4b\u8bd5\u6837\u677f\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898\u6d4b\u8bd5"
#         }
#     ]
# };
#         chart_7c42f4d87b7148d0a3b061fe488a57ee.setOption(option_7c42f4d87b7148d0a3b061fe488a57ee);
#     });
# </script>

# %%
from pyecharts.charts import Line

line = (
    Line(init_opts = opts.InitOpts(width="800px", height="400px", theme = ThemeType.ROMA))
    .add_xaxis(df['商品名称'].to_list())
    .add_yaxis("广州HM", df['广州HM'].to_list())
    .add_yaxis("杭州美乐", df['杭州美乐'].to_list())
    .set_global_opts(title_opts = opts.TitleOpts(title="折线图测试样板主标题", subtitle="副标题测试"))
)
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'roma':'https://assets.pyecharts.org/assets/themes/roma'
#         }
#     });
# </script>
#
#     <div id="c49b08953e8342eb949f8a551cf55468" style="width:800px; height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'roma'], function(echarts) {
#         var chart_c49b08953e8342eb949f8a551cf55468 = echarts.init(
#             document.getElementById('c49b08953e8342eb949f8a551cf55468'), 'roma', {renderer: 'canvas'});
#         var option_c49b08953e8342eb949f8a551cf55468 = {
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5e7f\u5ddeHM",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     35
#                 ],
#                 [
#                     "\u7f8a\u6bdb\u886b",
#                     25
#                 ],
#                 [
#                     "\u96ea\u7eba\u886b",
#                     66
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     39
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     35
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     78
#                 ],
#                 [
#                     "\u978b\u5b50",
#                     73
#                 ],
#                 [
#                     "\u5e3d\u5b50",
#                     55
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u676d\u5dde\u7f8e\u4e50",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     25
#                 ],
#                 [
#                     "\u7f8a\u6bdb\u886b",
#                     33
#                 ],
#                 [
#                     "\u96ea\u7eba\u886b",
#                     46
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     30
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     15
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     46
#                 ],
#                 [
#                     "\u978b\u5b50",
#                     63
#                 ],
#                 [
#                     "\u5e3d\u5b50",
#                     43
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e7f\u5ddeHM",
#                 "\u676d\u5dde\u7f8e\u4e50"
#             ],
#             "selected": {
#                 "\u5e7f\u5ddeHM": true,
#                 "\u676d\u5dde\u7f8e\u4e50": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u978b\u5b50",
#                 "\u5e3d\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6298\u7ebf\u56fe\u6d4b\u8bd5\u6837\u677f\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898\u6d4b\u8bd5"
#         }
#     ]
# };
#         chart_c49b08953e8342eb949f8a551cf55468.setOption(option_c49b08953e8342eb949f8a551cf55468);
#     });
# </script>

# %%
from pyecharts.charts import Pie

pie = (
    Pie(init_opts = opts.InitOpts(width="800px", height="400px"))
    .add(
        "", 
        [list(z) for z in zip(df['商品名称'].to_list()[2:7], df['广州HM'].to_list()[2:7])],
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="饼图测试样板"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}：{c}件"))
)

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="9ab19dcab79c458586d40737d1a4eb89" style="width:800px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_9ab19dcab79c458586d40737d1a4eb89 = echarts.init(
#             document.getElementById('9ab19dcab79c458586d40737d1a4eb89'), 'white', {renderer: 'canvas'});
#         var option_9ab19dcab79c458586d40737d1a4eb89 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 35
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 78
#                 },
#                 {
#                     "name": "\u978b\u5b50",
#                     "value": 73
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}\uff1a{c}\u4ef6"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u978b\u5b50"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u997c\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_9ab19dcab79c458586d40737d1a4eb89.setOption(option_9ab19dcab79c458586d40737d1a4eb89);
#     });
# </script>

# %%
from pyecharts.charts import Radar

datadefs=[("攻击力", 100), ("防御力", 100), ("机动力", 100), ("持久力", 100), ("经济力", 100)]

datadf = pd.DataFrame(
    {
        '张小五': np.random.randint(20,100,size=5),
        '李大六': np.random.randint(20,100,size=5)
    }
)

rd = (
    Radar(init_opts = opts.InitOpts(theme = ThemeType.INFOGRAPHIC))
    .add_schema(
        schema=[opts.RadarIndicatorItem(name=datadefs[i][0], max_=datadefs[i][1]) for i in range(len(datadefs))]
    )
    .add("张小五", [datadf['张小五'].to_list()])
    .add("李大六", [datadf['李大六'].to_list()])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="雷达图测试样板"))
)

rd.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'infographic':'https://assets.pyecharts.org/assets/themes/infographic'
#         }
#     });
# </script>
#
#     <div id="3eb3a6c5b85a4a919bdf9016254585c7" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'infographic'], function(echarts) {
#         var chart_3eb3a6c5b85a4a919bdf9016254585c7 = echarts.init(
#             document.getElementById('3eb3a6c5b85a4a919bdf9016254585c7'), 'infographic', {renderer: 'canvas'});
#         var option_3eb3a6c5b85a4a919bdf9016254585c7 = {
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u5f20\u5c0f\u4e94",
#             "data": [
#                 [
#                     40,
#                     66,
#                     76,
#                     68,
#                     20
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u674e\u5927\u516d",
#             "data": [
#                 [
#                     48,
#                     24,
#                     61,
#                     64,
#                     60
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5f20\u5c0f\u4e94",
#                 "\u674e\u5927\u516d"
#             ],
#             "selected": {
#                 "\u5f20\u5c0f\u4e94": true,
#                 "\u674e\u5927\u516d": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radar": {
#         "indicator": [
#             {
#                 "name": "\u653b\u51fb\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u9632\u5fa1\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u673a\u52a8\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u6301\u4e45\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u7ecf\u6d4e\u529b",
#                 "max": 100
#             }
#         ],
#         "name": {
#             "textStyle": {}
#         },
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             }
#         },
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "onZero": true,
#             "onZeroAxisIndex": 0
#         }
#     },
#     "title": [
#         {
#             "text": "\u96f7\u8fbe\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_3eb3a6c5b85a4a919bdf9016254585c7.setOption(option_3eb3a6c5b85a4a919bdf9016254585c7);
#     });
# </script>

# %% [markdown]
# # 其他数据图（自定义或随机数据源）

# %%
from pyecharts.charts import Polar

po = (
    Polar(init_opts = opts.InitOpts(width="800px", height="400px"))
    .add(
        "",
        #[[0,55], [1,25], [2, 84], [3, 72], [4, 37]],
        [(i, np.random.randint(0, 100)) for i in range(20)],
        type_="effectScatter",
        effect_opts=opts.EffectOpts(scale=6, period=4),
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="极坐标随机散点图测试样板"))
)

po.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="8a944a1b84af42fe9b41fd21c16a890f" style="width:800px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_8a944a1b84af42fe9b41fd21c16a890f = echarts.init(
#             document.getElementById('8a944a1b84af42fe9b41fd21c16a890f'), 'white', {renderer: 'canvas'});
#         var option_8a944a1b84af42fe9b41fd21c16a890f = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "polar",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 6,
#                 "period": 4
#             },
#             "symbolSize": 4,
#             "data": [
#                 [
#                     0,
#                     15
#                 ],
#                 [
#                     1,
#                     28
#                 ],
#                 [
#                     2,
#                     69
#                 ],
#                 [
#                     3,
#                     19
#                 ],
#                 [
#                     4,
#                     3
#                 ],
#                 [
#                     5,
#                     8
#                 ],
#                 [
#                     6,
#                     3
#                 ],
#                 [
#                     7,
#                     97
#                 ],
#                 [
#                     8,
#                     60
#                 ],
#                 [
#                     9,
#                     80
#                 ],
#                 [
#                     10,
#                     35
#                 ],
#                 [
#                     11,
#                     99
#                 ],
#                 [
#                     12,
#                     26
#                 ],
#                 [
#                     13,
#                     53
#                 ],
#                 [
#                     14,
#                     40
#                 ],
#                 [
#                     15,
#                     29
#                 ],
#                 [
#                     16,
#                     73
#                 ],
#                 [
#                     17,
#                     89
#                 ],
#                 [
#                     18,
#                     84
#                 ],
#                 [
#                     19,
#                     4
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radiusAxis": {
#         "scale": false
#     },
#     "angleAxis": {
#         "clockwise": false
#     },
#     "polar": {},
#     "title": [
#         {
#             "text": "\u6781\u5750\u6807\u968f\u673a\u6563\u70b9\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_8a944a1b84af42fe9b41fd21c16a890f.setOption(option_8a944a1b84af42fe9b41fd21c16a890f);
#     });
# </script>

# %%
from pyecharts.charts import Gauge

fp = 30
try:
    fp = float(input('工作进度? (0-100) '))
except ValueError as e:
    print(e)

gauge = (
    Gauge()
    .add(
        "工作进度", 
        [("百分比%", fp)],
        axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(
                    color=[(0.3, "#37ca92"), (0.7, "#67c3c0"), (1, "#f0668d")], width=30
                )
            ),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="仪表盘测试样板"))
)
gauge.render_notebook()
# Out:
# 工作进度? (0-100) 43.8
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="b0457086c26e4c31b357eea47c498228" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_b0457086c26e4c31b357eea47c498228 = echarts.init(
#             document.getElementById('b0457086c26e4c31b357eea47c498228'), 'white', {renderer: 'canvas'});
#         var option_b0457086c26e4c31b357eea47c498228 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "name": "\u5de5\u4f5c\u8fdb\u5ea6",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u767e\u5206\u6bd4%",
#                     "value": 43.8
#                 }
#             ],
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 30,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": [
#                         [
#                             0.3,
#                             "#37ca92"
#                         ],
#                         [
#                             0.7,
#                             "#67c3c0"
#                         ],
#                         [
#                             1,
#                             "#f0668d"
#                         ]
#                     ]
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5de5\u4f5c\u8fdb\u5ea6"
#             ],
#             "selected": {
#                 "\u5de5\u4f5c\u8fdb\u5ea6": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4eea\u8868\u76d8\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_b0457086c26e4c31b357eea47c498228.setOption(option_b0457086c26e4c31b357eea47c498228);
#     });
# </script>

# %%
from pyecharts.charts import Liquid
from pyecharts.commons import utils

lq = (
    Liquid()
    .add(
        "工作进度", 
        [fp / 100, fp / 100],
        tooltip_opts=opts.TooltipOpts(
            formatter=utils.JsCode("""function (param) {
                return param.seriesName + ': ' + (Math.round(param.value * 10000) / 100) + '%';
            }
            """),
        )
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="水量图测试样板"))
)

lq.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#     <div id="6dd12a6cccc645889bf5ea97c73071b0" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-liquidfill'], function(echarts) {
#         var chart_6dd12a6cccc645889bf5ea97c73071b0 = echarts.init(
#             document.getElementById('6dd12a6cccc645889bf5ea97c73071b0'), 'white', {renderer: 'canvas'});
#         var option_6dd12a6cccc645889bf5ea97c73071b0 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "\u5de5\u4f5c\u8fdb\u5ea6",
#             "data": [
#                 0.43799999999999994,
#                 0.43799999999999994
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "formatter": function (param) {                return param.seriesName + ': ' + (Math.round(param.value * 10000) / 100) + '%';            }            ,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6c34\u91cf\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_6dd12a6cccc645889bf5ea97c73071b0.setOption(option_6dd12a6cccc645889bf5ea97c73071b0);
#     });
# </script>

# %%
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType

words =('张三丰','Hello World','网红李','河边小草','打包件','王八蛋','笑死我','哈哈哈','有间客栈','解放军','中美关系','贸易战','中国航母')

wordsfrequency = [(words[i], np.random.randint(500,5000)) for i in range(len(words))]
wc = (
    WordCloud()
    .add(
        "",
        wordsfrequency,
        # 词云图轮廓，有 'ARROW', 'DIAMOND', 'RECT', 'ROUND_RECT', 'TRIANGLE'可选
        shape=SymbolType.DIAMOND
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="词云样板"))
)

print(wordsfrequency)
wc.render_notebook()
# Out:
# [('张三丰', 1871), ('Hello World', 2153), ('网红李', 578), ('河边小草', 2958), ('打包件', 2869), ('王八蛋', 633), ('笑死我', 1889), ('哈哈哈', 1852), ('有间客栈', 3528), ('解放军', 4044), ('中美关系', 980), ('贸易战', 757), ('中国航母', 4313)]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#     <div id="9a94f18e56724acf8c0711be298c9d17" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-wordcloud'], function(echarts) {
#         var chart_9a94f18e56724acf8c0711be298c9d17 = echarts.init(
#             document.getElementById('9a94f18e56724acf8c0711be298c9d17'), 'white', {renderer: 'canvas'});
#         var option_9a94f18e56724acf8c0711be298c9d17 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "\u5f20\u4e09\u4e30",
#                     "value": 1871,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,120,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Hello World",
#                     "value": 2153,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(33,0,83)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f51\u7ea2\u674e",
#                     "value": 578,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,152,14)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6cb3\u8fb9\u5c0f\u8349",
#                     "value": 2958,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,13,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6253\u5305\u4ef6",
#                     "value": 2869,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(68,51,50)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u738b\u516b\u86cb",
#                     "value": 633,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,153,76)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7b11\u6b7b\u6211",
#                     "value": 1889,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,42,66)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u54c8\u54c8\u54c8",
#                     "value": 1852,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(11,63,103)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6709\u95f4\u5ba2\u6808",
#                     "value": 3528,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,127,91)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u89e3\u653e\u519b",
#                     "value": 4044,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,147,2)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u7f8e\u5173\u7cfb",
#                     "value": 980,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(30,16,100)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8d38\u6613\u6218",
#                     "value": 757,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(7,8,141)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u56fd\u822a\u6bcd",
#                     "value": 4313,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(57,79,49)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u8bcd\u4e91\u6837\u677f"
#         }
#     ]
# };
#         chart_9a94f18e56724acf8c0711be298c9d17.setOption(option_9a94f18e56724acf8c0711be298c9d17);
#     });
# </script>

# %% [markdown]
# # 地理图表
#
# ## pyecharts地图数据链接
#
# ### [中国常用城市地图代码 maptype](https://github.com/pyecharts/pyecharts/blob/master/pyecharts/datasets/map_filename.json)
#
# ### [中国常用城市地图坐标数据](https://github.com/pyecharts/pyecharts/blob/master/pyecharts/datasets/city_coordinates.json)
#
# ### [世界各国地理代码](https://github.com/pyecharts/pyecharts/blob/master/pyecharts/datasets/countries_regions_db.json)

# %% [markdown]
# ## Geo Object

# %% [markdown]
# ### Random Data Initialization

# %%
cites = ["广州", "北京", "上海", "兰州", "台北", "乌鲁木齐", "西安", "成都", "哈尔滨"]

# 注意： 
#
# 因np.random.randint生成的数列元素数据类型为NumPy int类型(numpy.int64, 而非pyecharts能够识别的Python int类型。
# 故此需要使用int(i)进行二次封装转换成Python int类型数列。
#
citiesdataset = [list(x) for x in zip(cites, [int(i) for i in np.random.randint(1, 100, size=len(cites))])]
print(citiesdataset)
# Out:
# [['广州', 22], ['北京', 19], ['上海', 83], ['兰州', 11], ['台北', 10], ['乌鲁木齐', 37], ['西安', 27], ['成都', 96], ['哈尔滨', 97]]

# %% [markdown]
# ### Geo Samples

# %%
from pyecharts.charts import Geo
from pyecharts.globals import ChartType

geo1 = (
    Geo()
    .add(
        "关注度", 
        # [['台北', 96], ['广州', 45], ['北京', 34], ['上海', 85]],
        citiesdataset,
        type_=ChartType.EFFECT_SCATTER
    )
    .add_schema(maptype="china")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(is_piecewise=True),
        title_opts=opts.TitleOpts(title="地理图表基本示例"))
)

geo1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="91ce8c4d63aa4ac1909bb3fc9e7a4855" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_91ce8c4d63aa4ac1909bb3fc9e7a4855 = echarts.init(
#             document.getElementById('91ce8c4d63aa4ac1909bb3fc9e7a4855'), 'white', {renderer: 'canvas'});
#         var option_91ce8c4d63aa4ac1909bb3fc9e7a4855 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "\u5173\u6ce8\u5ea6",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         22
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         19
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         83
#                     ]
#                 },
#                 {
#                     "name": "\u5170\u5dde",
#                     "value": [
#                         103.73,
#                         36.03,
#                         11
#                     ]
#                 },
#                 {
#                     "name": "\u53f0\u5317",
#                     "value": [
#                         121.3,
#                         25.03,
#                         10
#                     ]
#                 },
#                 {
#                     "name": "\u4e4c\u9c81\u6728\u9f50",
#                     "value": [
#                         87.68,
#                         43.77,
#                         37
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         27
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         96
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         97
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5173\u6ce8\u5ea6"
#             ],
#             "selected": {
#                 "\u5173\u6ce8\u5ea6": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5730\u7406\u56fe\u8868\u57fa\u672c\u793a\u4f8b"
#         }
#     ],
#     "visualMap": {
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#         chart_91ce8c4d63aa4ac1909bb3fc9e7a4855.setOption(option_91ce8c4d63aa4ac1909bb3fc9e7a4855);
#     });
# </script>

# %%
geo2 = (
    Geo()
    .add(
        "关注度", 
        citiesdataset,
        type_=ChartType.HEATMAP
    )
    .add_schema(maptype="china")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="地理图表-热力图示例"))
)

geo2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="e72e655de5e149d7a2d0d5213d1ec609" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_e72e655de5e149d7a2d0d5213d1ec609 = echarts.init(
#             document.getElementById('e72e655de5e149d7a2d0d5213d1ec609'), 'white', {renderer: 'canvas'});
#         var option_e72e655de5e149d7a2d0d5213d1ec609 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u5173\u6ce8\u5ea6",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         22
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         19
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         83
#                     ]
#                 },
#                 {
#                     "name": "\u5170\u5dde",
#                     "value": [
#                         103.73,
#                         36.03,
#                         11
#                     ]
#                 },
#                 {
#                     "name": "\u53f0\u5317",
#                     "value": [
#                         121.3,
#                         25.03,
#                         10
#                     ]
#                 },
#                 {
#                     "name": "\u4e4c\u9c81\u6728\u9f50",
#                     "value": [
#                         87.68,
#                         43.77,
#                         37
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         27
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         96
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         97
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5173\u6ce8\u5ea6"
#             ],
#             "selected": {
#                 "\u5173\u6ce8\u5ea6": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5730\u7406\u56fe\u8868-\u70ed\u529b\u56fe\u793a\u4f8b"
#         }
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#         chart_e72e655de5e149d7a2d0d5213d1ec609.setOption(option_e72e655de5e149d7a2d0d5213d1ec609);
#     });
# </script>

# %% [markdown]
# ## Map Object

# %% [markdown]
# ### Map Samples
