# %%
# Install wheels by the magic commands below and restart at the very first time before running the following cells.
#
# %pip install pyecharts
#

# %% [markdown]
# # 柱状图/折线图/饼图（pandas数据源）

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(
    {
        '商品名称': ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子", "鞋子", "帽子"],
        '广州HM': [35, 25, 66, 39, 35, 78, 73, 55],
        '杭州美乐': [25, 33, 46, 30, 15, 46, 63, 43]
    }
)
df
# Out:
#   商品名称  广州HM  杭州美乐
# 0   衬衫    35    25
# 1  羊毛衫    25    33
# 2  雪纺衫    66    46
# 3   裤子    39    30
# 4  高跟鞋    35    15
# 5   袜子    78    46
# 6   鞋子    73    63
# 7   帽子    55    43

# %%
df.columns.to_list()
# Out:
# ['商品名称', '广州HM', '杭州美乐']

# %%
from pyecharts import options as opts
from pyecharts.globals import ThemeType

# %%
from pyecharts.charts import Bar

bar = (
    Bar(init_opts = opts.InitOpts(width="720px", height="360px", theme = ThemeType.WESTEROS))
    .add_xaxis(df['商品名称'].to_list())
    .add_yaxis("广州HM", df['广州HM'].to_list())
    .add_yaxis("杭州美乐", df['杭州美乐'].to_list())
    .set_global_opts(title_opts = opts.TitleOpts(title="柱状图测试样板主标题", subtitle="副标题测试"))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'westeros':'https://assets.pyecharts.org/assets/themes/westeros'
#         }
#     });
# </script>
#
#     <div id="022975ee3e7540cbaa6c2e61b5084ae5" style="width:720px; height:360px;"></div>
#
#
# <script>
#     require(['echarts', 'westeros'], function(echarts) {
#         var chart_022975ee3e7540cbaa6c2e61b5084ae5 = echarts.init(
#             document.getElementById('022975ee3e7540cbaa6c2e61b5084ae5'), 'westeros', {renderer: 'canvas'});
#         var option_022975ee3e7540cbaa6c2e61b5084ae5 = {
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5e7f\u5ddeHM",
#             "data": [
#                 35,
#                 25,
#                 66,
#                 39,
#                 35,
#                 78,
#                 73,
#                 55
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u676d\u5dde\u7f8e\u4e50",
#             "data": [
#                 25,
#                 33,
#                 46,
#                 30,
#                 15,
#                 46,
#                 63,
#                 43
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e7f\u5ddeHM",
#                 "\u676d\u5dde\u7f8e\u4e50"
#             ],
#             "selected": {
#                 "\u5e7f\u5ddeHM": true,
#                 "\u676d\u5dde\u7f8e\u4e50": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u978b\u5b50",
#                 "\u5e3d\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u6d4b\u8bd5\u6837\u677f\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898\u6d4b\u8bd5"
#         }
#     ]
# };
#         chart_022975ee3e7540cbaa6c2e61b5084ae5.setOption(option_022975ee3e7540cbaa6c2e61b5084ae5);
#     });
# </script>

# %%
from pyecharts.charts import Line

line = (
    Line(init_opts = opts.InitOpts(width="800px", height="400px", theme = ThemeType.ROMA))
    .add_xaxis(df['商品名称'].to_list())
    .add_yaxis("广州HM", df['广州HM'].to_list())
    .add_yaxis("杭州美乐", df['杭州美乐'].to_list())
    .set_global_opts(title_opts = opts.TitleOpts(title="折线图测试样板主标题", subtitle="副标题测试"))
)
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'roma':'https://assets.pyecharts.org/assets/themes/roma'
#         }
#     });
# </script>
#
#     <div id="2442cb4ea1b84a5dba7333d79b9935c2" style="width:800px; height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'roma'], function(echarts) {
#         var chart_2442cb4ea1b84a5dba7333d79b9935c2 = echarts.init(
#             document.getElementById('2442cb4ea1b84a5dba7333d79b9935c2'), 'roma', {renderer: 'canvas'});
#         var option_2442cb4ea1b84a5dba7333d79b9935c2 = {
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5e7f\u5ddeHM",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     35
#                 ],
#                 [
#                     "\u7f8a\u6bdb\u886b",
#                     25
#                 ],
#                 [
#                     "\u96ea\u7eba\u886b",
#                     66
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     39
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     35
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     78
#                 ],
#                 [
#                     "\u978b\u5b50",
#                     73
#                 ],
#                 [
#                     "\u5e3d\u5b50",
#                     55
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u676d\u5dde\u7f8e\u4e50",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     25
#                 ],
#                 [
#                     "\u7f8a\u6bdb\u886b",
#                     33
#                 ],
#                 [
#                     "\u96ea\u7eba\u886b",
#                     46
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     30
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     15
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     46
#                 ],
#                 [
#                     "\u978b\u5b50",
#                     63
#                 ],
#                 [
#                     "\u5e3d\u5b50",
#                     43
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e7f\u5ddeHM",
#                 "\u676d\u5dde\u7f8e\u4e50"
#             ],
#             "selected": {
#                 "\u5e7f\u5ddeHM": true,
#                 "\u676d\u5dde\u7f8e\u4e50": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u978b\u5b50",
#                 "\u5e3d\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6298\u7ebf\u56fe\u6d4b\u8bd5\u6837\u677f\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898\u6d4b\u8bd5"
#         }
#     ]
# };
#         chart_2442cb4ea1b84a5dba7333d79b9935c2.setOption(option_2442cb4ea1b84a5dba7333d79b9935c2);
#     });
# </script>

# %%
from pyecharts.charts import Pie

pie = (
    Pie(init_opts = opts.InitOpts(width="800px", height="400px"))
    .add(
        "", 
        [list(z) for z in zip(df['商品名称'].to_list()[2:7], df['广州HM'].to_list()[2:7])],
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="饼图测试样板"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}：{c}件"))
)

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="ac36f31cf8cc43d4b20ba7180b372f0d" style="width:800px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_ac36f31cf8cc43d4b20ba7180b372f0d = echarts.init(
#             document.getElementById('ac36f31cf8cc43d4b20ba7180b372f0d'), 'white', {renderer: 'canvas'});
#         var option_ac36f31cf8cc43d4b20ba7180b372f0d = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 35
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 78
#                 },
#                 {
#                     "name": "\u978b\u5b50",
#                     "value": 73
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}\uff1a{c}\u4ef6"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u978b\u5b50"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u997c\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_ac36f31cf8cc43d4b20ba7180b372f0d.setOption(option_ac36f31cf8cc43d4b20ba7180b372f0d);
#     });
# </script>

# %%
from pyecharts.charts import Radar

datadefs=[("攻击力", 100), ("防御力", 100), ("机动力", 100), ("持久力", 100), ("经济力", 100)]

datadf = pd.DataFrame(
    {
        '张小五': np.random.randint(20,100,size=5),
        '李大六': np.random.randint(20,100,size=5)
    }
)

rd = (
    Radar(init_opts = opts.InitOpts(theme = ThemeType.INFOGRAPHIC))
    .add_schema(
        schema=[opts.RadarIndicatorItem(name=datadefs[i][0], max_=datadefs[i][1]) for i in range(len(datadefs))]
    )
    .add("张小五", [datadf['张小五'].to_list()])
    .add("李大六", [datadf['李大六'].to_list()])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="雷达图测试样板"))
)

rd.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'infographic':'https://assets.pyecharts.org/assets/themes/infographic'
#         }
#     });
# </script>
#
#     <div id="7f6a89a45c4241f38527c8c9dc20774a" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'infographic'], function(echarts) {
#         var chart_7f6a89a45c4241f38527c8c9dc20774a = echarts.init(
#             document.getElementById('7f6a89a45c4241f38527c8c9dc20774a'), 'infographic', {renderer: 'canvas'});
#         var option_7f6a89a45c4241f38527c8c9dc20774a = {
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u5f20\u5c0f\u4e94",
#             "data": [
#                 [
#                     60,
#                     46,
#                     80,
#                     48,
#                     65
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u674e\u5927\u516d",
#             "data": [
#                 [
#                     68,
#                     90,
#                     68,
#                     61,
#                     56
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5f20\u5c0f\u4e94",
#                 "\u674e\u5927\u516d"
#             ],
#             "selected": {
#                 "\u5f20\u5c0f\u4e94": true,
#                 "\u674e\u5927\u516d": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radar": {
#         "indicator": [
#             {
#                 "name": "\u653b\u51fb\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u9632\u5fa1\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u673a\u52a8\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u6301\u4e45\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u7ecf\u6d4e\u529b",
#                 "max": 100
#             }
#         ],
#         "name": {
#             "textStyle": {}
#         },
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             }
#         },
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "onZero": true,
#             "onZeroAxisIndex": 0
#         }
#     },
#     "title": [
#         {
#             "text": "\u96f7\u8fbe\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_7f6a89a45c4241f38527c8c9dc20774a.setOption(option_7f6a89a45c4241f38527c8c9dc20774a);
#     });
# </script>

# %% [markdown]
# # 其他数据图（自定义或随机数据源）

# %%
from pyecharts.charts import Polar

po = (
    Polar(init_opts = opts.InitOpts(width="800px", height="400px"))
    .add(
        "",
        #[[0,55], [1,25], [2, 84], [3, 72], [4, 37]],
        [(i, np.random.randint(0, 100)) for i in range(20)],
        type_="effectScatter",
        effect_opts=opts.EffectOpts(scale=6, period=4),
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="极坐标随机散点图测试样板"))
)

po.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="d8960c686ef34951b5d90a7493b2018c" style="width:800px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_d8960c686ef34951b5d90a7493b2018c = echarts.init(
#             document.getElementById('d8960c686ef34951b5d90a7493b2018c'), 'white', {renderer: 'canvas'});
#         var option_d8960c686ef34951b5d90a7493b2018c = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "polar",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 6,
#                 "period": 4
#             },
#             "symbolSize": 4,
#             "data": [
#                 [
#                     0,
#                     66
#                 ],
#                 [
#                     1,
#                     78
#                 ],
#                 [
#                     2,
#                     54
#                 ],
#                 [
#                     3,
#                     62
#                 ],
#                 [
#                     4,
#                     7
#                 ],
#                 [
#                     5,
#                     72
#                 ],
#                 [
#                     6,
#                     29
#                 ],
#                 [
#                     7,
#                     96
#                 ],
#                 [
#                     8,
#                     64
#                 ],
#                 [
#                     9,
#                     11
#                 ],
#                 [
#                     10,
#                     61
#                 ],
#                 [
#                     11,
#                     38
#                 ],
#                 [
#                     12,
#                     67
#                 ],
#                 [
#                     13,
#                     54
#                 ],
#                 [
#                     14,
#                     38
#                 ],
#                 [
#                     15,
#                     18
#                 ],
#                 [
#                     16,
#                     23
#                 ],
#                 [
#                     17,
#                     96
#                 ],
#                 [
#                     18,
#                     28
#                 ],
#                 [
#                     19,
#                     74
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radiusAxis": {
#         "scale": false
#     },
#     "angleAxis": {
#         "clockwise": false
#     },
#     "polar": {},
#     "title": [
#         {
#             "text": "\u6781\u5750\u6807\u968f\u673a\u6563\u70b9\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_d8960c686ef34951b5d90a7493b2018c.setOption(option_d8960c686ef34951b5d90a7493b2018c);
#     });
# </script>

# %%
from pyecharts.charts import Gauge

fp = 30
try:
    fp = float(input('工作进度? (0-100) '))
except ValueError as e:
    print(e)

gauge = (
    Gauge()
    .add(
        "工作进度", 
        [("百分比%", fp)],
        axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(
                    color=[(0.3, "#37ca92"), (0.7, "#67c3c0"), (1, "#f0668d")], width=30
                )
            ),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="仪表盘测试样板"))
)
gauge.render_notebook()
# Out:
# 工作进度? (0-100) 66
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="76ee5ee2075f4b7ea8992f4abec04005" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_76ee5ee2075f4b7ea8992f4abec04005 = echarts.init(
#             document.getElementById('76ee5ee2075f4b7ea8992f4abec04005'), 'white', {renderer: 'canvas'});
#         var option_76ee5ee2075f4b7ea8992f4abec04005 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "name": "\u5de5\u4f5c\u8fdb\u5ea6",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u767e\u5206\u6bd4%",
#                     "value": 66.0
#                 }
#             ],
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 30,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": [
#                         [
#                             0.3,
#                             "#37ca92"
#                         ],
#                         [
#                             0.7,
#                             "#67c3c0"
#                         ],
#                         [
#                             1,
#                             "#f0668d"
#                         ]
#                     ]
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5de5\u4f5c\u8fdb\u5ea6"
#             ],
#             "selected": {
#                 "\u5de5\u4f5c\u8fdb\u5ea6": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4eea\u8868\u76d8\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_76ee5ee2075f4b7ea8992f4abec04005.setOption(option_76ee5ee2075f4b7ea8992f4abec04005);
#     });
# </script>

# %%
from pyecharts.charts import Liquid
from pyecharts.commons import utils

lq = (
    Liquid()
    .add(
        "工作进度", 
        [fp / 100, fp / 100],
        tooltip_opts=opts.TooltipOpts(
            formatter=utils.JsCode("""function (param) {
                return param.seriesName + ': ' + (Math.round(param.value * 10000) / 100) + '%';
            }
            """),
        )
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="水量图测试样板"))
)

lq.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#     <div id="9da96fd687e04365969ed127b5e8cd1c" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-liquidfill'], function(echarts) {
#         var chart_9da96fd687e04365969ed127b5e8cd1c = echarts.init(
#             document.getElementById('9da96fd687e04365969ed127b5e8cd1c'), 'white', {renderer: 'canvas'});
#         var option_9da96fd687e04365969ed127b5e8cd1c = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "\u5de5\u4f5c\u8fdb\u5ea6",
#             "data": [
#                 0.66,
#                 0.66
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "formatter": function (param) {                return param.seriesName + ': ' + (Math.round(param.value * 10000) / 100) + '%';            }            ,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6c34\u91cf\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#         chart_9da96fd687e04365969ed127b5e8cd1c.setOption(option_9da96fd687e04365969ed127b5e8cd1c);
#     });
# </script>

# %%
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType

words =('张三丰','Hello World','网红李','河边小草','打包件','王八蛋','笑死我','哈哈哈','有间客栈','解放军','中美关系','贸易战','中国航母')

wordsfrequency = [(words[i], np.random.randint(500,5000)) for i in range(len(words))]
wc = (
    WordCloud()
    .add(
        "",
        wordsfrequency,
        # 词云图轮廓，有 'ARROW', 'DIAMOND', 'RECT', 'ROUND_RECT', 'TRIANGLE'可选
        shape=SymbolType.DIAMOND
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="词云样板"))
)

print(wordsfrequency)
wc.render_notebook()
# Out:
# [('张三丰', 4833), ('Hello World', 3091), ('网红李', 4909), ('河边小草', 1896), ('打包件', 4601), ('王八蛋', 3203), ('笑死我', 1217), ('哈哈哈', 2217), ('有间客栈', 704), ('解放军', 1088), ('中美关系', 3599), ('贸易战', 4601), ('中国航母', 3753)]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#     <div id="cb92be897d45420ab3d7f73e6224cb40" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-wordcloud'], function(echarts) {
#         var chart_cb92be897d45420ab3d7f73e6224cb40 = echarts.init(
#             document.getElementById('cb92be897d45420ab3d7f73e6224cb40'), 'white', {renderer: 'canvas'});
#         var option_cb92be897d45420ab3d7f73e6224cb40 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "\u5f20\u4e09\u4e30",
#                     "value": 4833,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,157,91)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Hello World",
#                     "value": 3091,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,141,103)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f51\u7ea2\u674e",
#                     "value": 4909,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(78,19,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6cb3\u8fb9\u5c0f\u8349",
#                     "value": 1896,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,30,117)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6253\u5305\u4ef6",
#                     "value": 4601,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(150,127,140)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u738b\u516b\u86cb",
#                     "value": 3203,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(131,61,125)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7b11\u6b7b\u6211",
#                     "value": 1217,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(100,133,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u54c8\u54c8\u54c8",
#                     "value": 2217,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(133,122,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6709\u95f4\u5ba2\u6808",
#                     "value": 704,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(11,74,145)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u89e3\u653e\u519b",
#                     "value": 1088,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(38,110,110)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u7f8e\u5173\u7cfb",
#                     "value": 3599,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(140,144,61)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8d38\u6613\u6218",
#                     "value": 4601,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(10,95,129)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u56fd\u822a\u6bcd",
#                     "value": 3753,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(80,87,60)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u8bcd\u4e91\u6837\u677f"
#         }
#     ]
# };
#         chart_cb92be897d45420ab3d7f73e6224cb40.setOption(option_cb92be897d45420ab3d7f73e6224cb40);
#     });
# </script>

# %% [markdown]
# # 地理图表
#
# ## pyecharts地图数据链接
#
# ### [中国常用城市地图代码 maptype](https://github.com/pyecharts/pyecharts/blob/master/pyecharts/datasets/map_filename.json)
#
# ### [中国常用城市地图坐标数据](https://github.com/pyecharts/pyecharts/blob/master/pyecharts/datasets/city_coordinates.json)
#
# ### [世界各国地理代码](https://github.com/pyecharts/pyecharts/blob/master/pyecharts/datasets/countries_regions_db.json)

# %% [markdown]
# ## Geo Object

# %% [markdown]
# ### Random Data Initialization

# %%
cites = ["广东", "北京", "上海", "兰州", "台北", "乌鲁木齐", "西安", "成都", "哈尔滨"]

# 注意： 
#
# 因np.random.randint生成的数列元素数据类型为NumPy int类型(numpy.int64, 而非pyecharts能够识别的Python int类型。
# 故此需要使用int(i)进行二次封装转换成Python int类型数列。
#
citiesdataset = [list(x) for x in zip(cites, [int(i) for i in np.random.randint(1, 100, size=len(cites))])]
print(citiesdataset)
# Out:
# [['广东', 45], ['北京', 96], ['上海', 10], ['兰州', 8], ['台北', 91], ['乌鲁木齐', 23], ['西安', 69], ['成都', 55], ['哈尔滨', 49]]

# %% [markdown]
# ### Geo Samples

# %%
from pyecharts.charts import Geo
from pyecharts.globals import ChartType

geo1 = (
    Geo()
    .add(
        "关注度", 
        # [['台北', 96], ['广州', 45], ['北京', 34], ['上海', 85]],
        citiesdataset,
        type_=ChartType.EFFECT_SCATTER
    )
    .add_schema(maptype="china")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(is_piecewise=True),
        title_opts=opts.TitleOpts(title="地理图表Geo基本示例"))
)

geo1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="2dd6d4ae02d74975b018e7fd0ea8edc3" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_2dd6d4ae02d74975b018e7fd0ea8edc3 = echarts.init(
#             document.getElementById('2dd6d4ae02d74975b018e7fd0ea8edc3'), 'white', {renderer: 'canvas'});
#         var option_2dd6d4ae02d74975b018e7fd0ea8edc3 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "\u5173\u6ce8\u5ea6",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         45
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         96
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         10
#                     ]
#                 },
#                 {
#                     "name": "\u5170\u5dde",
#                     "value": [
#                         103.73,
#                         36.03,
#                         8
#                     ]
#                 },
#                 {
#                     "name": "\u53f0\u5317",
#                     "value": [
#                         121.3,
#                         25.03,
#                         91
#                     ]
#                 },
#                 {
#                     "name": "\u4e4c\u9c81\u6728\u9f50",
#                     "value": [
#                         87.68,
#                         43.77,
#                         23
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         69
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         55
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         49
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5173\u6ce8\u5ea6"
#             ],
#             "selected": {
#                 "\u5173\u6ce8\u5ea6": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5730\u7406\u56fe\u8868Geo\u57fa\u672c\u793a\u4f8b"
#         }
#     ],
#     "visualMap": {
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#         chart_2dd6d4ae02d74975b018e7fd0ea8edc3.setOption(option_2dd6d4ae02d74975b018e7fd0ea8edc3);
#     });
# </script>

# %%
geo2 = (
    Geo()
    .add(
        "关注度", 
        citiesdataset,
        type_=ChartType.HEATMAP
    )
    .add_schema(maptype="china")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="地理图表Geo热力图示例"))
)

geo2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="ba005918b7044f278a942018780ed9b3" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_ba005918b7044f278a942018780ed9b3 = echarts.init(
#             document.getElementById('ba005918b7044f278a942018780ed9b3'), 'white', {renderer: 'canvas'});
#         var option_ba005918b7044f278a942018780ed9b3 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u5173\u6ce8\u5ea6",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         45
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         96
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         10
#                     ]
#                 },
#                 {
#                     "name": "\u5170\u5dde",
#                     "value": [
#                         103.73,
#                         36.03,
#                         8
#                     ]
#                 },
#                 {
#                     "name": "\u53f0\u5317",
#                     "value": [
#                         121.3,
#                         25.03,
#                         91
#                     ]
#                 },
#                 {
#                     "name": "\u4e4c\u9c81\u6728\u9f50",
#                     "value": [
#                         87.68,
#                         43.77,
#                         23
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         69
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         55
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         49
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5173\u6ce8\u5ea6"
#             ],
#             "selected": {
#                 "\u5173\u6ce8\u5ea6": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5730\u7406\u56fe\u8868Geo\u70ed\u529b\u56fe\u793a\u4f8b"
#         }
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#         chart_ba005918b7044f278a942018780ed9b3.setOption(option_ba005918b7044f278a942018780ed9b3);
#     });
# </script>

# %% [markdown]
# ## Map Object

# %% [markdown]
# ### Random Data Initialization

# %%
provinces = ["广东", "北京", "上海", "浙江", "新疆", "四川", "湖北", "内蒙古", "黑龙江"]

# 注意： 
#
# 因np.random.randint生成的数列元素数据类型为NumPy int类型(numpy.int64, 而非pyecharts能够识别的Python int类型。
# 故此需要使用int(i)进行二次封装转换成Python int类型数列。
#
provincesdataset = [list(x) for x in zip(provinces, [int(i) for i in np.random.randint(100, 1000, size=len(provinces))])]
print(provincesdataset)
# Out:
# [['广东', 155], ['北京', 205], ['上海', 310], ['浙江', 141], ['新疆', 206], ['四川', 884], ['湖北', 587], ['内蒙古', 895], ['黑龙江', 830]]

# %% [markdown]
# ### Map Samples

# %%
from pyecharts.charts import Map

map1 = (
    Map()
    .add(
        "Map关注度", 
        provincesdataset,
        "china"
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(
            min_=100, 
            max_=1000, 
            is_piecewise=True,
            split_number=6,
            range_color=["#EEFFEE", "#003F00"]
        ),
        title_opts=opts.TitleOpts(title="地理图表Map基本示例")
    )
)

map1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="22a69d5a776e43e88223bd90c62f5384" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_22a69d5a776e43e88223bd90c62f5384 = echarts.init(
#             document.getElementById('22a69d5a776e43e88223bd90c62f5384'), 'white', {renderer: 'canvas'});
#         var option_22a69d5a776e43e88223bd90c62f5384 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Map\u5173\u6ce8\u5ea6",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 155
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 205
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 310
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 141
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 206
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 884
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 587
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 895
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 830
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Map\u5173\u6ce8\u5ea6"
#             ],
#             "selected": {
#                 "Map\u5173\u6ce8\u5ea6": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5730\u7406\u56fe\u8868Map\u57fa\u672c\u793a\u4f8b"
#         }
#     ],
#     "visualMap": {
#         "type": "piecewise",
#         "min": 100,
#         "max": 1000,
#         "inRange": {
#             "color": [
#                 "#EEFFEE",
#                 "#003F00"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 6,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#         chart_22a69d5a776e43e88223bd90c62f5384.setOption(option_22a69d5a776e43e88223bd90c62f5384);
#     });
# </script>

# %%
map2 = (
    Map()
    .add(
        "", 
        [],
        "world",
        is_roam = False,
        center = [90,25],
        zoom = 2.5
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        # visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="地理图表Map基本示例（世界地图-亚洲主要地区）")
    )
)

map2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#     <div id="5c59cc93e61f4e0aa3520c26784e1e87" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'world'], function(echarts) {
#         var chart_5c59cc93e61f4e0aa3520c26784e1e87 = echarts.init(
#             document.getElementById('5c59cc93e61f4e0aa3520c26784e1e87'), 'white', {renderer: 'canvas'});
#         var option_5c59cc93e61f4e0aa3520c26784e1e87 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [],
#             "roam": false,
#             "center": [
#                 90,
#                 25
#             ],
#             "zoom": 2.5,
#             "showLegendSymbol": true,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5730\u7406\u56fe\u8868Map\u57fa\u672c\u793a\u4f8b\uff08\u4e16\u754c\u5730\u56fe-\u4e9a\u6d32\u4e3b\u8981\u5730\u533a\uff09"
#         }
#     ]
# };
#         chart_5c59cc93e61f4e0aa3520c26784e1e87.setOption(option_5c59cc93e61f4e0aa3520c26784e1e87);
#     });
# </script>
