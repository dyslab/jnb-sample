# %%
# Install wheels by the magic commands below and restart at the very first time before running the following cells.
#
# %pip install pyecharts
#

# %% [markdown]
# # 柱状图/折线图/饼图（pandas数据源）

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(
    {
        '商品名称': ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子", "鞋子", "帽子"],
        '广州HM': [35, 25, 66, 39, 35, 78, 73, 55],
        '杭州美乐': [25, 33, 46, 30, 15, 46, 63, 43]
    }
)
df
# Out:
#   商品名称  广州HM  杭州美乐
# 0   衬衫    35    25
# 1  羊毛衫    25    33
# 2  雪纺衫    66    46
# 3   裤子    39    30
# 4  高跟鞋    35    15
# 5   袜子    78    46
# 6   鞋子    73    63
# 7   帽子    55    43

# %%
df.columns.to_list()
# Out:
# ['商品名称', '广州HM', '杭州美乐']

# %%
from pyecharts import options as opts
from pyecharts.globals import ThemeType

# %%
from pyecharts.charts import Bar

bar = (
    Bar(init_opts = opts.InitOpts(width="720px", height="360px", theme = ThemeType.WESTEROS))
    .add_xaxis(df['商品名称'].to_list())
    .add_yaxis("广州HM", df['广州HM'].to_list())
    .add_yaxis("杭州美乐", df['杭州美乐'].to_list())
    .set_global_opts(title_opts = opts.TitleOpts(title="柱状图测试样板主标题", subtitle="副标题测试"))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'westeros':'https://assets.pyecharts.org/assets/themes/westeros'
#         }
#     });
# </script>
#
#         <div id="be2515ce526a4d9c9422de2f930321da" style="width:720px; height:360px;"></div>
#
# <script>
#         require(['echarts', 'westeros'], function(echarts) {
#                 var chart_be2515ce526a4d9c9422de2f930321da = echarts.init(
#                     document.getElementById('be2515ce526a4d9c9422de2f930321da'), 'westeros', {renderer: 'canvas'});
#                 var option_be2515ce526a4d9c9422de2f930321da = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5e7f\u5ddeHM",
#             "data": [
#                 35,
#                 25,
#                 66,
#                 39,
#                 35,
#                 78,
#                 73,
#                 55
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u676d\u5dde\u7f8e\u4e50",
#             "data": [
#                 25,
#                 33,
#                 46,
#                 30,
#                 15,
#                 46,
#                 63,
#                 43
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e7f\u5ddeHM",
#                 "\u676d\u5dde\u7f8e\u4e50"
#             ],
#             "selected": {
#                 "\u5e7f\u5ddeHM": true,
#                 "\u676d\u5dde\u7f8e\u4e50": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u978b\u5b50",
#                 "\u5e3d\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u6d4b\u8bd5\u6837\u677f\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898\u6d4b\u8bd5"
#         }
#     ]
# };
#                 chart_be2515ce526a4d9c9422de2f930321da.setOption(option_be2515ce526a4d9c9422de2f930321da);
#         });
#     </script>

# %%
from pyecharts.charts import Line

line = (
    Line(init_opts = opts.InitOpts(width="800px", height="400px", theme = ThemeType.ROMA))
    .add_xaxis(df['商品名称'].to_list())
    .add_yaxis("广州HM", df['广州HM'].to_list())
    .add_yaxis("杭州美乐", df['杭州美乐'].to_list())
    .set_global_opts(title_opts = opts.TitleOpts(title="折线图测试样板主标题", subtitle="副标题测试"))
)
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'roma':'https://assets.pyecharts.org/assets/themes/roma'
#         }
#     });
# </script>
#
#         <div id="69b6416456f54fa79ac50325ac11dee9" style="width:800px; height:400px;"></div>
#
# <script>
#         require(['echarts', 'roma'], function(echarts) {
#                 var chart_69b6416456f54fa79ac50325ac11dee9 = echarts.init(
#                     document.getElementById('69b6416456f54fa79ac50325ac11dee9'), 'roma', {renderer: 'canvas'});
#                 var option_69b6416456f54fa79ac50325ac11dee9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5e7f\u5ddeHM",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     35
#                 ],
#                 [
#                     "\u7f8a\u6bdb\u886b",
#                     25
#                 ],
#                 [
#                     "\u96ea\u7eba\u886b",
#                     66
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     39
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     35
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     78
#                 ],
#                 [
#                     "\u978b\u5b50",
#                     73
#                 ],
#                 [
#                     "\u5e3d\u5b50",
#                     55
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u676d\u5dde\u7f8e\u4e50",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     25
#                 ],
#                 [
#                     "\u7f8a\u6bdb\u886b",
#                     33
#                 ],
#                 [
#                     "\u96ea\u7eba\u886b",
#                     46
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     30
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     15
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     46
#                 ],
#                 [
#                     "\u978b\u5b50",
#                     63
#                 ],
#                 [
#                     "\u5e3d\u5b50",
#                     43
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e7f\u5ddeHM",
#                 "\u676d\u5dde\u7f8e\u4e50"
#             ],
#             "selected": {
#                 "\u5e7f\u5ddeHM": true,
#                 "\u676d\u5dde\u7f8e\u4e50": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u978b\u5b50",
#                 "\u5e3d\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6298\u7ebf\u56fe\u6d4b\u8bd5\u6837\u677f\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898\u6d4b\u8bd5"
#         }
#     ]
# };
#                 chart_69b6416456f54fa79ac50325ac11dee9.setOption(option_69b6416456f54fa79ac50325ac11dee9);
#         });
#     </script>

# %%
from pyecharts.charts import Pie

pie = (
    Pie(init_opts = opts.InitOpts(width="800px", height="400px"))
    .add(
        "", 
        [list(z) for z in zip(df['商品名称'].to_list()[2:7], df['广州HM'].to_list()[2:7])],
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="饼图测试样板"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}：{c}件"))
)

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="10e60067cdf1422e92db95ea69f676ff" style="width:800px; height:400px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_10e60067cdf1422e92db95ea69f676ff = echarts.init(
#                     document.getElementById('10e60067cdf1422e92db95ea69f676ff'), 'white', {renderer: 'canvas'});
#                 var option_10e60067cdf1422e92db95ea69f676ff = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 35
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 78
#                 },
#                 {
#                     "name": "\u978b\u5b50",
#                     "value": 73
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}\uff1a{c}\u4ef6"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u978b\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u997c\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#                 chart_10e60067cdf1422e92db95ea69f676ff.setOption(option_10e60067cdf1422e92db95ea69f676ff);
#         });
#     </script>

# %%
from pyecharts.charts import Radar

datadefs=[("攻击力", 100), ("防御力", 100), ("机动力", 100), ("持久力", 100), ("经济力", 100)]

datadf = pd.DataFrame(
    {
        '张小五': np.random.randint(20,100,size=5),
        '李大六': np.random.randint(20,100,size=5)
    }
)

rd = (
    Radar(init_opts = opts.InitOpts(theme = ThemeType.INFOGRAPHIC))
    .add_schema(
        schema=[opts.RadarIndicatorItem(name=datadefs[i][0], max_=datadefs[i][1]) for i in range(len(datadefs))]
    )
    .add("张小五", [datadf['张小五'].to_list()])
    .add("李大六", [datadf['李大六'].to_list()])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="雷达图测试样板"))
)

rd.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'infographic':'https://assets.pyecharts.org/assets/themes/infographic'
#         }
#     });
# </script>
#
#         <div id="e61d2960f7854418b9a541ed3f01cb1f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'infographic'], function(echarts) {
#                 var chart_e61d2960f7854418b9a541ed3f01cb1f = echarts.init(
#                     document.getElementById('e61d2960f7854418b9a541ed3f01cb1f'), 'infographic', {renderer: 'canvas'});
#                 var option_e61d2960f7854418b9a541ed3f01cb1f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u5f20\u5c0f\u4e94",
#             "data": [
#                 [
#                     67,
#                     82,
#                     91,
#                     64,
#                     58
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u674e\u5927\u516d",
#             "data": [
#                 [
#                     73,
#                     75,
#                     25,
#                     97,
#                     22
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5f20\u5c0f\u4e94",
#                 "\u674e\u5927\u516d"
#             ],
#             "selected": {
#                 "\u5f20\u5c0f\u4e94": true,
#                 "\u674e\u5927\u516d": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radar": {
#         "indicator": [
#             {
#                 "name": "\u653b\u51fb\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u9632\u5fa1\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u673a\u52a8\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u6301\u4e45\u529b",
#                 "max": 100
#             },
#             {
#                 "name": "\u7ecf\u6d4e\u529b",
#                 "max": 100
#             }
#         ],
#         "name": {
#             "textStyle": {}
#         },
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             }
#         },
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "onZero": true,
#             "onZeroAxisIndex": 0
#         }
#     },
#     "title": [
#         {
#             "text": "\u96f7\u8fbe\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#                 chart_e61d2960f7854418b9a541ed3f01cb1f.setOption(option_e61d2960f7854418b9a541ed3f01cb1f);
#         });
#     </script>

# %% [markdown]
# # 其他数据图（自定义或随机数据源）

# %%
from pyecharts.charts import Polar

po = (
    Polar(init_opts = opts.InitOpts(width="800px", height="400px"))
    .add(
        "",
        #[[0,55], [1,25], [2, 84], [3, 72], [4, 37]],
        [(i, np.random.randint(0, 100)) for i in range(20)],
        type_="effectScatter",
        effect_opts=opts.EffectOpts(scale=6, period=4),
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="极坐标随机散点图测试样板"))
)

po.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a538a001e39e438f8dc613757c0a89a7" style="width:800px; height:400px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a538a001e39e438f8dc613757c0a89a7 = echarts.init(
#                     document.getElementById('a538a001e39e438f8dc613757c0a89a7'), 'white', {renderer: 'canvas'});
#                 var option_a538a001e39e438f8dc613757c0a89a7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "polar",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 6,
#                 "period": 4
#             },
#             "symbolSize": 4,
#             "data": [
#                 [
#                     0,
#                     41
#                 ],
#                 [
#                     1,
#                     80
#                 ],
#                 [
#                     2,
#                     93
#                 ],
#                 [
#                     3,
#                     66
#                 ],
#                 [
#                     4,
#                     98
#                 ],
#                 [
#                     5,
#                     62
#                 ],
#                 [
#                     6,
#                     58
#                 ],
#                 [
#                     7,
#                     56
#                 ],
#                 [
#                     8,
#                     54
#                 ],
#                 [
#                     9,
#                     95
#                 ],
#                 [
#                     10,
#                     28
#                 ],
#                 [
#                     11,
#                     51
#                 ],
#                 [
#                     12,
#                     80
#                 ],
#                 [
#                     13,
#                     95
#                 ],
#                 [
#                     14,
#                     88
#                 ],
#                 [
#                     15,
#                     80
#                 ],
#                 [
#                     16,
#                     61
#                 ],
#                 [
#                     17,
#                     98
#                 ],
#                 [
#                     18,
#                     1
#                 ],
#                 [
#                     19,
#                     49
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radiusAxis": {
#         "scale": false
#     },
#     "angleAxis": {
#         "clockwise": false
#     },
#     "polar": {},
#     "title": [
#         {
#             "text": "\u6781\u5750\u6807\u968f\u673a\u6563\u70b9\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#                 chart_a538a001e39e438f8dc613757c0a89a7.setOption(option_a538a001e39e438f8dc613757c0a89a7);
#         });
#     </script>

# %%
from pyecharts.charts import Gauge

fp = 30
try:
    fp = float(input('工作进度? (0-100) '))
except ValueError as e:
    print(e)

gauge = (
    Gauge()
    .add(
        "工作进度", 
        [("百分比%", fp)],
        axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(
                    color=[(0.3, "#37ca92"), (0.7, "#67c3c0"), (1, "#f0668d")], width=30
                )
            ),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="仪表盘测试样板"))
)
gauge.render_notebook()
# Out:
# 工作进度? (0-100) 59
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="25a1d37e6926498792068985c9e2aa67" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_25a1d37e6926498792068985c9e2aa67 = echarts.init(
#                     document.getElementById('25a1d37e6926498792068985c9e2aa67'), 'white', {renderer: 'canvas'});
#                 var option_25a1d37e6926498792068985c9e2aa67 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "name": "\u5de5\u4f5c\u8fdb\u5ea6",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u767e\u5206\u6bd4%",
#                     "value": 59.0
#                 }
#             ],
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 30,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": [
#                         [
#                             0.3,
#                             "#37ca92"
#                         ],
#                         [
#                             0.7,
#                             "#67c3c0"
#                         ],
#                         [
#                             1,
#                             "#f0668d"
#                         ]
#                     ]
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5de5\u4f5c\u8fdb\u5ea6"
#             ],
#             "selected": {
#                 "\u5de5\u4f5c\u8fdb\u5ea6": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4eea\u8868\u76d8\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#                 chart_25a1d37e6926498792068985c9e2aa67.setOption(option_25a1d37e6926498792068985c9e2aa67);
#         });
#     </script>

# %%
from pyecharts.charts import Liquid
from pyecharts.commons import utils

lq = (
    Liquid()
    .add(
        "工作进度", 
        [fp / 100, fp / 100],
        tooltip_opts=opts.TooltipOpts(
            formatter=utils.JsCode("""function (param) {
                return param.seriesName + ': ' + (Math.round(param.value * 10000) / 100) + '%';
            }
            """),
        )
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="水量图测试样板"))
)

lq.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="a282c7a6911f49f4b558afc280634707" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_a282c7a6911f49f4b558afc280634707 = echarts.init(
#                     document.getElementById('a282c7a6911f49f4b558afc280634707'), 'white', {renderer: 'canvas'});
#                 var option_a282c7a6911f49f4b558afc280634707 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "\u5de5\u4f5c\u8fdb\u5ea6",
#             "data": [
#                 0.59,
#                 0.59
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "formatter": function (param) {                return param.seriesName + ': ' + (Math.round(param.value * 10000) / 100) + '%';            }            ,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6c34\u91cf\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#                 chart_a282c7a6911f49f4b558afc280634707.setOption(option_a282c7a6911f49f4b558afc280634707);
#         });
#     </script>

# %%
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType

words =('张三丰','Hello World','网红李','河边小草','打包件','王八蛋','笑死我','哈哈哈','有间客栈','解放军','中美关系','贸易战','中国航母')

wordsfrequency = [(words[i], np.random.randint(500,5000)) for i in range(len(words))]
wc = (
    WordCloud()
    .add(
        "",
        wordsfrequency,
        # 词云图轮廓，有 'ARROW', 'DIAMOND', 'RECT', 'ROUND_RECT', 'TRIANGLE'可选
        shape=SymbolType.DIAMOND
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="词云样板"))
)

print(wordsfrequency)
wc.render_notebook()
# Out:
# [('张三丰', 689), ('Hello World', 1318), ('网红李', 4094), ('河边小草', 678), ('打包件', 2174), ('王八蛋', 4222), ('笑死我', 4628), ('哈哈哈', 2366), ('有间客栈', 4177), ('解放军', 2555), ('中美关系', 2579), ('贸易战', 2654), ('中国航母', 2199)]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="16403403e78d49c79412273ca9b86697" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_16403403e78d49c79412273ca9b86697 = echarts.init(
#                     document.getElementById('16403403e78d49c79412273ca9b86697'), 'white', {renderer: 'canvas'});
#                 var option_16403403e78d49c79412273ca9b86697 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "\u5f20\u4e09\u4e30",
#                     "value": 689,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,10,153)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Hello World",
#                     "value": 1318,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(20,3,99)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f51\u7ea2\u674e",
#                     "value": 4094,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(45,71,144)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6cb3\u8fb9\u5c0f\u8349",
#                     "value": 678,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(112,19,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6253\u5305\u4ef6",
#                     "value": 2174,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(80,99,84)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u738b\u516b\u86cb",
#                     "value": 4222,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(24,137,21)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7b11\u6b7b\u6211",
#                     "value": 4628,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(71,16,125)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u54c8\u54c8\u54c8",
#                     "value": 2366,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(57,109,113)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6709\u95f4\u5ba2\u6808",
#                     "value": 4177,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(84,29,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u89e3\u653e\u519b",
#                     "value": 2555,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(61,74,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u7f8e\u5173\u7cfb",
#                     "value": 2579,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,27,14)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8d38\u6613\u6218",
#                     "value": 2654,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(100,48,157)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u56fd\u822a\u6bcd",
#                     "value": 2199,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(22,152,157)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u8bcd\u4e91\u6837\u677f"
#         }
#     ]
# };
#                 chart_16403403e78d49c79412273ca9b86697.setOption(option_16403403e78d49c79412273ca9b86697);
#         });
#     </script>

# %%
import random
from pyecharts.charts import Scatter3D

sd3 = (
    Scatter3D()
    .add(
        "", 
        [[random.randint(0, 100), random.randint(0, 100), random.randint(0, 100)] for _ in range(30)],
        grid3d_opts = opts.Grid3DOpts(width=100, height=100, depth=100)
    )
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="三维散点图测试样板")
    )
)

sd3.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="1024674218ca4a08b16a3904a358ad78" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_1024674218ca4a08b16a3904a358ad78 = echarts.init(
#                     document.getElementById('1024674218ca4a08b16a3904a358ad78'), 'white', {renderer: 'canvas'});
#                 var option_1024674218ca4a08b16a3904a358ad78 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter3D",
#             "data": [
#                 [
#                     68,
#                     21,
#                     39
#                 ],
#                 [
#                     31,
#                     71,
#                     52
#                 ],
#                 [
#                     33,
#                     52,
#                     84
#                 ],
#                 [
#                     89,
#                     73,
#                     96
#                 ],
#                 [
#                     48,
#                     82,
#                     32
#                 ],
#                 [
#                     11,
#                     90,
#                     54
#                 ],
#                 [
#                     7,
#                     89,
#                     95
#                 ],
#                 [
#                     8,
#                     7,
#                     32
#                 ],
#                 [
#                     87,
#                     93,
#                     4
#                 ],
#                 [
#                     47,
#                     18,
#                     62
#                 ],
#                 [
#                     98,
#                     47,
#                     99
#                 ],
#                 [
#                     71,
#                     23,
#                     98
#                 ],
#                 [
#                     35,
#                     28,
#                     35
#                 ],
#                 [
#                     43,
#                     11,
#                     41
#                 ],
#                 [
#                     49,
#                     28,
#                     33
#                 ],
#                 [
#                     29,
#                     14,
#                     41
#                 ],
#                 [
#                     90,
#                     54,
#                     9
#                 ],
#                 [
#                     75,
#                     1,
#                     13
#                 ],
#                 [
#                     36,
#                     86,
#                     35
#                 ],
#                 [
#                     61,
#                     14,
#                     5
#                 ],
#                 [
#                     48,
#                     87,
#                     80
#                 ],
#                 [
#                     93,
#                     83,
#                     28
#                 ],
#                 [
#                     95,
#                     90,
#                     26
#                 ],
#                 [
#                     3,
#                     48,
#                     79
#                 ],
#                 [
#                     57,
#                     30,
#                     35
#                 ],
#                 [
#                     1,
#                     88,
#                     71
#                 ],
#                 [
#                     100,
#                     80,
#                     13
#                 ],
#                 [
#                     76,
#                     70,
#                     99
#                 ],
#                 [
#                     16,
#                     98,
#                     68
#                 ],
#                 [
#                     70,
#                     89,
#                     91
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     },
#     "xAxis3D": {
#         "nameGap": 20,
#         "type": "category",
#         "axisLabel": {
#             "margin": 8
#         }
#     },
#     "yAxis3D": {
#         "nameGap": 20,
#         "type": "category",
#         "axisLabel": {
#             "margin": 8
#         }
#     },
#     "zAxis3D": {
#         "nameGap": 20,
#         "type": "value",
#         "axisLabel": {
#             "margin": 8
#         }
#     },
#     "grid3D": {
#         "boxWidth": 100,
#         "boxHeight": 100,
#         "boxDepth": 100,
#         "viewControl": {
#             "autoRotate": false,
#             "autoRotateSpeed": 10,
#             "rotateSensitivity": 1
#         }
#     },
#     "title": [
#         {
#             "text": "\u4e09\u7ef4\u6563\u70b9\u56fe\u6d4b\u8bd5\u6837\u677f"
#         }
#     ]
# };
#                 chart_1024674218ca4a08b16a3904a358ad78.setOption(option_1024674218ca4a08b16a3904a358ad78);
#         });
#     </script>

# %% [markdown]
# # 地理图表
#
# ## pyecharts地图数据链接
#
# ### [中国常用城市地图代码 maptype](https://github.com/pyecharts/pyecharts/blob/master/pyecharts/datasets/map_filename.json)
#
# ### [中国常用城市地图坐标数据](https://github.com/pyecharts/pyecharts/blob/master/pyecharts/datasets/city_coordinates.json)
#
# ### [世界各国地理代码](https://github.com/pyecharts/pyecharts/blob/master/pyecharts/datasets/countries_regions_db.json)

# %% [markdown]
# ## Geo Object

# %% [markdown]
# ### Random Data Initialization

# %%
cites = ["广州", "北京", "上海", "兰州", "台北", "乌鲁木齐", "西安", "成都", "哈尔滨"]

# 注意： 
#
# 因np.random.randint生成的数列元素数据类型为NumPy int类型(numpy.int64, 而非pyecharts能够识别的Python int类型。
# 故此需要使用int(i)进行二次封装转换成Python int类型数列。
#
citiesdataset = [list(x) for x in zip(cites, [int(i) for i in np.random.randint(1, 100, size=len(cites))])]
print(citiesdataset)
# Out:
# [['广州', 9], ['北京', 86], ['上海', 22], ['兰州', 66], ['台北', 23], ['乌鲁木齐', 87], ['西安', 44], ['成都', 96], ['哈尔滨', 85]]

# %% [markdown]
# ### Geo Samples

# %%
from pyecharts.charts import Geo
from pyecharts.globals import ChartType

geo1 = (
    Geo()
    .add(
        "关注度", 
        # [['台北', 96], ['广州', 45], ['北京', 34], ['上海', 85]],
        citiesdataset,
        type_=ChartType.EFFECT_SCATTER
    )
    .add_schema(maptype="china")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(is_piecewise=True),
        title_opts=opts.TitleOpts(title="地理图表Geo基本示例"))
)

geo1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="9e7bc8904d9345dfa0c513e1c4794d78" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_9e7bc8904d9345dfa0c513e1c4794d78 = echarts.init(
#                     document.getElementById('9e7bc8904d9345dfa0c513e1c4794d78'), 'white', {renderer: 'canvas'});
#                 var option_9e7bc8904d9345dfa0c513e1c4794d78 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "\u5173\u6ce8\u5ea6",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         9
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         86
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         22
#                     ]
#                 },
#                 {
#                     "name": "\u5170\u5dde",
#                     "value": [
#                         103.73,
#                         36.03,
#                         66
#                     ]
#                 },
#                 {
#                     "name": "\u53f0\u5317",
#                     "value": [
#                         121.3,
#                         25.03,
#                         23
#                     ]
#                 },
#                 {
#                     "name": "\u4e4c\u9c81\u6728\u9f50",
#                     "value": [
#                         87.68,
#                         43.77,
#                         87
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         44
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         96
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         85
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5173\u6ce8\u5ea6"
#             ],
#             "selected": {
#                 "\u5173\u6ce8\u5ea6": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5730\u7406\u56fe\u8868Geo\u57fa\u672c\u793a\u4f8b"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_9e7bc8904d9345dfa0c513e1c4794d78.setOption(option_9e7bc8904d9345dfa0c513e1c4794d78);
#         });
#     </script>

# %%
geo2 = (
    Geo()
    .add(
        "关注度", 
        citiesdataset,
        type_=ChartType.HEATMAP
    )
    .add_schema(maptype="china")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="地理图表Geo热力图示例"))
)

geo2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="86d7f68c534049a4ab68bdeb38791d05" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_86d7f68c534049a4ab68bdeb38791d05 = echarts.init(
#                     document.getElementById('86d7f68c534049a4ab68bdeb38791d05'), 'white', {renderer: 'canvas'});
#                 var option_86d7f68c534049a4ab68bdeb38791d05 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u5173\u6ce8\u5ea6",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         9
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         86
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         22
#                     ]
#                 },
#                 {
#                     "name": "\u5170\u5dde",
#                     "value": [
#                         103.73,
#                         36.03,
#                         66
#                     ]
#                 },
#                 {
#                     "name": "\u53f0\u5317",
#                     "value": [
#                         121.3,
#                         25.03,
#                         23
#                     ]
#                 },
#                 {
#                     "name": "\u4e4c\u9c81\u6728\u9f50",
#                     "value": [
#                         87.68,
#                         43.77,
#                         87
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         44
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         96
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         85
#                     ]
#                 }
#             ],
#             "pointSize": 20,
#             "blurSize": 20,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5173\u6ce8\u5ea6"
#             ],
#             "selected": {
#                 "\u5173\u6ce8\u5ea6": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5730\u7406\u56fe\u8868Geo\u70ed\u529b\u56fe\u793a\u4f8b"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_86d7f68c534049a4ab68bdeb38791d05.setOption(option_86d7f68c534049a4ab68bdeb38791d05);
#         });
#     </script>

# %% [markdown]
# ## Map Object

# %% [markdown]
# ### Random Data Initialization

# %%
provinces = ["广东省", "北京市", "上海市", "浙江省", "新疆维吾尔自治区", "四川省", "湖北省", "内蒙古自治区", "黑龙江省","台湾省"]

# 注意： 
#
# 因np.random.randint生成的数列元素数据类型为NumPy int类型(numpy.int64, 而非pyecharts能够识别的Python int类型。
# 故此需要使用int(i)进行二次封装转换成Python int类型数列。
#
provincesdataset = [list(x) for x in zip(provinces, [int(i) for i in np.random.randint(100, 1000, size=len(provinces))])]
print(provincesdataset)
# Out:
# [['广东省', 823], ['北京市', 794], ['上海市', 529], ['浙江省', 634], ['新疆维吾尔自治区', 275], ['四川省', 180], ['湖北省', 625], ['内蒙古自治区', 943], ['黑龙江省', 505], ['台湾省', 830]]

# %% [markdown]
# ### Map Samples

# %%
from pyecharts import options as opts
from pyecharts.charts import Map

map1 = (
    Map()
    .add(
        "Map关注度", 
        provincesdataset,
        "china"
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(
            min_=0, 
            max_=1000, 
            is_piecewise=True,
            split_number=5,
            range_color=["#EEFFEE", "#003F00"]
        ),
        title_opts=opts.TitleOpts(title="地理图表Map基本示例")
    )
)

map1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="bbf02c0fc98645c6b77ca78e04437401" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_bbf02c0fc98645c6b77ca78e04437401 = echarts.init(
#                     document.getElementById('bbf02c0fc98645c6b77ca78e04437401'), 'white', {renderer: 'canvas'});
#                 var option_bbf02c0fc98645c6b77ca78e04437401 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Map\u5173\u6ce8\u5ea6",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c\u7701",
#                     "value": 823
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": 794
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": 529
#                 },
#                 {
#                     "name": "\u6d59\u6c5f\u7701",
#                     "value": 634
#                 },
#                 {
#                     "name": "\u65b0\u7586\u7ef4\u543e\u5c14\u81ea\u6cbb\u533a",
#                     "value": 275
#                 },
#                 {
#                     "name": "\u56db\u5ddd\u7701",
#                     "value": 180
#                 },
#                 {
#                     "name": "\u6e56\u5317\u7701",
#                     "value": 625
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4\u81ea\u6cbb\u533a",
#                     "value": 943
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f\u7701",
#                     "value": 505
#                 },
#                 {
#                     "name": "\u53f0\u6e7e\u7701",
#                     "value": 830
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Map\u5173\u6ce8\u5ea6"
#             ],
#             "selected": {
#                 "Map\u5173\u6ce8\u5ea6": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5730\u7406\u56fe\u8868Map\u57fa\u672c\u793a\u4f8b"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 1000,
#         "inRange": {
#             "color": [
#                 "#EEFFEE",
#                 "#003F00"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14
#     }
# };
#                 chart_bbf02c0fc98645c6b77ca78e04437401.setOption(option_bbf02c0fc98645c6b77ca78e04437401);
#         });
#     </script>

# %%
map2 = (
    Map()
    .add(
        "", 
        [],
        "world",
        is_roam = False,
        center = [90,25],
        zoom = 2.5
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        # visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="地理图表Map基本示例（世界地图-亚洲主要地区）")
    )
)

map2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="56a34a7fc4254bf38b32949442808e02" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_56a34a7fc4254bf38b32949442808e02 = echarts.init(
#                     document.getElementById('56a34a7fc4254bf38b32949442808e02'), 'white', {renderer: 'canvas'});
#                 var option_56a34a7fc4254bf38b32949442808e02 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [],
#             "roam": false,
#             "center": [
#                 90,
#                 25
#             ],
#             "zoom": 2.5,
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5730\u7406\u56fe\u8868Map\u57fa\u672c\u793a\u4f8b\uff08\u4e16\u754c\u5730\u56fe-\u4e9a\u6d32\u4e3b\u8981\u5730\u533a\uff09"
#         }
#     ]
# };
#                 chart_56a34a7fc4254bf38b32949442808e02.setOption(option_56a34a7fc4254bf38b32949442808e02);
#         });
#     </script>
